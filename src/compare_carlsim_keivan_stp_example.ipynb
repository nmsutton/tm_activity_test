# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import statistics as st
from collections import Counter
import os
import os.path
import scipy
import csv
from scipy import signal
import pandas as pd

# %%
plot_source="neuronmonitor" # choose "neuronmonitor" or "jk_custom" for CARLsim data file source
# Create time points
Tmin, Tmax, dt = 0, 1000, 0.025  # Step size
T = np.arange(Tmin, Tmax + dt, dt)

# Declare the current to be used
I_ext = 150

## Nine parameters for IM model
# Axo_Axonic
k, a, b, d, C, vr, vt, c, vpeak = 3.961462878, 0.004638608, 8.683644937, 15, 165, -57.09978287, \
                                  -51.71875628, -73.96850421, 27.79863559

preNeuronType = "Axo-Axonic"

## Make a state vector that has a (v, u) pair for each timestep
s = np.zeros((len(T), 2))

# Create a vector to store spike times
if plot_source=="neuronmonitor":
    spike_times = np.array([15, 40, 67, 97, 130, 166, 206, 249, 295, 343, 392, 442, 493, 544, 595, 646, 697, 748, 799, 850, 901, 952])
if plot_source=="jk_custom":
    spike_times = np.array([])
isi_mode_list = np.array([])


## Initial values
s[0, 0] = vr
s[0, 1] = 0


# Note that s1[0] is v, s1[1] is u. This is Izhikevich equation in vector form
def s_dt(s1, I):
  v_dt = (k*(s1[0] - vr)*(s1[0] - vt) - s1[1] + I)*(1/C)
  u_dt = a*(b*(s1[0] - vr) - s1[1])
  return np.array([v_dt, u_dt])


## SIMULATE
for t in range(len(T)-1):
  # Calculate the four constants of Runge-Kutta method
  k_1 = s_dt(s[t], I_ext)
  k_2 = s_dt(s[t] + 0.5*dt*k_1, I_ext)
  k_3 = s_dt(s[t] + 0.5*dt*k_2, I_ext)
  k_4 = s_dt(s[t] + dt*k_3, I_ext)

  s[t+1] = s[t] + (1.0/6)*dt*(k_1 + 2*k_2 + 2*k_3 + k_4)

  # Reset the neuron if it has spiked
  if s[t+1, 0] >= vpeak:
    s[t, 0]   = vpeak # add Dirac pulse for visualisation
    s[t+1, 0] = c   # Reset to resting potential
    s[t+1, 1] += d  # Update recovery variable
    if plot_source=="jk_custom":
        spike_times = np.append(spike_times, math.ceil(t*dt))
    #print(math.floor(t * dt))

v = s[:, 0]
u = s[:, 1]


## Nine parameters for IM model
# Pyramidal
postNeuronType = "Pyramidal"
a, b, c, d, k, vr, vt, C, vpeak = 0.00838350334098279, -42.5524776883928, -38.8680990294091, 588.0, \
                                  0.792338703789581, -63.2044008171655, -33.6041733124267, 366.0, 35.8614648558726

# Synaptic Parameters and equations
synaptic_event_times = list(spike_times)
print(synaptic_event_times)

# TPM parameters
g0, tau_d, tau_f, tau_r, Utilization, e_rev = 3.644261648, 10.71107251, 17.20004939, 435.8103009, 0.259914361, -70

tm_model = 'Keivan'#'Carlsim'#'Keivan'

if tm_model == 'Keivan':
    # in CARLsim there is no change to the g param from the value it is set as in connect()
    # Note: NS is unclear why this calculation exists and is related to eq. 13 in (Moradi, 2022) supp mat.
    g0 /= Utilization

def synaptic_event(delta_t_, g, g0, tau_d_, tau_r_, tau_f_, utilization, x0, y0, u0, e_syn):
    if tm_model != 'Carlsim':
        # TM Model that depends on tau_d
        tau1r = tau_d_ / ((tau_d_ - tau_r_) if tau_d_ != tau_r_ else 1e-13)
        y_ = y0 * math.exp(-delta_t_ / tau_d_)
        x_ = 1 + (x0 - 1 + tau1r * y0) * math.exp(-delta_t_ / tau_r_) - tau1r * y_
        u_ = u0 * math.exp(-delta_t_ / tau_f_)
        u0 = u_ + utilization * (1 - u_)
        y0 = y_ + u0 * x_
        x0 = x_ - u0 * x_
        g  = g0 * y0
        #print("%f  = %f * %f; u0:%f x0:%f x_:%f" % (g, g0, y0, u0, x0, x_))
    else:
        # Carlsim's TM Model
        A  = 1 / Utilization # this seems to serve the same function as g0 /= Utilization would
        u_ = u0 + utilization * (1 - u0)
        x_ = x0 - u_ * x0
        #print("%f + %f * (%f * %f * %f)" % (g, g0, A, u_, x_))        
        g  = g + g0 * (A * u_ * x0)
        u0 = u_
        x0 = x_
        
    return g, x0, y0, u0


def synaptic_current(I, g, delta_t_, tau_d_, e_syn_, tm_model):
    if tm_model == 'Keivan':
        #g = g * math.exp(-delta_t_ / tau_d_) * e_syn_
        I = g * math.exp(-delta_t_ / tau_d_) * e_syn_
    if tm_model == 'Carlsim':
        I = g * e_syn_
        #print("%f * (1 - (1 / %f))" % (g,tau_d))
    return I

def synaptic_decay(g, tau_d_, tm_model):
    g = g * (1 - (1 / tau_d_))
    return g

def stp_variable_update(u, x, tau_f, tau_r, tm_model):
    tau_f_inv = 1/tau_f
    tau_r_inv = 1/tau_r
    u = u * (1 - tau_f_inv)
    x = x + (1 - x) * tau_r_inv
    #u = u + -u/tau_f
    #x = x + (1 - x)/tau_r
    return u, x

# Initialize synaptic state variables
g, x0, y0 = 0.0, 1.0, 0.0
I = 0.0
if tm_model == 'Carlsim':
    u0 = 0 #Utilization # NS does not see evidence in CARLsim that this is initialized as other than 0
else:
    u0 = 0

# Make a state vector that has a (v, u) pair for each timestep
s = np.zeros((len(T), 2))

# Initial Izhikevich state variables
s[0, 0] = vr
s[0, 1] = 0


# Note that s1[0] is v, s1[1] is u. This is Izhikevich equation in vector form
def s_dt(s1, I):
    v_dt = (k * (s1[0] - vr) * (s1[0] - vt) - s1[1] + I) * (1 / C)
    u_dt = a * (b * (s1[0] - vr) - s1[1])
    return np.array([v_dt, u_dt])

# SIMULATE
next_synaptic_event_time, delta_t, I_syn = synaptic_event_times[0], 0.0, [0]
synaptic_event_time = next_synaptic_event_time
spike_times = np.array([])
for t in range(len(T) - 1):
    v = s[t, 0]
    e_syn = v - e_rev
    time = T[t]

    # in CARLsim this occurs before the synaptic spike current update. doSTPUpdateAndDecayCond() is before globalStateUpdate().
    if (tm_model == 'Carlsim' and t % (1/dt) == 0): # run every whole number millisecond
        g = synaptic_decay(g, tau_d, tm_model)
        u0, x0 = stp_variable_update(u0, x0, tau_f, tau_r, tm_model)

    if next_synaptic_event_time <= time:
        inter_event_time = next_synaptic_event_time - synaptic_event_time
        g, x0, y0, u0 = synaptic_event(inter_event_time, g, g0, tau_d, tau_r, tau_f, Utilization, x0, y0, u0, e_syn)
        # NS updated g for carlsim calcs
        #print(g, time, synaptic_event_time, next_synaptic_event_time)
        print("t:%d I:%.3f\tg:%.3f\tu:%.3f\tx:%.3f\tv:%.3f\tsynaptic spike" % (time,I,g,u0,x0,e_syn))
        synaptic_event_time = time
        if len(synaptic_event_times) > 1:
            del synaptic_event_times[0]
            next_synaptic_event_time = synaptic_event_times[0]
        else:
            next_synaptic_event_time = math.inf

    delta_t = time - synaptic_event_time
    if delta_t >= 0:
        if (t % (1/dt) == 0):
            I = synaptic_current(I, g, delta_t, tau_d, e_syn, tm_model)
            print("t:%d I:%.3f\tg:%.3f\tu:%.3f\tx:%.3f\tv:%.3f\tcurrent decay" % (t/(1/dt),I,g,u0,x0,e_syn))
    I_syn.append(I)

    # Calculate the four constants of Runge-Kutta method
    k_1 = s_dt(s[t], -I)
    k_2 = s_dt(s[t] + 0.5 * dt * k_1, -I)
    k_3 = s_dt(s[t] + 0.5 * dt * k_2, -I)
    k_4 = s_dt(s[t] + dt * k_3, -I)

    s[t + 1] = s[t] + (1.0 / 6) * dt * (k_1 + 2 * k_2 + 2 * k_3 + k_4)

    # Reset the neuron if it has spiked
    if s[t + 1, 0] >= vpeak:
        s[t, 0] = vpeak  # add Dirac pulse for visualisation
        s[t + 1, 0] = c  # Reset to resting potential
        s[t + 1, 1] += d  # Update recovery variable
        spike_times = np.append(spike_times, math.floor(t * dt))

v = s[:, 0]
u = s[:, 1]

# First define function to flip the sign of the current
def sign(lst): 
    return [ -i for i in lst ]

# downsample
if plot_source=="neuronmonitor":
    steps = 40 #1/dt
    dt = 1  # Step size
    T = np.arange(Tmin, Tmax + dt, dt)

# Compare to CARLsim simulation output
if plot_source=="neuronmonitor":
    FH = np.loadtxt("stp_compare_results.csv")
elif plot_source=="jk_custom":
    FH = np.loadtxt("HC_IM_05_26_aac_pyr_I_150pA_fast_1_slow_0.txt")
I = FH[1::2]
V = FH[0::2]
I = sign(I)
I = I[0:len(I_syn)-1]
V = V[0:len(I_syn)-1]
ax1 = plt.subplot(211)
ax1.plot(T,np.append(V, [V[-1]]), label = "CARLsim TM") # added the last value of V to ensure the same length as time vector
plt.ylabel('Membrane potential (mV)')
ax2 = plt.subplot(212)
ax2.plot(T,np.append(I, [I[-1]]), label = "CARLsim TM") # added the last value of I to ensure the same length as time vector
plt.ylabel('Synaptic Current (pA)')
plt.xlabel('Time (ms)')
plt.legend(loc = "center right")
plt.tight_layout()

# downsample
if plot_source=="neuronmonitor":
    v = v[0:v.size:steps]
    I_syn = I_syn[0:len(I_syn):steps]

## Plot the membrane potential
ax1 = plt.subplot(211)
ax1.plot(T, v, color = "orange", linestyle='dotted', label = "Keivan TM", alpha=0.85)
plt.ylabel('Membrane potential (mV)')
plt.title(f"{postNeuronType}")
ax2 = plt.subplot(212)
ax2.plot(T, I_syn, color = "orange", linestyle='dotted', label = "Keivan TM", alpha=0.85)
plt.ylabel('Synaptic Current (pA)')
plt.xlabel('Time (ms)')
plt.legend(loc = "center right")
plt.tight_layout()
fileOutputName = preNeuronType + '_' + postNeuronType + '_' + str(I_ext) + 'pA' + \
      '_CARLsim_vs_Keivan_superimposed.png'
plt.savefig(fileOutputName, dpi=800)
plt.clf()


# Look at the error between CARLsim and python computed synaptic signal
I = np.append(I, [I[-1]])
V = np.append(V, [V[-1]])
#if plot_source=="neuronmonitor":
#    V = np.append(V, [V[-1]])

af = scipy.fft.fft(I_syn)
bf = scipy.fft.fft(I)
c = scipy.ifft(af * scipy.conj(bf))
time_shift = np.argmax(abs(c))
#         print(time_shift)

#if plot_source=="neuronmonitor":
#    I_2 = I
#if plot_source=="jk_custom":
#    I_2 = I[:-1]
I_2 = I[:-1]
I_2 = I_2[::int(1/dt)]
I_syn_2 = I_syn[0+time_shift:]
I_syn_2 = I_syn_2[::int(1/dt)]
I_syn_2 = np.array(np.array(I_syn_2,dtype=np.float32))
V_2 = V[:-1]
V_2 = V_2[::int(1/dt)]
v_2 = v[0+time_shift:]
v_2 = v_2[::int(1/dt)]

if len(V_2) == len(v_2):
    ax1 = plt.subplot(211)
    ax1.plot(abs(V_2 - v_2))
    plt.ylabel('Membrane potential (mV)')
    plt.title(f"{postNeuronType}")
    ax2 = plt.subplot(212)
    ax2.plot(abs(I_2 - I_syn_2))
    plt.ylabel('I_syn diff (HCO - Carlsim) (pA)')
    plt.xlabel('Time (ms)')
    plt.tight_layout()
    fileOutputName = preNeuronType + '_' + postNeuronType + '_' + str(I_ext) + 'pA' + \
          '_CARLsim_vs_Keivan_error.png'
    plt.savefig(fileOutputName, dpi=800)
    plt.clf()

    # Append min, max, mean, and median of errors between V and I
    pctErrorV = abs((V_2 - v_2)/v_2)
    pctErrorI = abs((I_2 - I_syn_2)/I_syn_2)
    maxErrorV = max(pctErrorV[~np.isnan(pctErrorV)])
    maxErrorI = max(pctErrorI[~np.isnan(pctErrorI)])
    minErrorV = min(pctErrorV[~np.isnan(pctErrorV)])
    minErrorI = min(pctErrorI[~np.isnan(pctErrorI)])
    meanErrorV = np.mean(pctErrorV[~np.isnan(pctErrorV)])
    meanErrorI = np.mean(pctErrorI[~np.isnan(pctErrorI)])
    medianErrorV = np.median(pctErrorV[~np.isnan(pctErrorV)])
    medianErrorI = np.median(pctErrorI[~np.isnan(pctErrorI)])
    mismatchV = sum(abs(V_2-v_2)*dt)/sum(abs((V_2 + v_2)/2))
    mismatchI = sum(abs(I_2-I_syn_2)*dt)/sum(abs((I_2 + I_syn_2)/2))
# Out:
# [15, 40, 67, 97, 130, 166, 206, 249, 295, 343, 392, 442, 493, 544, 595, 646, 697, 748, 799, 850, 901, 952]
# t:15 I:0.000	g:3.644	u:0.260	x:0.740	v:6.796	synaptic spike
# t:15 I:24.765	g:3.644	u:0.260	x:0.740	v:6.796	current decay
# t:16 I:22.340	g:3.644	u:0.260	x:0.740	v:6.730	current decay
# t:17 I:20.182	g:3.644	u:0.260	x:0.740	v:6.675	current decay
# t:18 I:18.256	g:3.644	u:0.260	x:0.740	v:6.629	current decay
# t:19 I:16.533	g:3.644	u:0.260	x:0.740	v:6.591	current decay
# t:20 I:14.987	g:3.644	u:0.260	x:0.740	v:6.559	current decay
# t:21 I:13.598	g:3.644	u:0.260	x:0.740	v:6.534	current decay
# t:22 I:12.347	g:3.644	u:0.260	x:0.740	v:6.513	current decay
# t:23 I:11.219	g:3.644	u:0.260	x:0.740	v:6.497	current decay
# t:24 I:10.199	g:3.644	u:0.260	x:0.740	v:6.484	current decay
# t:25 I:9.277	g:3.644	u:0.260	x:0.740	v:6.475	current decay
# t:26 I:8.441	g:3.644	u:0.260	x:0.740	v:6.469	current decay
# t:27 I:7.684	g:3.644	u:0.260	x:0.740	v:6.464	current decay
# t:28 I:6.997	g:3.644	u:0.260	x:0.740	v:6.462	current decay
# t:29 I:6.372	g:3.644	u:0.260	x:0.740	v:6.462	current decay
# t:30 I:5.805	g:3.644	u:0.260	x:0.740	v:6.463	current decay
# t:31 I:5.289	g:3.644	u:0.260	x:0.740	v:6.465	current decay
# t:32 I:4.820	g:3.644	u:0.260	x:0.740	v:6.468	current decay
# t:33 I:4.393	g:3.644	u:0.260	x:0.740	v:6.471	current decay
# t:34 I:4.004	g:3.644	u:0.260	x:0.740	v:6.476	current decay
# t:35 I:3.650	g:3.644	u:0.260	x:0.740	v:6.480	current decay
# t:36 I:3.327	g:3.644	u:0.260	x:0.740	v:6.486	current decay
# t:37 I:3.033	g:3.644	u:0.260	x:0.740	v:6.491	current decay
# t:38 I:2.765	g:3.644	u:0.260	x:0.740	v:6.497	current decay
# t:39 I:2.521	g:3.644	u:0.260	x:0.740	v:6.503	current decay
# t:40 I:2.521	g:3.555	u:0.305	x:0.521	v:6.509	synaptic spike
# t:40 I:23.138	g:3.555	u:0.305	x:0.521	v:6.509	current decay
# t:41 I:20.916	g:3.555	u:0.305	x:0.521	v:6.459	current decay
# t:42 I:18.932	g:3.555	u:0.305	x:0.521	v:6.419	current decay
# t:43 I:17.156	g:3.555	u:0.305	x:0.521	v:6.386	current decay
# t:44 I:15.562	g:3.555	u:0.305	x:0.521	v:6.359	current decay
# t:45 I:14.128	g:3.555	u:0.305	x:0.521	v:6.338	current decay
# t:46 I:12.836	g:3.555	u:0.305	x:0.521	v:6.322	current decay
# t:47 I:11.669	g:3.555	u:0.305	x:0.521	v:6.310	current decay
# t:48 I:10.614	g:3.555	u:0.305	x:0.521	v:6.301	current decay
# t:49 I:9.659	g:3.555	u:0.305	x:0.521	v:6.295	current decay
# t:50 I:8.794	g:3.555	u:0.305	x:0.521	v:6.292	current decay
# t:51 I:8.009	g:3.555	u:0.305	x:0.521	v:6.291	current decay
# t:52 I:7.295	g:3.555	u:0.305	x:0.521	v:6.292	current decay
# t:53 I:6.647	g:3.555	u:0.305	x:0.521	v:6.294	current decay
# t:54 I:6.058	g:3.555	u:0.305	x:0.521	v:6.297	current decay
# t:55 I:5.522	g:3.555	u:0.305	x:0.521	v:6.301	current decay
# t:56 I:5.034	g:3.555	u:0.305	x:0.521	v:6.306	current decay
# t:57 I:4.589	g:3.555	u:0.305	x:0.521	v:6.312	current decay
# t:58 I:4.184	g:3.555	u:0.305	x:0.521	v:6.318	current decay
# t:59 I:3.815	g:3.555	u:0.305	x:0.521	v:6.324	current decay
# t:60 I:3.479	g:3.555	u:0.305	x:0.521	v:6.331	current decay
# t:61 I:3.172	g:3.555	u:0.305	x:0.521	v:6.338	current decay
# t:62 I:2.892	g:3.555	u:0.305	x:0.521	v:6.345	current decay
# t:63 I:2.637	g:3.555	u:0.305	x:0.521	v:6.352	current decay
# t:64 I:2.405	g:3.555	u:0.305	x:0.521	v:6.358	current decay
# t:65 I:2.193	g:3.555	u:0.305	x:0.521	v:6.365	current decay
# t:66 I:1.999	g:3.555	u:0.305	x:0.521	v:6.372	current decay
# t:67 I:1.999	g:2.626	u:0.307	x:0.377	v:6.378	synaptic spike
# t:67 I:16.750	g:2.626	u:0.307	x:0.377	v:6.378	current decay
# t:68 I:15.177	g:2.626	u:0.307	x:0.377	v:6.345	current decay
# t:69 I:13.765	g:2.626	u:0.307	x:0.377	v:6.317	current decay
# t:70 I:12.494	g:2.626	u:0.307	x:0.377	v:6.295	current decay
# t:71 I:11.348	g:2.626	u:0.307	x:0.377	v:6.277	current decay
# t:72 I:10.314	g:2.626	u:0.307	x:0.377	v:6.263	current decay
# t:73 I:9.379	g:2.626	u:0.307	x:0.377	v:6.253	current decay
# t:74 I:8.532	g:2.626	u:0.307	x:0.377	v:6.245	current decay
# t:75 I:7.765	g:2.626	u:0.307	x:0.377	v:6.239	current decay
# t:76 I:7.068	g:2.626	u:0.307	x:0.377	v:6.236	current decay
# t:77 I:6.437	g:2.626	u:0.307	x:0.377	v:6.234	current decay
# t:78 I:5.862	g:2.626	u:0.307	x:0.377	v:6.234	current decay
# t:79 I:5.341	g:2.626	u:0.307	x:0.377	v:6.234	current decay
# t:80 I:4.866	g:2.626	u:0.307	x:0.377	v:6.236	current decay
# t:81 I:4.434	g:2.626	u:0.307	x:0.377	v:6.239	current decay
# t:82 I:4.041	g:2.626	u:0.307	x:0.377	v:6.242	current decay
# t:83 I:3.683	g:2.626	u:0.307	x:0.377	v:6.246	current decay
# t:84 I:3.357	g:2.626	u:0.307	x:0.377	v:6.250	current decay
# t:85 I:3.060	g:2.626	u:0.307	x:0.377	v:6.254	current decay
# t:86 I:2.789	g:2.626	u:0.307	x:0.377	v:6.258	current decay
# t:87 I:2.542	g:2.626	u:0.307	x:0.377	v:6.263	current decay
# t:88 I:2.317	g:2.626	u:0.307	x:0.377	v:6.267	current decay
# t:89 I:2.112	g:2.626	u:0.307	x:0.377	v:6.272	current decay
# t:90 I:1.925	g:2.626	u:0.307	x:0.377	v:6.277	current decay
# t:91 I:1.755	g:2.626	u:0.307	x:0.377	v:6.281	current decay
# t:92 I:1.600	g:2.626	u:0.307	x:0.377	v:6.285	current decay
# t:93 I:1.458	g:2.626	u:0.307	x:0.377	v:6.290	current decay
# t:94 I:1.329	g:2.626	u:0.307	x:0.377	v:6.294	current decay
# t:95 I:1.211	g:2.626	u:0.307	x:0.377	v:6.297	current decay
# t:96 I:1.104	g:2.626	u:0.307	x:0.377	v:6.301	current decay
# t:97 I:1.104	g:1.900	u:0.300	x:0.290	v:6.304	synaptic spike
# t:97 I:11.980	g:1.900	u:0.300	x:0.290	v:6.304	current decay
# t:98 I:10.867	g:1.900	u:0.300	x:0.290	v:6.279	current decay
# t:99 I:9.865	g:1.900	u:0.300	x:0.290	v:6.257	current decay
# t:100 I:8.960	g:1.900	u:0.300	x:0.290	v:6.239	current decay
# t:101 I:8.142	g:1.900	u:0.300	x:0.290	v:6.225	current decay
# t:102 I:7.403	g:1.900	u:0.300	x:0.290	v:6.213	current decay
# t:103 I:6.733	g:1.900	u:0.300	x:0.290	v:6.204	current decay
# t:104 I:6.125	g:1.900	u:0.300	x:0.290	v:6.196	current decay
# t:105 I:5.574	g:1.900	u:0.300	x:0.290	v:6.191	current decay
# t:106 I:5.074	g:1.900	u:0.300	x:0.290	v:6.187	current decay
# t:107 I:4.620	g:1.900	u:0.300	x:0.290	v:6.184	current decay
# t:108 I:4.207	g:1.900	u:0.300	x:0.290	v:6.182	current decay
# t:109 I:3.831	g:1.900	u:0.300	x:0.290	v:6.181	current decay
# t:110 I:3.489	g:1.900	u:0.300	x:0.290	v:6.181	current decay
# t:111 I:3.179	g:1.900	u:0.300	x:0.290	v:6.181	current decay
# t:112 I:2.896	g:1.900	u:0.300	x:0.290	v:6.182	current decay
# t:113 I:2.638	g:1.900	u:0.300	x:0.290	v:6.183	current decay
# t:114 I:2.403	g:1.900	u:0.300	x:0.290	v:6.185	current decay
# t:115 I:2.190	g:1.900	u:0.300	x:0.290	v:6.186	current decay
# t:116 I:1.995	g:1.900	u:0.300	x:0.290	v:6.188	current decay
# t:117 I:1.818	g:1.900	u:0.300	x:0.290	v:6.190	current decay
# t:118 I:1.656	g:1.900	u:0.300	x:0.290	v:6.192	current decay
# t:119 I:1.509	g:1.900	u:0.300	x:0.290	v:6.194	current decay
# t:120 I:1.375	g:1.900	u:0.300	x:0.290	v:6.196	current decay
# t:121 I:1.253	g:1.900	u:0.300	x:0.290	v:6.198	current decay
# t:122 I:1.142	g:1.900	u:0.300	x:0.290	v:6.199	current decay
# t:123 I:1.040	g:1.900	u:0.300	x:0.290	v:6.201	current decay
# t:124 I:0.948	g:1.900	u:0.300	x:0.290	v:6.202	current decay
# t:125 I:0.863	g:1.900	u:0.300	x:0.290	v:6.204	current decay
# t:126 I:0.787	g:1.900	u:0.300	x:0.290	v:6.205	current decay
# t:127 I:0.717	g:1.900	u:0.300	x:0.290	v:6.206	current decay
# t:128 I:0.653	g:1.900	u:0.300	x:0.290	v:6.207	current decay
# t:129 I:0.595	g:1.900	u:0.300	x:0.290	v:6.208	current decay
# t:130 I:0.595	g:1.477	u:0.292	x:0.240	v:6.209	synaptic spike
# t:130 I:9.172	g:1.477	u:0.292	x:0.240	v:6.209	current decay
# t:131 I:8.324	g:1.477	u:0.292	x:0.240	v:6.186	current decay
# t:132 I:7.559	g:1.477	u:0.292	x:0.240	v:6.167	current decay
# t:133 I:6.867	g:1.477	u:0.292	x:0.240	v:6.151	current decay
# t:134 I:6.242	g:1.477	u:0.292	x:0.240	v:6.138	current decay
# t:135 I:5.675	g:1.477	u:0.292	x:0.240	v:6.127	current decay
# t:136 I:5.161	g:1.477	u:0.292	x:0.240	v:6.117	current decay
# t:137 I:4.695	g:1.477	u:0.292	x:0.240	v:6.110	current decay
# t:138 I:4.272	g:1.477	u:0.292	x:0.240	v:6.103	current decay
# t:139 I:3.888	g:1.477	u:0.292	x:0.240	v:6.098	current decay
# t:140 I:3.539	g:1.477	u:0.292	x:0.240	v:6.094	current decay
# t:141 I:3.222	g:1.477	u:0.292	x:0.240	v:6.091	current decay
# t:142 I:2.934	g:1.477	u:0.292	x:0.240	v:6.088	current decay
# t:143 I:2.671	g:1.477	u:0.292	x:0.240	v:6.086	current decay
# t:144 I:2.433	g:1.477	u:0.292	x:0.240	v:6.085	current decay
# t:145 I:2.215	g:1.477	u:0.292	x:0.240	v:6.084	current decay
# t:146 I:2.018	g:1.477	u:0.292	x:0.240	v:6.083	current decay
# t:147 I:1.838	g:1.477	u:0.292	x:0.240	v:6.083	current decay
# t:148 I:1.674	g:1.477	u:0.292	x:0.240	v:6.082	current decay
# t:149 I:1.524	g:1.477	u:0.292	x:0.240	v:6.082	current decay
# t:150 I:1.389	g:1.477	u:0.292	x:0.240	v:6.082	current decay
# t:151 I:1.265	g:1.477	u:0.292	x:0.240	v:6.082	current decay
# t:152 I:1.152	g:1.477	u:0.292	x:0.240	v:6.082	current decay
# t:153 I:1.049	g:1.477	u:0.292	x:0.240	v:6.081	current decay
# t:154 I:0.956	g:1.477	u:0.292	x:0.240	v:6.081	current decay
# t:155 I:0.871	g:1.477	u:0.292	x:0.240	v:6.081	current decay
# t:156 I:0.793	g:1.477	u:0.292	x:0.240	v:6.081	current decay
# t:157 I:0.722	g:1.477	u:0.292	x:0.240	v:6.080	current decay
# t:158 I:0.658	g:1.477	u:0.292	x:0.240	v:6.080	current decay
# t:159 I:0.599	g:1.477	u:0.292	x:0.240	v:6.079	current decay
# t:160 I:0.546	g:1.477	u:0.292	x:0.240	v:6.079	current decay
# t:161 I:0.497	g:1.477	u:0.292	x:0.240	v:6.078	current decay
# t:162 I:0.453	g:1.477	u:0.292	x:0.240	v:6.077	current decay
# t:163 I:0.412	g:1.477	u:0.292	x:0.240	v:6.076	current decay
# t:164 I:0.375	g:1.477	u:0.292	x:0.240	v:6.075	current decay
# t:165 I:0.342	g:1.477	u:0.292	x:0.240	v:6.074	current decay
# t:166 I:0.342	g:1.248	u:0.287	x:0.212	v:6.072	synaptic spike
# t:166 I:7.577	g:1.248	u:0.287	x:0.212	v:6.072	current decay
# t:167 I:6.878	g:1.248	u:0.287	x:0.212	v:6.051	current decay
# t:168 I:6.246	g:1.248	u:0.287	x:0.212	v:6.034	current decay
# t:169 I:5.675	g:1.248	u:0.287	x:0.212	v:6.018	current decay
# t:170 I:5.158	g:1.248	u:0.287	x:0.212	v:6.005	current decay
# t:171 I:4.689	g:1.248	u:0.287	x:0.212	v:5.994	current decay
# t:172 I:4.264	g:1.248	u:0.287	x:0.212	v:5.984	current decay
# t:173 I:3.879	g:1.248	u:0.287	x:0.212	v:5.976	current decay
# t:174 I:3.529	g:1.248	u:0.287	x:0.212	v:5.969	current decay
# t:175 I:3.211	g:1.248	u:0.287	x:0.212	v:5.963	current decay
# t:176 I:2.922	g:1.248	u:0.287	x:0.212	v:5.958	current decay
# t:177 I:2.660	g:1.248	u:0.287	x:0.212	v:5.953	current decay
# t:178 I:2.421	g:1.248	u:0.287	x:0.212	v:5.949	current decay
# t:179 I:2.204	g:1.248	u:0.287	x:0.212	v:5.946	current decay
# t:180 I:2.007	g:1.248	u:0.287	x:0.212	v:5.943	current decay
# t:181 I:1.827	g:1.248	u:0.287	x:0.212	v:5.941	current decay
# t:182 I:1.664	g:1.248	u:0.287	x:0.212	v:5.938	current decay
# t:183 I:1.515	g:1.248	u:0.287	x:0.212	v:5.936	current decay
# t:184 I:1.379	g:1.248	u:0.287	x:0.212	v:5.934	current decay
# t:185 I:1.256	g:1.248	u:0.287	x:0.212	v:5.933	current decay
# t:186 I:1.144	g:1.248	u:0.287	x:0.212	v:5.931	current decay
# t:187 I:1.041	g:1.248	u:0.287	x:0.212	v:5.929	current decay
# t:188 I:0.948	g:1.248	u:0.287	x:0.212	v:5.927	current decay
# t:189 I:0.864	g:1.248	u:0.287	x:0.212	v:5.926	current decay
# t:190 I:0.786	g:1.248	u:0.287	x:0.212	v:5.924	current decay
# t:191 I:0.716	g:1.248	u:0.287	x:0.212	v:5.922	current decay
# t:192 I:0.652	g:1.248	u:0.287	x:0.212	v:5.921	current decay
# t:193 I:0.594	g:1.248	u:0.287	x:0.212	v:5.919	current decay
# t:194 I:0.541	g:1.248	u:0.287	x:0.212	v:5.917	current decay
# t:195 I:0.492	g:1.248	u:0.287	x:0.212	v:5.915	current decay
# t:196 I:0.448	g:1.248	u:0.287	x:0.212	v:5.913	current decay
# t:197 I:0.408	g:1.248	u:0.287	x:0.212	v:5.910	current decay
# t:198 I:0.372	g:1.248	u:0.287	x:0.212	v:5.908	current decay
# t:199 I:0.338	g:1.248	u:0.287	x:0.212	v:5.906	current decay
# t:200 I:0.308	g:1.248	u:0.287	x:0.212	v:5.903	current decay
# t:201 I:0.280	g:1.248	u:0.287	x:0.212	v:5.900	current decay
# t:202 I:0.255	g:1.248	u:0.287	x:0.212	v:5.898	current decay
# t:203 I:0.232	g:1.248	u:0.287	x:0.212	v:5.895	current decay
# t:204 I:0.212	g:1.248	u:0.287	x:0.212	v:5.892	current decay
# t:205 I:0.193	g:1.248	u:0.287	x:0.212	v:5.889	current decay
# t:206 I:0.193	g:1.130	u:0.281	x:0.201	v:5.886	synaptic spike
# t:206 I:6.648	g:1.130	u:0.281	x:0.201	v:5.886	current decay
# t:207 I:6.035	g:1.130	u:0.281	x:0.201	v:5.865	current decay
# t:208 I:5.480	g:1.130	u:0.281	x:0.201	v:5.848	current decay
# t:209 I:4.979	g:1.130	u:0.281	x:0.201	v:5.832	current decay
# t:210 I:4.524	g:1.130	u:0.281	x:0.201	v:5.819	current decay
# t:211 I:4.113	g:1.130	u:0.281	x:0.201	v:5.807	current decay
# t:212 I:3.739	g:1.130	u:0.281	x:0.201	v:5.796	current decay
# t:213 I:3.401	g:1.130	u:0.281	x:0.201	v:5.787	current decay
# t:214 I:3.093	g:1.130	u:0.281	x:0.201	v:5.779	current decay
# t:215 I:2.814	g:1.130	u:0.281	x:0.201	v:5.772	current decay
# t:216 I:2.560	g:1.130	u:0.281	x:0.201	v:5.766	current decay
# t:217 I:2.330	g:1.130	u:0.281	x:0.201	v:5.760	current decay
# t:218 I:2.120	g:1.130	u:0.281	x:0.201	v:5.755	current decay
# t:219 I:1.930	g:1.130	u:0.281	x:0.201	v:5.750	current decay
# t:220 I:1.756	g:1.130	u:0.281	x:0.201	v:5.746	current decay
# t:221 I:1.599	g:1.130	u:0.281	x:0.201	v:5.742	current decay
# t:222 I:1.455	g:1.130	u:0.281	x:0.201	v:5.738	current decay
# t:223 I:1.325	g:1.130	u:0.281	x:0.201	v:5.735	current decay
# t:224 I:1.206	g:1.130	u:0.281	x:0.201	v:5.732	current decay
# t:225 I:1.098	g:1.130	u:0.281	x:0.201	v:5.728	current decay
# t:226 I:0.999	g:1.130	u:0.281	x:0.201	v:5.725	current decay
# t:227 I:0.910	g:1.130	u:0.281	x:0.201	v:5.722	current decay
# t:228 I:0.828	g:1.130	u:0.281	x:0.201	v:5.719	current decay
# t:229 I:0.754	g:1.130	u:0.281	x:0.201	v:5.716	current decay
# t:230 I:0.686	g:1.130	u:0.281	x:0.201	v:5.712	current decay
# t:231 I:0.625	g:1.130	u:0.281	x:0.201	v:5.709	current decay
# t:232 I:0.569	g:1.130	u:0.281	x:0.201	v:5.706	current decay
# t:233 I:0.518	g:1.130	u:0.281	x:0.201	v:5.703	current decay
# t:234 I:0.471	g:1.130	u:0.281	x:0.201	v:5.699	current decay
# t:235 I:0.429	g:1.130	u:0.281	x:0.201	v:5.696	current decay
# t:236 I:0.391	g:1.130	u:0.281	x:0.201	v:5.692	current decay
# t:237 I:0.356	g:1.130	u:0.281	x:0.201	v:5.689	current decay
# t:238 I:0.324	g:1.130	u:0.281	x:0.201	v:5.685	current decay
# t:239 I:0.295	g:1.130	u:0.281	x:0.201	v:5.681	current decay
# t:240 I:0.268	g:1.130	u:0.281	x:0.201	v:5.677	current decay
# t:241 I:0.244	g:1.130	u:0.281	x:0.201	v:5.673	current decay
# t:242 I:0.222	g:1.130	u:0.281	x:0.201	v:5.669	current decay
# t:243 I:0.202	g:1.130	u:0.281	x:0.201	v:5.665	current decay
# t:244 I:0.184	g:1.130	u:0.281	x:0.201	v:5.661	current decay
# t:245 I:0.168	g:1.130	u:0.281	x:0.201	v:5.656	current decay
# t:246 I:0.152	g:1.130	u:0.281	x:0.201	v:5.652	current decay
# t:247 I:0.139	g:1.130	u:0.281	x:0.201	v:5.647	current decay
# t:248 I:0.126	g:1.130	u:0.281	x:0.201	v:5.643	current decay
# t:249 I:0.126	g:1.086	u:0.277	x:0.198	v:5.638	synaptic spike
# t:249 I:6.121	g:1.086	u:0.277	x:0.198	v:5.638	current decay
# t:250 I:5.555	g:1.086	u:0.277	x:0.198	v:5.617	current decay
# t:251 I:5.043	g:1.086	u:0.277	x:0.198	v:5.599	current decay
# t:252 I:4.580	g:1.086	u:0.277	x:0.198	v:5.583	current decay
# t:253 I:4.161	g:1.086	u:0.277	x:0.198	v:5.568	current decay
# t:254 I:3.782	g:1.086	u:0.277	x:0.198	v:5.556	current decay
# t:255 I:3.438	g:1.086	u:0.277	x:0.198	v:5.544	current decay
# t:256 I:3.125	g:1.086	u:0.277	x:0.198	v:5.534	current decay
# t:257 I:2.842	g:1.086	u:0.277	x:0.198	v:5.525	current decay
# t:258 I:2.585	g:1.086	u:0.277	x:0.198	v:5.517	current decay
# t:259 I:2.351	g:1.086	u:0.277	x:0.198	v:5.509	current decay
# t:260 I:2.139	g:1.086	u:0.277	x:0.198	v:5.502	current decay
# t:261 I:1.946	g:1.086	u:0.277	x:0.198	v:5.496	current decay
# t:262 I:1.771	g:1.086	u:0.277	x:0.198	v:5.490	current decay
# t:263 I:1.611	g:1.086	u:0.277	x:0.198	v:5.484	current decay
# t:264 I:1.466	g:1.086	u:0.277	x:0.198	v:5.479	current decay
# t:265 I:1.334	g:1.086	u:0.277	x:0.198	v:5.474	current decay
# t:266 I:1.214	g:1.086	u:0.277	x:0.198	v:5.469	current decay
# t:267 I:1.105	g:1.086	u:0.277	x:0.198	v:5.464	current decay
# t:268 I:1.006	g:1.086	u:0.277	x:0.198	v:5.459	current decay
# t:269 I:0.915	g:1.086	u:0.277	x:0.198	v:5.454	current decay
# t:270 I:0.833	g:1.086	u:0.277	x:0.198	v:5.450	current decay
# t:271 I:0.758	g:1.086	u:0.277	x:0.198	v:5.445	current decay
# t:272 I:0.690	g:1.086	u:0.277	x:0.198	v:5.440	current decay
# t:273 I:0.628	g:1.086	u:0.277	x:0.198	v:5.436	current decay
# t:274 I:0.571	g:1.086	u:0.277	x:0.198	v:5.431	current decay
# t:275 I:0.520	g:1.086	u:0.277	x:0.198	v:5.426	current decay
# t:276 I:0.473	g:1.086	u:0.277	x:0.198	v:5.421	current decay
# t:277 I:0.431	g:1.086	u:0.277	x:0.198	v:5.417	current decay
# t:278 I:0.392	g:1.086	u:0.277	x:0.198	v:5.412	current decay
# t:279 I:0.357	g:1.086	u:0.277	x:0.198	v:5.407	current decay
# t:280 I:0.325	g:1.086	u:0.277	x:0.198	v:5.401	current decay
# t:281 I:0.295	g:1.086	u:0.277	x:0.198	v:5.396	current decay
# t:282 I:0.269	g:1.086	u:0.277	x:0.198	v:5.391	current decay
# t:283 I:0.245	g:1.086	u:0.277	x:0.198	v:5.385	current decay
# t:284 I:0.223	g:1.086	u:0.277	x:0.198	v:5.380	current decay
# t:285 I:0.202	g:1.086	u:0.277	x:0.198	v:5.374	current decay
# t:286 I:0.184	g:1.086	u:0.277	x:0.198	v:5.369	current decay
# t:287 I:0.168	g:1.086	u:0.277	x:0.198	v:5.363	current decay
# t:288 I:0.153	g:1.086	u:0.277	x:0.198	v:5.357	current decay
# t:289 I:0.139	g:1.086	u:0.277	x:0.198	v:5.351	current decay
# t:290 I:0.126	g:1.086	u:0.277	x:0.198	v:5.345	current decay
# t:291 I:0.115	g:1.086	u:0.277	x:0.198	v:5.339	current decay
# t:292 I:0.105	g:1.086	u:0.277	x:0.198	v:5.333	current decay
# t:293 I:0.095	g:1.086	u:0.277	x:0.198	v:5.326	current decay
# t:294 I:0.087	g:1.086	u:0.277	x:0.198	v:5.320	current decay
# t:295 I:0.087	g:1.079	u:0.274	x:0.201	v:5.314	synaptic spike
# t:295 I:5.733	g:1.079	u:0.274	x:0.201	v:5.314	current decay
# t:296 I:5.200	g:1.079	u:0.274	x:0.201	v:5.292	current decay
# t:297 I:4.720	g:1.079	u:0.274	x:0.201	v:5.273	current decay
# t:298 I:4.285	g:1.079	u:0.274	x:0.201	v:5.256	current decay
# t:299 I:3.892	g:1.079	u:0.274	x:0.201	v:5.241	current decay
# t:300 I:3.535	g:1.079	u:0.274	x:0.201	v:5.227	current decay
# t:301 I:3.213	g:1.079	u:0.274	x:0.201	v:5.214	current decay
# t:302 I:2.920	g:1.079	u:0.274	x:0.201	v:5.203	current decay
# t:303 I:2.654	g:1.079	u:0.274	x:0.201	v:5.192	current decay
# t:304 I:2.413	g:1.079	u:0.274	x:0.201	v:5.182	current decay
# t:305 I:2.194	g:1.079	u:0.274	x:0.201	v:5.173	current decay
# t:306 I:1.995	g:1.079	u:0.274	x:0.201	v:5.165	current decay
# t:307 I:1.815	g:1.079	u:0.274	x:0.201	v:5.157	current decay
# t:308 I:1.650	g:1.079	u:0.274	x:0.201	v:5.149	current decay
# t:309 I:1.501	g:1.079	u:0.274	x:0.201	v:5.142	current decay
# t:310 I:1.366	g:1.079	u:0.274	x:0.201	v:5.135	current decay
# t:311 I:1.242	g:1.079	u:0.274	x:0.201	v:5.128	current decay
# t:312 I:1.130	g:1.079	u:0.274	x:0.201	v:5.122	current decay
# t:313 I:1.028	g:1.079	u:0.274	x:0.201	v:5.115	current decay
# t:314 I:0.935	g:1.079	u:0.274	x:0.201	v:5.109	current decay
# t:315 I:0.851	g:1.079	u:0.274	x:0.201	v:5.103	current decay
# t:316 I:0.774	g:1.079	u:0.274	x:0.201	v:5.096	current decay
# t:317 I:0.704	g:1.079	u:0.274	x:0.201	v:5.090	current decay
# t:318 I:0.641	g:1.079	u:0.274	x:0.201	v:5.084	current decay
# t:319 I:0.583	g:1.079	u:0.274	x:0.201	v:5.077	current decay
# t:320 I:0.530	g:1.079	u:0.274	x:0.201	v:5.071	current decay
# t:321 I:0.482	g:1.079	u:0.274	x:0.201	v:5.064	current decay
# t:322 I:0.439	g:1.079	u:0.274	x:0.201	v:5.058	current decay
# t:323 I:0.399	g:1.079	u:0.274	x:0.201	v:5.051	current decay
# t:324 I:0.363	g:1.079	u:0.274	x:0.201	v:5.045	current decay
# t:325 I:0.330	g:1.079	u:0.274	x:0.201	v:5.038	current decay
# t:326 I:0.300	g:1.079	u:0.274	x:0.201	v:5.031	current decay
# t:327 I:0.273	g:1.079	u:0.274	x:0.201	v:5.024	current decay
# t:328 I:0.249	g:1.079	u:0.274	x:0.201	v:5.017	current decay
# t:329 I:0.226	g:1.079	u:0.274	x:0.201	v:5.010	current decay
# t:330 I:0.206	g:1.079	u:0.274	x:0.201	v:5.003	current decay
# t:331 I:0.187	g:1.079	u:0.274	x:0.201	v:4.995	current decay
# t:332 I:0.170	g:1.079	u:0.274	x:0.201	v:4.988	current decay
# t:333 I:0.155	g:1.079	u:0.274	x:0.201	v:4.980	current decay
# t:334 I:0.141	g:1.079	u:0.274	x:0.201	v:4.973	current decay
# t:335 I:0.128	g:1.079	u:0.274	x:0.201	v:4.965	current decay
# t:336 I:0.116	g:1.079	u:0.274	x:0.201	v:4.957	current decay
# t:337 I:0.106	g:1.079	u:0.274	x:0.201	v:4.950	current decay
# t:338 I:0.096	g:1.079	u:0.274	x:0.201	v:4.942	current decay
# t:339 I:0.088	g:1.079	u:0.274	x:0.201	v:4.934	current decay
# t:340 I:0.080	g:1.079	u:0.274	x:0.201	v:4.926	current decay
# t:341 I:0.072	g:1.079	u:0.274	x:0.201	v:4.917	current decay
# t:342 I:0.066	g:1.079	u:0.274	x:0.201	v:4.909	current decay
# t:343 I:0.066	g:1.092	u:0.272	x:0.206	v:4.901	synaptic spike
# t:343 I:5.349	g:1.092	u:0.272	x:0.206	v:4.901	current decay
# t:344 I:4.850	g:1.092	u:0.272	x:0.206	v:4.878	current decay
# t:345 I:4.400	g:1.092	u:0.272	x:0.206	v:4.858	current decay
# t:346 I:3.993	g:1.092	u:0.272	x:0.206	v:4.840	current decay
# t:347 I:3.624	g:1.092	u:0.272	x:0.206	v:4.823	current decay
# t:348 I:3.291	g:1.092	u:0.272	x:0.206	v:4.808	current decay
# t:349 I:2.989	g:1.092	u:0.272	x:0.206	v:4.794	current decay
# t:350 I:2.715	g:1.092	u:0.272	x:0.206	v:4.781	current decay
# t:351 I:2.467	g:1.092	u:0.272	x:0.206	v:4.769	current decay
# t:352 I:2.242	g:1.092	u:0.272	x:0.206	v:4.758	current decay
# t:353 I:2.037	g:1.092	u:0.272	x:0.206	v:4.747	current decay
# t:354 I:1.852	g:1.092	u:0.272	x:0.206	v:4.737	current decay
# t:355 I:1.683	g:1.092	u:0.272	x:0.206	v:4.727	current decay
# t:356 I:1.530	g:1.092	u:0.272	x:0.206	v:4.718	current decay
# t:357 I:1.391	g:1.092	u:0.272	x:0.206	v:4.709	current decay
# t:358 I:1.265	g:1.092	u:0.272	x:0.206	v:4.700	current decay
# t:359 I:1.150	g:1.092	u:0.272	x:0.206	v:4.692	current decay
# t:360 I:1.045	g:1.092	u:0.272	x:0.206	v:4.683	current decay
# t:361 I:0.951	g:1.092	u:0.272	x:0.206	v:4.675	current decay
# t:362 I:0.864	g:1.092	u:0.272	x:0.206	v:4.667	current decay
# t:363 I:0.786	g:1.092	u:0.272	x:0.206	v:4.658	current decay
# t:364 I:0.715	g:1.092	u:0.272	x:0.206	v:4.650	current decay
# t:365 I:0.650	g:1.092	u:0.272	x:0.206	v:4.642	current decay
# t:366 I:0.591	g:1.092	u:0.272	x:0.206	v:4.634	current decay
# t:367 I:0.537	g:1.092	u:0.272	x:0.206	v:4.625	current decay
# t:368 I:0.488	g:1.092	u:0.272	x:0.206	v:4.617	current decay
# t:369 I:0.444	g:1.092	u:0.272	x:0.206	v:4.609	current decay
# t:370 I:0.404	g:1.092	u:0.272	x:0.206	v:4.600	current decay
# t:371 I:0.367	g:1.092	u:0.272	x:0.206	v:4.592	current decay
# t:372 I:0.334	g:1.092	u:0.272	x:0.206	v:4.583	current decay
# t:373 I:0.303	g:1.092	u:0.272	x:0.206	v:4.574	current decay
# t:374 I:0.276	g:1.092	u:0.272	x:0.206	v:4.566	current decay
# t:375 I:0.251	g:1.092	u:0.272	x:0.206	v:4.557	current decay
# t:376 I:0.228	g:1.092	u:0.272	x:0.206	v:4.548	current decay
# t:377 I:0.207	g:1.092	u:0.272	x:0.206	v:4.539	current decay
# t:378 I:0.188	g:1.092	u:0.272	x:0.206	v:4.529	current decay
# t:379 I:0.171	g:1.092	u:0.272	x:0.206	v:4.520	current decay
# t:380 I:0.156	g:1.092	u:0.272	x:0.206	v:4.511	current decay
# t:381 I:0.141	g:1.092	u:0.272	x:0.206	v:4.501	current decay
# t:382 I:0.129	g:1.092	u:0.272	x:0.206	v:4.492	current decay
# t:383 I:0.117	g:1.092	u:0.272	x:0.206	v:4.482	current decay
# t:384 I:0.106	g:1.092	u:0.272	x:0.206	v:4.473	current decay
# t:385 I:0.097	g:1.092	u:0.272	x:0.206	v:4.463	current decay
# t:386 I:0.088	g:1.092	u:0.272	x:0.206	v:4.453	current decay
# t:387 I:0.080	g:1.092	u:0.272	x:0.206	v:4.443	current decay
# t:388 I:0.072	g:1.092	u:0.272	x:0.206	v:4.433	current decay
# t:389 I:0.066	g:1.092	u:0.272	x:0.206	v:4.423	current decay
# t:390 I:0.060	g:1.092	u:0.272	x:0.206	v:4.412	current decay
# t:391 I:0.054	g:1.092	u:0.272	x:0.206	v:4.402	current decay
# t:392 I:0.054	g:1.109	u:0.272	x:0.210	v:4.392	synaptic spike
# t:392 I:4.873	g:1.109	u:0.272	x:0.210	v:4.392	current decay
# t:393 I:4.415	g:1.109	u:0.272	x:0.210	v:4.369	current decay
# t:394 I:4.002	g:1.109	u:0.272	x:0.210	v:4.348	current decay
# t:395 I:3.629	g:1.109	u:0.272	x:0.210	v:4.328	current decay
# t:396 I:3.292	g:1.109	u:0.272	x:0.210	v:4.310	current decay
# t:397 I:2.987	g:1.109	u:0.272	x:0.210	v:4.294	current decay
# t:398 I:2.711	g:1.109	u:0.272	x:0.210	v:4.278	current decay
# t:399 I:2.461	g:1.109	u:0.272	x:0.210	v:4.264	current decay
# t:400 I:2.234	g:1.109	u:0.272	x:0.210	v:4.250	current decay
# t:401 I:2.029	g:1.109	u:0.272	x:0.210	v:4.237	current decay
# t:402 I:1.843	g:1.109	u:0.272	x:0.210	v:4.225	current decay
# t:403 I:1.674	g:1.109	u:0.272	x:0.210	v:4.213	current decay
# t:404 I:1.520	g:1.109	u:0.272	x:0.210	v:4.201	current decay
# t:405 I:1.381	g:1.109	u:0.272	x:0.210	v:4.190	current decay
# t:406 I:1.255	g:1.109	u:0.272	x:0.210	v:4.179	current decay
# t:407 I:1.140	g:1.109	u:0.272	x:0.210	v:4.168	current decay
# t:408 I:1.036	g:1.109	u:0.272	x:0.210	v:4.158	current decay
# t:409 I:0.941	g:1.109	u:0.272	x:0.210	v:4.147	current decay
# t:410 I:0.855	g:1.109	u:0.272	x:0.210	v:4.137	current decay
# t:411 I:0.777	g:1.109	u:0.272	x:0.210	v:4.126	current decay
# t:412 I:0.706	g:1.109	u:0.272	x:0.210	v:4.116	current decay
# t:413 I:0.641	g:1.109	u:0.272	x:0.210	v:4.106	current decay
# t:414 I:0.583	g:1.109	u:0.272	x:0.210	v:4.095	current decay
# t:415 I:0.529	g:1.109	u:0.272	x:0.210	v:4.085	current decay
# t:416 I:0.481	g:1.109	u:0.272	x:0.210	v:4.075	current decay
# t:417 I:0.437	g:1.109	u:0.272	x:0.210	v:4.064	current decay
# t:418 I:0.397	g:1.109	u:0.272	x:0.210	v:4.054	current decay
# t:419 I:0.361	g:1.109	u:0.272	x:0.210	v:4.043	current decay
# t:420 I:0.328	g:1.109	u:0.272	x:0.210	v:4.032	current decay
# t:421 I:0.298	g:1.109	u:0.272	x:0.210	v:4.022	current decay
# t:422 I:0.270	g:1.109	u:0.272	x:0.210	v:4.011	current decay
# t:423 I:0.246	g:1.109	u:0.272	x:0.210	v:4.000	current decay
# t:424 I:0.223	g:1.109	u:0.272	x:0.210	v:3.989	current decay
# t:425 I:0.203	g:1.109	u:0.272	x:0.210	v:3.978	current decay
# t:426 I:0.184	g:1.109	u:0.272	x:0.210	v:3.966	current decay
# t:427 I:0.167	g:1.109	u:0.272	x:0.210	v:3.955	current decay
# t:428 I:0.152	g:1.109	u:0.272	x:0.210	v:3.944	current decay
# t:429 I:0.138	g:1.109	u:0.272	x:0.210	v:3.932	current decay
# t:430 I:0.125	g:1.109	u:0.272	x:0.210	v:3.921	current decay
# t:431 I:0.114	g:1.109	u:0.272	x:0.210	v:3.909	current decay
# t:432 I:0.103	g:1.109	u:0.272	x:0.210	v:3.897	current decay
# t:433 I:0.094	g:1.109	u:0.272	x:0.210	v:3.885	current decay
# t:434 I:0.085	g:1.109	u:0.272	x:0.210	v:3.873	current decay
# t:435 I:0.077	g:1.109	u:0.272	x:0.210	v:3.861	current decay
# t:436 I:0.070	g:1.109	u:0.272	x:0.210	v:3.849	current decay
# t:437 I:0.064	g:1.109	u:0.272	x:0.210	v:3.837	current decay
# t:438 I:0.058	g:1.109	u:0.272	x:0.210	v:3.825	current decay
# t:439 I:0.053	g:1.109	u:0.272	x:0.210	v:3.813	current decay
# t:440 I:0.048	g:1.109	u:0.272	x:0.210	v:3.800	current decay
# t:441 I:0.043	g:1.109	u:0.272	x:0.210	v:3.788	current decay
# t:442 I:0.043	g:1.127	u:0.271	x:0.214	v:3.775	synaptic spike
# t:442 I:4.254	g:1.127	u:0.271	x:0.214	v:3.775	current decay
# t:443 I:3.851	g:1.127	u:0.271	x:0.214	v:3.751	current decay
# t:444 I:3.487	g:1.127	u:0.271	x:0.214	v:3.730	current decay
# t:445 I:3.159	g:1.127	u:0.271	x:0.214	v:3.709	current decay
# t:446 I:2.862	g:1.127	u:0.271	x:0.214	v:3.690	current decay
# t:447 I:2.595	g:1.127	u:0.271	x:0.214	v:3.672	current decay
# t:448 I:2.352	g:1.127	u:0.271	x:0.214	v:3.655	current decay
# t:449 I:2.133	g:1.127	u:0.271	x:0.214	v:3.639	current decay
# t:450 I:1.935	g:1.127	u:0.271	x:0.214	v:3.624	current decay
# t:451 I:1.755	g:1.127	u:0.271	x:0.214	v:3.609	current decay
# t:452 I:1.593	g:1.127	u:0.271	x:0.214	v:3.595	current decay
# t:453 I:1.445	g:1.127	u:0.271	x:0.214	v:3.581	current decay
# t:454 I:1.311	g:1.127	u:0.271	x:0.214	v:3.567	current decay
# t:455 I:1.190	g:1.127	u:0.271	x:0.214	v:3.554	current decay
# t:456 I:1.080	g:1.127	u:0.271	x:0.214	v:3.541	current decay
# t:457 I:0.980	g:1.127	u:0.271	x:0.214	v:3.528	current decay
# t:458 I:0.889	g:1.127	u:0.271	x:0.214	v:3.515	current decay
# t:459 I:0.807	g:1.127	u:0.271	x:0.214	v:3.503	current decay
# t:460 I:0.733	g:1.127	u:0.271	x:0.214	v:3.490	current decay
# t:461 I:0.665	g:1.127	u:0.271	x:0.214	v:3.478	current decay
# t:462 I:0.603	g:1.127	u:0.271	x:0.214	v:3.465	current decay
# t:463 I:0.548	g:1.127	u:0.271	x:0.214	v:3.452	current decay
# t:464 I:0.497	g:1.127	u:0.271	x:0.214	v:3.440	current decay
# t:465 I:0.451	g:1.127	u:0.271	x:0.214	v:3.427	current decay
# t:466 I:0.409	g:1.127	u:0.271	x:0.214	v:3.414	current decay
# t:467 I:0.371	g:1.127	u:0.271	x:0.214	v:3.402	current decay
# t:468 I:0.337	g:1.127	u:0.271	x:0.214	v:3.389	current decay
# t:469 I:0.306	g:1.127	u:0.271	x:0.214	v:3.376	current decay
# t:470 I:0.278	g:1.127	u:0.271	x:0.214	v:3.363	current decay
# t:471 I:0.252	g:1.127	u:0.271	x:0.214	v:3.350	current decay
# t:472 I:0.228	g:1.127	u:0.271	x:0.214	v:3.337	current decay
# t:473 I:0.207	g:1.127	u:0.271	x:0.214	v:3.324	current decay
# t:474 I:0.188	g:1.127	u:0.271	x:0.214	v:3.310	current decay
# t:475 I:0.171	g:1.127	u:0.271	x:0.214	v:3.297	current decay
# t:476 I:0.155	g:1.127	u:0.271	x:0.214	v:3.283	current decay
# t:477 I:0.140	g:1.127	u:0.271	x:0.214	v:3.270	current decay
# t:478 I:0.127	g:1.127	u:0.271	x:0.214	v:3.256	current decay
# t:479 I:0.115	g:1.127	u:0.271	x:0.214	v:3.242	current decay
# t:480 I:0.105	g:1.127	u:0.271	x:0.214	v:3.229	current decay
# t:481 I:0.095	g:1.127	u:0.271	x:0.214	v:3.215	current decay
# t:482 I:0.086	g:1.127	u:0.271	x:0.214	v:3.201	current decay
# t:483 I:0.078	g:1.127	u:0.271	x:0.214	v:3.187	current decay
# t:484 I:0.071	g:1.127	u:0.271	x:0.214	v:3.172	current decay
# t:485 I:0.064	g:1.127	u:0.271	x:0.214	v:3.158	current decay
# t:486 I:0.058	g:1.127	u:0.271	x:0.214	v:3.144	current decay
# t:487 I:0.053	g:1.127	u:0.271	x:0.214	v:3.129	current decay
# t:488 I:0.048	g:1.127	u:0.271	x:0.214	v:3.115	current decay
# t:489 I:0.043	g:1.127	u:0.271	x:0.214	v:3.100	current decay
# t:490 I:0.039	g:1.127	u:0.271	x:0.214	v:3.086	current decay
# t:491 I:0.036	g:1.127	u:0.271	x:0.214	v:3.071	current decay
# t:492 I:0.032	g:1.127	u:0.271	x:0.214	v:3.056	current decay
# t:493 I:0.032	g:1.144	u:0.270	x:0.218	v:3.042	synaptic spike
# t:493 I:3.479	g:1.144	u:0.270	x:0.218	v:3.042	current decay
# t:494 I:3.144	g:1.144	u:0.270	x:0.218	v:3.018	current decay
# t:495 I:2.842	g:1.144	u:0.270	x:0.218	v:2.995	current decay
# t:496 I:2.571	g:1.144	u:0.270	x:0.218	v:2.974	current decay
# t:497 I:2.326	g:1.144	u:0.270	x:0.218	v:2.954	current decay
# t:498 I:2.105	g:1.144	u:0.270	x:0.218	v:2.935	current decay
# t:499 I:1.905	g:1.144	u:0.270	x:0.218	v:2.917	current decay
# t:500 I:1.725	g:1.144	u:0.270	x:0.218	v:2.899	current decay
# t:501 I:1.562	g:1.144	u:0.270	x:0.218	v:2.882	current decay
# t:502 I:1.415	g:1.144	u:0.270	x:0.218	v:2.866	current decay
# t:503 I:1.281	g:1.144	u:0.270	x:0.218	v:2.849	current decay
# t:504 I:1.161	g:1.144	u:0.270	x:0.218	v:2.834	current decay
# t:505 I:1.051	g:1.144	u:0.270	x:0.218	v:2.818	current decay
# t:506 I:0.952	g:1.144	u:0.270	x:0.218	v:2.803	current decay
# t:507 I:0.863	g:1.144	u:0.270	x:0.218	v:2.787	current decay
# t:508 I:0.782	g:1.144	u:0.270	x:0.218	v:2.772	current decay
# t:509 I:0.708	g:1.144	u:0.270	x:0.218	v:2.757	current decay
# t:510 I:0.641	g:1.144	u:0.270	x:0.218	v:2.742	current decay
# t:511 I:0.581	g:1.144	u:0.270	x:0.218	v:2.728	current decay
# t:512 I:0.526	g:1.144	u:0.270	x:0.218	v:2.713	current decay
# t:513 I:0.477	g:1.144	u:0.270	x:0.218	v:2.698	current decay
# t:514 I:0.432	g:1.144	u:0.270	x:0.218	v:2.683	current decay
# t:515 I:0.391	g:1.144	u:0.270	x:0.218	v:2.668	current decay
# t:516 I:0.354	g:1.144	u:0.270	x:0.218	v:2.653	current decay
# t:517 I:0.321	g:1.144	u:0.270	x:0.218	v:2.638	current decay
# t:518 I:0.291	g:1.144	u:0.270	x:0.218	v:2.623	current decay
# t:519 I:0.263	g:1.144	u:0.270	x:0.218	v:2.608	current decay
# t:520 I:0.238	g:1.144	u:0.270	x:0.218	v:2.592	current decay
# t:521 I:0.216	g:1.144	u:0.270	x:0.218	v:2.577	current decay
# t:522 I:0.195	g:1.144	u:0.270	x:0.218	v:2.562	current decay
# t:523 I:0.177	g:1.144	u:0.270	x:0.218	v:2.546	current decay
# t:524 I:0.160	g:1.144	u:0.270	x:0.218	v:2.531	current decay
# t:525 I:0.145	g:1.144	u:0.270	x:0.218	v:2.515	current decay
# t:526 I:0.131	g:1.144	u:0.270	x:0.218	v:2.499	current decay
# t:527 I:0.119	g:1.144	u:0.270	x:0.218	v:2.484	current decay
# t:528 I:0.108	g:1.144	u:0.270	x:0.218	v:2.468	current decay
# t:529 I:0.097	g:1.144	u:0.270	x:0.218	v:2.452	current decay
# t:530 I:0.088	g:1.144	u:0.270	x:0.218	v:2.436	current decay
# t:531 I:0.080	g:1.144	u:0.270	x:0.218	v:2.420	current decay
# t:532 I:0.072	g:1.144	u:0.270	x:0.218	v:2.404	current decay
# t:533 I:0.065	g:1.144	u:0.270	x:0.218	v:2.387	current decay
# t:534 I:0.059	g:1.144	u:0.270	x:0.218	v:2.371	current decay
# t:535 I:0.053	g:1.144	u:0.270	x:0.218	v:2.355	current decay
# t:536 I:0.048	g:1.144	u:0.270	x:0.218	v:2.338	current decay
# t:537 I:0.044	g:1.144	u:0.270	x:0.218	v:2.322	current decay
# t:538 I:0.039	g:1.144	u:0.270	x:0.218	v:2.305	current decay
# t:539 I:0.036	g:1.144	u:0.270	x:0.218	v:2.289	current decay
# t:540 I:0.032	g:1.144	u:0.270	x:0.218	v:2.272	current decay
# t:541 I:0.029	g:1.144	u:0.270	x:0.218	v:2.255	current decay
# t:542 I:0.026	g:1.144	u:0.270	x:0.218	v:2.239	current decay
# t:543 I:0.024	g:1.144	u:0.270	x:0.218	v:2.222	current decay
# t:544 I:0.024	g:1.157	u:0.270	x:0.221	v:2.205	synaptic spike
# t:544 I:2.552	g:1.157	u:0.270	x:0.221	v:2.205	current decay
# t:545 I:2.300	g:1.157	u:0.270	x:0.221	v:2.181	current decay
# t:546 I:2.073	g:1.157	u:0.270	x:0.221	v:2.159	current decay
# t:547 I:1.869	g:1.157	u:0.270	x:0.221	v:2.137	current decay
# t:548 I:1.686	g:1.157	u:0.270	x:0.221	v:2.116	current decay
# t:549 I:1.521	g:1.157	u:0.270	x:0.221	v:2.096	current decay
# t:550 I:1.373	g:1.157	u:0.270	x:0.221	v:2.077	current decay
# t:551 I:1.239	g:1.157	u:0.270	x:0.221	v:2.058	current decay
# t:552 I:1.119	g:1.157	u:0.270	x:0.221	v:2.040	current decay
# t:553 I:1.010	g:1.157	u:0.270	x:0.221	v:2.021	current decay
# t:554 I:0.912	g:1.157	u:0.270	x:0.221	v:2.004	current decay
# t:555 I:0.823	g:1.157	u:0.270	x:0.221	v:1.986	current decay
# t:556 I:0.743	g:1.157	u:0.270	x:0.221	v:1.968	current decay
# t:557 I:0.671	g:1.157	u:0.270	x:0.221	v:1.951	current decay
# t:558 I:0.606	g:1.157	u:0.270	x:0.221	v:1.934	current decay
# t:559 I:0.547	g:1.157	u:0.270	x:0.221	v:1.917	current decay
# t:560 I:0.494	g:1.157	u:0.270	x:0.221	v:1.900	current decay
# t:561 I:0.446	g:1.157	u:0.270	x:0.221	v:1.882	current decay
# t:562 I:0.402	g:1.157	u:0.270	x:0.221	v:1.865	current decay
# t:563 I:0.363	g:1.157	u:0.270	x:0.221	v:1.848	current decay
# t:564 I:0.328	g:1.157	u:0.270	x:0.221	v:1.831	current decay
# t:565 I:0.296	g:1.157	u:0.270	x:0.221	v:1.814	current decay
# t:566 I:0.267	g:1.157	u:0.270	x:0.221	v:1.797	current decay
# t:567 I:0.241	g:1.157	u:0.270	x:0.221	v:1.780	current decay
# t:568 I:0.217	g:1.157	u:0.270	x:0.221	v:1.762	current decay
# t:569 I:0.196	g:1.157	u:0.270	x:0.221	v:1.745	current decay
# t:570 I:0.177	g:1.157	u:0.270	x:0.221	v:1.728	current decay
# t:571 I:0.159	g:1.157	u:0.270	x:0.221	v:1.710	current decay
# t:572 I:0.143	g:1.157	u:0.270	x:0.221	v:1.693	current decay
# t:573 I:0.129	g:1.157	u:0.270	x:0.221	v:1.675	current decay
# t:574 I:0.117	g:1.157	u:0.270	x:0.221	v:1.658	current decay
# t:575 I:0.105	g:1.157	u:0.270	x:0.221	v:1.640	current decay
# t:576 I:0.095	g:1.157	u:0.270	x:0.221	v:1.622	current decay
# t:577 I:0.085	g:1.157	u:0.270	x:0.221	v:1.604	current decay
# t:578 I:0.077	g:1.157	u:0.270	x:0.221	v:1.587	current decay
# t:579 I:0.069	g:1.157	u:0.270	x:0.221	v:1.569	current decay
# t:580 I:0.062	g:1.157	u:0.270	x:0.221	v:1.551	current decay
# t:581 I:0.056	g:1.157	u:0.270	x:0.221	v:1.533	current decay
# t:582 I:0.050	g:1.157	u:0.270	x:0.221	v:1.514	current decay
# t:583 I:0.045	g:1.157	u:0.270	x:0.221	v:1.496	current decay
# t:584 I:0.041	g:1.157	u:0.270	x:0.221	v:1.478	current decay
# t:585 I:0.037	g:1.157	u:0.270	x:0.221	v:1.460	current decay
# t:586 I:0.033	g:1.157	u:0.270	x:0.221	v:1.441	current decay
# t:587 I:0.030	g:1.157	u:0.270	x:0.221	v:1.423	current decay
# t:588 I:0.027	g:1.157	u:0.270	x:0.221	v:1.404	current decay
# t:589 I:0.024	g:1.157	u:0.270	x:0.221	v:1.386	current decay
# t:590 I:0.022	g:1.157	u:0.270	x:0.221	v:1.367	current decay
# t:591 I:0.019	g:1.157	u:0.270	x:0.221	v:1.349	current decay
# t:592 I:0.017	g:1.157	u:0.270	x:0.221	v:1.330	current decay
# t:593 I:0.016	g:1.157	u:0.270	x:0.221	v:1.311	current decay
# t:594 I:0.014	g:1.157	u:0.270	x:0.221	v:1.293	current decay
# t:595 I:0.014	g:1.166	u:0.270	x:0.223	v:1.274	synaptic spike
# t:595 I:1.486	g:1.166	u:0.270	x:0.223	v:1.274	current decay
# t:596 I:1.329	g:1.166	u:0.270	x:0.223	v:1.251	current decay
# t:597 I:1.189	g:1.166	u:0.270	x:0.223	v:1.229	current decay
# t:598 I:1.065	g:1.166	u:0.270	x:0.223	v:1.208	current decay
# t:599 I:0.953	g:1.166	u:0.270	x:0.223	v:1.187	current decay
# t:600 I:0.853	g:1.166	u:0.270	x:0.223	v:1.166	current decay
# t:601 I:0.763	g:1.166	u:0.270	x:0.223	v:1.146	current decay
# t:602 I:0.683	g:1.166	u:0.270	x:0.223	v:1.126	current decay
# t:603 I:0.611	g:1.166	u:0.270	x:0.223	v:1.106	current decay
# t:604 I:0.547	g:1.166	u:0.270	x:0.223	v:1.087	current decay
# t:605 I:0.489	g:1.166	u:0.270	x:0.223	v:1.067	current decay
# t:606 I:0.438	g:1.166	u:0.270	x:0.223	v:1.048	current decay
# t:607 I:0.391	g:1.166	u:0.270	x:0.223	v:1.029	current decay
# t:608 I:0.350	g:1.166	u:0.270	x:0.223	v:1.010	current decay
# t:609 I:0.313	g:1.166	u:0.270	x:0.223	v:0.991	current decay
# t:610 I:0.279	g:1.166	u:0.270	x:0.223	v:0.972	current decay
# t:611 I:0.250	g:1.166	u:0.270	x:0.223	v:0.953	current decay
# t:612 I:0.223	g:1.166	u:0.270	x:0.223	v:0.934	current decay
# t:613 I:0.199	g:1.166	u:0.270	x:0.223	v:0.915	current decay
# t:614 I:0.177	g:1.166	u:0.270	x:0.223	v:0.896	current decay
# t:615 I:0.158	g:1.166	u:0.270	x:0.223	v:0.877	current decay
# t:616 I:0.141	g:1.166	u:0.270	x:0.223	v:0.857	current decay
# t:617 I:0.125	g:1.166	u:0.270	x:0.223	v:0.838	current decay
# t:618 I:0.112	g:1.166	u:0.270	x:0.223	v:0.819	current decay
# t:619 I:0.099	g:1.166	u:0.270	x:0.223	v:0.800	current decay
# t:620 I:0.088	g:1.166	u:0.270	x:0.223	v:0.781	current decay
# t:621 I:0.078	g:1.166	u:0.270	x:0.223	v:0.761	current decay
# t:622 I:0.070	g:1.166	u:0.270	x:0.223	v:0.742	current decay
# t:623 I:0.062	g:1.166	u:0.270	x:0.223	v:0.722	current decay
# t:624 I:0.055	g:1.166	u:0.270	x:0.223	v:0.703	current decay
# t:625 I:0.048	g:1.166	u:0.270	x:0.223	v:0.683	current decay
# t:626 I:0.043	g:1.166	u:0.270	x:0.223	v:0.664	current decay
# t:627 I:0.038	g:1.166	u:0.270	x:0.223	v:0.644	current decay
# t:628 I:0.033	g:1.166	u:0.270	x:0.223	v:0.625	current decay
# t:629 I:0.030	g:1.166	u:0.270	x:0.223	v:0.605	current decay
# t:630 I:0.026	g:1.166	u:0.270	x:0.223	v:0.585	current decay
# t:631 I:0.023	g:1.166	u:0.270	x:0.223	v:0.565	current decay
# t:632 I:0.020	g:1.166	u:0.270	x:0.223	v:0.546	current decay
# t:633 I:0.018	g:1.166	u:0.270	x:0.223	v:0.526	current decay
# t:634 I:0.015	g:1.166	u:0.270	x:0.223	v:0.506	current decay
# t:635 I:0.014	g:1.166	u:0.270	x:0.223	v:0.486	current decay
# t:636 I:0.012	g:1.166	u:0.270	x:0.223	v:0.466	current decay
# t:637 I:0.010	g:1.166	u:0.270	x:0.223	v:0.446	current decay
# t:638 I:0.009	g:1.166	u:0.270	x:0.223	v:0.426	current decay
# t:639 I:0.008	g:1.166	u:0.270	x:0.223	v:0.406	current decay
# t:640 I:0.007	g:1.166	u:0.270	x:0.223	v:0.385	current decay
# t:641 I:0.006	g:1.166	u:0.270	x:0.223	v:0.365	current decay
# t:642 I:0.005	g:1.166	u:0.270	x:0.223	v:0.345	current decay
# t:643 I:0.004	g:1.166	u:0.270	x:0.223	v:0.325	current decay
# t:644 I:0.004	g:1.166	u:0.270	x:0.223	v:0.305	current decay
# t:645 I:0.003	g:1.166	u:0.270	x:0.223	v:0.284	current decay
# t:646 I:0.003	g:1.172	u:0.270	x:0.224	v:0.264	synaptic spike
# t:646 I:0.309	g:1.172	u:0.270	x:0.224	v:0.264	current decay
# t:647 I:0.259	g:1.172	u:0.270	x:0.224	v:0.243	current decay
# t:648 I:0.216	g:1.172	u:0.270	x:0.224	v:0.222	current decay
# t:649 I:0.178	g:1.172	u:0.270	x:0.224	v:0.201	current decay
# t:650 I:0.145	g:1.172	u:0.270	x:0.224	v:0.180	current decay
# t:651 I:0.117	g:1.172	u:0.270	x:0.224	v:0.159	current decay
# t:652 I:0.093	g:1.172	u:0.270	x:0.224	v:0.139	current decay
# t:653 I:0.072	g:1.172	u:0.270	x:0.224	v:0.118	current decay
# t:654 I:0.054	g:1.172	u:0.270	x:0.224	v:0.098	current decay
# t:655 I:0.039	g:1.172	u:0.270	x:0.224	v:0.077	current decay
# t:656 I:0.026	g:1.172	u:0.270	x:0.224	v:0.057	current decay
# t:657 I:0.015	g:1.172	u:0.270	x:0.224	v:0.036	current decay
# t:658 I:0.006	g:1.172	u:0.270	x:0.224	v:0.015	current decay
# t:659 I:-0.002	g:1.172	u:0.270	x:0.224	v:-0.005	current decay
# t:660 I:-0.008	g:1.172	u:0.270	x:0.224	v:-0.026	current decay
# t:661 I:-0.013	g:1.172	u:0.270	x:0.224	v:-0.046	current decay
# t:662 I:-0.018	g:1.172	u:0.270	x:0.224	v:-0.067	current decay
# t:663 I:-0.021	g:1.172	u:0.270	x:0.224	v:-0.088	current decay
# t:664 I:-0.024	g:1.172	u:0.270	x:0.224	v:-0.108	current decay
# t:665 I:-0.026	g:1.172	u:0.270	x:0.224	v:-0.129	current decay
# t:666 I:-0.027	g:1.172	u:0.270	x:0.224	v:-0.150	current decay
# t:667 I:-0.028	g:1.172	u:0.270	x:0.224	v:-0.170	current decay
# t:668 I:-0.029	g:1.172	u:0.270	x:0.224	v:-0.191	current decay
# t:669 I:-0.029	g:1.172	u:0.270	x:0.224	v:-0.212	current decay
# t:670 I:-0.029	g:1.172	u:0.270	x:0.224	v:-0.233	current decay
# t:671 I:-0.029	g:1.172	u:0.270	x:0.224	v:-0.254	current decay
# t:672 I:-0.028	g:1.172	u:0.270	x:0.224	v:-0.275	current decay
# t:673 I:-0.028	g:1.172	u:0.270	x:0.224	v:-0.296	current decay
# t:674 I:-0.027	g:1.172	u:0.270	x:0.224	v:-0.317	current decay
# t:675 I:-0.026	g:1.172	u:0.270	x:0.224	v:-0.338	current decay
# t:676 I:-0.026	g:1.172	u:0.270	x:0.224	v:-0.359	current decay
# t:677 I:-0.025	g:1.172	u:0.270	x:0.224	v:-0.380	current decay
# t:678 I:-0.024	g:1.172	u:0.270	x:0.224	v:-0.401	current decay
# t:679 I:-0.023	g:1.172	u:0.270	x:0.224	v:-0.422	current decay
# t:680 I:-0.022	g:1.172	u:0.270	x:0.224	v:-0.443	current decay
# t:681 I:-0.021	g:1.172	u:0.270	x:0.224	v:-0.464	current decay
# t:682 I:-0.020	g:1.172	u:0.270	x:0.224	v:-0.485	current decay
# t:683 I:-0.019	g:1.172	u:0.270	x:0.224	v:-0.507	current decay
# t:684 I:-0.018	g:1.172	u:0.270	x:0.224	v:-0.528	current decay
# t:685 I:-0.017	g:1.172	u:0.270	x:0.224	v:-0.549	current decay
# t:686 I:-0.016	g:1.172	u:0.270	x:0.224	v:-0.570	current decay
# t:687 I:-0.015	g:1.172	u:0.270	x:0.224	v:-0.592	current decay
# t:688 I:-0.014	g:1.172	u:0.270	x:0.224	v:-0.613	current decay
# t:689 I:-0.013	g:1.172	u:0.270	x:0.224	v:-0.634	current decay
# t:690 I:-0.013	g:1.172	u:0.270	x:0.224	v:-0.656	current decay
# t:691 I:-0.012	g:1.172	u:0.270	x:0.224	v:-0.677	current decay
# t:692 I:-0.011	g:1.172	u:0.270	x:0.224	v:-0.698	current decay
# t:693 I:-0.010	g:1.172	u:0.270	x:0.224	v:-0.720	current decay
# t:694 I:-0.010	g:1.172	u:0.270	x:0.224	v:-0.741	current decay
# t:695 I:-0.009	g:1.172	u:0.270	x:0.224	v:-0.762	current decay
# t:696 I:-0.009	g:1.172	u:0.270	x:0.224	v:-0.784	current decay
# t:697 I:-0.009	g:1.176	u:0.270	x:0.225	v:-0.805	synaptic spike
# t:697 I:-0.947	g:1.176	u:0.270	x:0.225	v:-0.805	current decay
# t:698 I:-0.883	g:1.176	u:0.270	x:0.225	v:-0.824	current decay
# t:699 I:-0.823	g:1.176	u:0.270	x:0.225	v:-0.844	current decay
# t:700 I:-0.767	g:1.176	u:0.270	x:0.225	v:-0.864	current decay
# t:701 I:-0.715	g:1.176	u:0.270	x:0.225	v:-0.884	current decay
# t:702 I:-0.667	g:1.176	u:0.270	x:0.225	v:-0.904	current decay
# t:703 I:-0.621	g:1.176	u:0.270	x:0.225	v:-0.925	current decay
# t:704 I:-0.578	g:1.176	u:0.270	x:0.225	v:-0.946	current decay
# t:705 I:-0.539	g:1.176	u:0.270	x:0.225	v:-0.967	current decay
# t:706 I:-0.501	g:1.176	u:0.270	x:0.225	v:-0.988	current decay
# t:707 I:-0.466	g:1.176	u:0.270	x:0.225	v:-1.009	current decay
# t:708 I:-0.434	g:1.176	u:0.270	x:0.225	v:-1.031	current decay
# t:709 I:-0.404	g:1.176	u:0.270	x:0.225	v:-1.052	current decay
# t:710 I:-0.375	g:1.176	u:0.270	x:0.225	v:-1.074	current decay
# t:711 I:-0.349	g:1.176	u:0.270	x:0.225	v:-1.095	current decay
# t:712 I:-0.324	g:1.176	u:0.270	x:0.225	v:-1.117	current decay
# t:713 I:-0.301	g:1.176	u:0.270	x:0.225	v:-1.139	current decay
# t:714 I:-0.279	g:1.176	u:0.270	x:0.225	v:-1.161	current decay
# t:715 I:-0.259	g:1.176	u:0.270	x:0.225	v:-1.183	current decay
# t:716 I:-0.240	g:1.176	u:0.270	x:0.225	v:-1.205	current decay
# t:717 I:-0.223	g:1.176	u:0.270	x:0.225	v:-1.227	current decay
# t:718 I:-0.207	g:1.176	u:0.270	x:0.225	v:-1.249	current decay
# t:719 I:-0.192	g:1.176	u:0.270	x:0.225	v:-1.271	current decay
# t:720 I:-0.178	g:1.176	u:0.270	x:0.225	v:-1.293	current decay
# t:721 I:-0.165	g:1.176	u:0.270	x:0.225	v:-1.315	current decay
# t:722 I:-0.152	g:1.176	u:0.270	x:0.225	v:-1.337	current decay
# t:723 I:-0.141	g:1.176	u:0.270	x:0.225	v:-1.359	current decay
# t:724 I:-0.131	g:1.176	u:0.270	x:0.225	v:-1.381	current decay
# t:725 I:-0.121	g:1.176	u:0.270	x:0.225	v:-1.403	current decay
# t:726 I:-0.112	g:1.176	u:0.270	x:0.225	v:-1.425	current decay
# t:727 I:-0.103	g:1.176	u:0.270	x:0.225	v:-1.448	current decay
# t:728 I:-0.096	g:1.176	u:0.270	x:0.225	v:-1.470	current decay
# t:729 I:-0.088	g:1.176	u:0.270	x:0.225	v:-1.492	current decay
# t:730 I:-0.082	g:1.176	u:0.270	x:0.225	v:-1.514	current decay
# t:731 I:-0.076	g:1.176	u:0.270	x:0.225	v:-1.536	current decay
# t:732 I:-0.070	g:1.176	u:0.270	x:0.225	v:-1.558	current decay
# t:733 I:-0.064	g:1.176	u:0.270	x:0.225	v:-1.580	current decay
# t:734 I:-0.060	g:1.176	u:0.270	x:0.225	v:-1.602	current decay
# t:735 I:-0.055	g:1.176	u:0.270	x:0.225	v:-1.624	current decay
# t:736 I:-0.051	g:1.176	u:0.270	x:0.225	v:-1.647	current decay
# t:737 I:-0.047	g:1.176	u:0.270	x:0.225	v:-1.669	current decay
# t:738 I:-0.043	g:1.176	u:0.270	x:0.225	v:-1.691	current decay
# t:739 I:-0.040	g:1.176	u:0.270	x:0.225	v:-1.713	current decay
# t:740 I:-0.037	g:1.176	u:0.270	x:0.225	v:-1.735	current decay
# t:741 I:-0.034	g:1.176	u:0.270	x:0.225	v:-1.757	current decay
# t:742 I:-0.031	g:1.176	u:0.270	x:0.225	v:-1.779	current decay
# t:743 I:-0.029	g:1.176	u:0.270	x:0.225	v:-1.801	current decay
# t:744 I:-0.027	g:1.176	u:0.270	x:0.225	v:-1.823	current decay
# t:745 I:-0.025	g:1.176	u:0.270	x:0.225	v:-1.846	current decay
# t:746 I:-0.023	g:1.176	u:0.270	x:0.225	v:-1.868	current decay
# t:747 I:-0.021	g:1.176	u:0.270	x:0.225	v:-1.890	current decay
# t:748 I:-0.021	g:1.178	u:0.270	x:0.225	v:-1.912	synaptic spike
# t:748 I:-2.253	g:1.178	u:0.270	x:0.225	v:-1.912	current decay
# t:749 I:-2.070	g:1.178	u:0.270	x:0.225	v:-1.928	current decay
# t:750 I:-1.902	g:1.178	u:0.270	x:0.225	v:-1.946	current decay
# t:751 I:-1.749	g:1.178	u:0.270	x:0.225	v:-1.964	current decay
# t:752 I:-1.608	g:1.178	u:0.270	x:0.225	v:-1.983	current decay
# t:753 I:-1.479	g:1.178	u:0.270	x:0.225	v:-2.002	current decay
# t:754 I:-1.361	g:1.178	u:0.270	x:0.225	v:-2.023	current decay
# t:755 I:-1.252	g:1.178	u:0.270	x:0.225	v:-2.043	current decay
# t:756 I:-1.153	g:1.178	u:0.270	x:0.225	v:-2.064	current decay
# t:757 I:-1.061	g:1.178	u:0.270	x:0.225	v:-2.086	current decay
# t:758 I:-0.976	g:1.178	u:0.270	x:0.225	v:-2.108	current decay
# t:759 I:-0.899	g:1.178	u:0.270	x:0.225	v:-2.129	current decay
# t:760 I:-0.827	g:1.178	u:0.270	x:0.225	v:-2.152	current decay
# t:761 I:-0.761	g:1.178	u:0.270	x:0.225	v:-2.174	current decay
# t:762 I:-0.700	g:1.178	u:0.270	x:0.225	v:-2.196	current decay
# t:763 I:-0.644	g:1.178	u:0.270	x:0.225	v:-2.219	current decay
# t:764 I:-0.593	g:1.178	u:0.270	x:0.225	v:-2.242	current decay
# t:765 I:-0.546	g:1.178	u:0.270	x:0.225	v:-2.264	current decay
# t:766 I:-0.502	g:1.178	u:0.270	x:0.225	v:-2.287	current decay
# t:767 I:-0.462	g:1.178	u:0.270	x:0.225	v:-2.310	current decay
# t:768 I:-0.425	g:1.178	u:0.270	x:0.225	v:-2.333	current decay
# t:769 I:-0.391	g:1.178	u:0.270	x:0.225	v:-2.356	current decay
# t:770 I:-0.359	g:1.178	u:0.270	x:0.225	v:-2.378	current decay
# t:771 I:-0.330	g:1.178	u:0.270	x:0.225	v:-2.401	current decay
# t:772 I:-0.304	g:1.178	u:0.270	x:0.225	v:-2.424	current decay
# t:773 I:-0.279	g:1.178	u:0.270	x:0.225	v:-2.447	current decay
# t:774 I:-0.257	g:1.178	u:0.270	x:0.225	v:-2.470	current decay
# t:775 I:-0.236	g:1.178	u:0.270	x:0.225	v:-2.492	current decay
# t:776 I:-0.217	g:1.178	u:0.270	x:0.225	v:-2.515	current decay
# t:777 I:-0.199	g:1.178	u:0.270	x:0.225	v:-2.538	current decay
# t:778 I:-0.183	g:1.178	u:0.270	x:0.225	v:-2.561	current decay
# t:779 I:-0.168	g:1.178	u:0.270	x:0.225	v:-2.583	current decay
# t:780 I:-0.155	g:1.178	u:0.270	x:0.225	v:-2.606	current decay
# t:781 I:-0.142	g:1.178	u:0.270	x:0.225	v:-2.629	current decay
# t:782 I:-0.131	g:1.178	u:0.270	x:0.225	v:-2.651	current decay
# t:783 I:-0.120	g:1.178	u:0.270	x:0.225	v:-2.674	current decay
# t:784 I:-0.110	g:1.178	u:0.270	x:0.225	v:-2.697	current decay
# t:785 I:-0.101	g:1.178	u:0.270	x:0.225	v:-2.719	current decay
# t:786 I:-0.093	g:1.178	u:0.270	x:0.225	v:-2.742	current decay
# t:787 I:-0.085	g:1.178	u:0.270	x:0.225	v:-2.764	current decay
# t:788 I:-0.078	g:1.178	u:0.270	x:0.225	v:-2.787	current decay
# t:789 I:-0.072	g:1.178	u:0.270	x:0.225	v:-2.809	current decay
# t:790 I:-0.066	g:1.178	u:0.270	x:0.225	v:-2.832	current decay
# t:791 I:-0.061	g:1.178	u:0.270	x:0.225	v:-2.854	current decay
# t:792 I:-0.056	g:1.178	u:0.270	x:0.225	v:-2.877	current decay
# t:793 I:-0.051	g:1.178	u:0.270	x:0.225	v:-2.899	current decay
# t:794 I:-0.047	g:1.178	u:0.270	x:0.225	v:-2.921	current decay
# t:795 I:-0.043	g:1.178	u:0.270	x:0.225	v:-2.944	current decay
# t:796 I:-0.040	g:1.178	u:0.270	x:0.225	v:-2.966	current decay
# t:797 I:-0.036	g:1.178	u:0.270	x:0.225	v:-2.989	current decay
# t:798 I:-0.033	g:1.178	u:0.270	x:0.225	v:-3.011	current decay
# t:799 I:-0.033	g:1.180	u:0.270	x:0.225	v:-3.033	synaptic spike
# t:799 I:-3.579	g:1.180	u:0.270	x:0.225	v:-3.033	current decay
# t:800 I:-3.274	g:1.180	u:0.270	x:0.225	v:-3.046	current decay
# t:801 I:-2.996	g:1.180	u:0.270	x:0.225	v:-3.061	current decay
# t:802 I:-2.744	g:1.180	u:0.270	x:0.225	v:-3.077	current decay
# t:803 I:-2.513	g:1.180	u:0.270	x:0.225	v:-3.095	current decay
# t:804 I:-2.303	g:1.180	u:0.270	x:0.225	v:-3.113	current decay
# t:805 I:-2.111	g:1.180	u:0.270	x:0.225	v:-3.133	current decay
# t:806 I:-1.935	g:1.180	u:0.270	x:0.225	v:-3.153	current decay
# t:807 I:-1.774	g:1.180	u:0.270	x:0.225	v:-3.174	current decay
# t:808 I:-1.627	g:1.180	u:0.270	x:0.225	v:-3.195	current decay
# t:809 I:-1.492	g:1.180	u:0.270	x:0.225	v:-3.217	current decay
# t:810 I:-1.368	g:1.180	u:0.270	x:0.225	v:-3.239	current decay
# t:811 I:-1.255	g:1.180	u:0.270	x:0.225	v:-3.261	current decay
# t:812 I:-1.151	g:1.180	u:0.270	x:0.225	v:-3.284	current decay
# t:813 I:-1.056	g:1.180	u:0.270	x:0.225	v:-3.307	current decay
# t:814 I:-0.968	g:1.180	u:0.270	x:0.225	v:-3.330	current decay
# t:815 I:-0.888	g:1.180	u:0.270	x:0.225	v:-3.353	current decay
# t:816 I:-0.815	g:1.180	u:0.270	x:0.225	v:-3.376	current decay
# t:817 I:-0.747	g:1.180	u:0.270	x:0.225	v:-3.399	current decay
# t:818 I:-0.685	g:1.180	u:0.270	x:0.225	v:-3.422	current decay
# t:819 I:-0.628	g:1.180	u:0.270	x:0.225	v:-3.445	current decay
# t:820 I:-0.576	g:1.180	u:0.270	x:0.225	v:-3.469	current decay
# t:821 I:-0.528	g:1.180	u:0.270	x:0.225	v:-3.492	current decay
# t:822 I:-0.484	g:1.180	u:0.270	x:0.225	v:-3.515	current decay
# t:823 I:-0.444	g:1.180	u:0.270	x:0.225	v:-3.538	current decay
# t:824 I:-0.407	g:1.180	u:0.270	x:0.225	v:-3.561	current decay
# t:825 I:-0.373	g:1.180	u:0.270	x:0.225	v:-3.585	current decay
# t:826 I:-0.342	g:1.180	u:0.270	x:0.225	v:-3.608	current decay
# t:827 I:-0.314	g:1.180	u:0.270	x:0.225	v:-3.631	current decay
# t:828 I:-0.288	g:1.180	u:0.270	x:0.225	v:-3.654	current decay
# t:829 I:-0.264	g:1.180	u:0.270	x:0.225	v:-3.677	current decay
# t:830 I:-0.242	g:1.180	u:0.270	x:0.225	v:-3.699	current decay
# t:831 I:-0.221	g:1.180	u:0.270	x:0.225	v:-3.722	current decay
# t:832 I:-0.203	g:1.180	u:0.270	x:0.225	v:-3.745	current decay
# t:833 I:-0.186	g:1.180	u:0.270	x:0.225	v:-3.768	current decay
# t:834 I:-0.170	g:1.180	u:0.270	x:0.225	v:-3.790	current decay
# t:835 I:-0.156	g:1.180	u:0.270	x:0.225	v:-3.813	current decay
# t:836 I:-0.143	g:1.180	u:0.270	x:0.225	v:-3.836	current decay
# t:837 I:-0.131	g:1.180	u:0.270	x:0.225	v:-3.858	current decay
# t:838 I:-0.120	g:1.180	u:0.270	x:0.225	v:-3.881	current decay
# t:839 I:-0.110	g:1.180	u:0.270	x:0.225	v:-3.903	current decay
# t:840 I:-0.101	g:1.180	u:0.270	x:0.225	v:-3.926	current decay
# t:841 I:-0.092	g:1.180	u:0.270	x:0.225	v:-3.948	current decay
# t:842 I:-0.085	g:1.180	u:0.270	x:0.225	v:-3.970	current decay
# t:843 I:-0.077	g:1.180	u:0.270	x:0.225	v:-3.993	current decay
# t:844 I:-0.071	g:1.180	u:0.270	x:0.225	v:-4.015	current decay
# t:845 I:-0.065	g:1.180	u:0.270	x:0.225	v:-4.037	current decay
# t:846 I:-0.060	g:1.180	u:0.270	x:0.225	v:-4.060	current decay
# t:847 I:-0.055	g:1.180	u:0.270	x:0.225	v:-4.082	current decay
# t:848 I:-0.050	g:1.180	u:0.270	x:0.225	v:-4.104	current decay
# t:849 I:-0.046	g:1.180	u:0.270	x:0.225	v:-4.126	current decay
# t:850 I:-0.046	g:1.181	u:0.270	x:0.225	v:-4.148	synaptic spike
# t:850 I:-4.898	g:1.181	u:0.270	x:0.225	v:-4.148	current decay
# t:851 I:-4.472	g:1.181	u:0.270	x:0.225	v:-4.158	current decay
# t:852 I:-4.085	g:1.181	u:0.270	x:0.225	v:-4.170	current decay
# t:853 I:-3.733	g:1.181	u:0.270	x:0.225	v:-4.184	current decay
# t:854 I:-3.413	g:1.181	u:0.270	x:0.225	v:-4.199	current decay
# t:855 I:-3.122	g:1.181	u:0.270	x:0.225	v:-4.216	current decay
# t:856 I:-2.856	g:1.181	u:0.270	x:0.225	v:-4.235	current decay
# t:857 I:-2.613	g:1.181	u:0.270	x:0.225	v:-4.254	current decay
# t:858 I:-2.391	g:1.181	u:0.270	x:0.225	v:-4.274	current decay
# t:859 I:-2.189	g:1.181	u:0.270	x:0.225	v:-4.295	current decay
# t:860 I:-2.004	g:1.181	u:0.270	x:0.225	v:-4.316	current decay
# t:861 I:-1.834	g:1.181	u:0.270	x:0.225	v:-4.338	current decay
# t:862 I:-1.679	g:1.181	u:0.270	x:0.225	v:-4.361	current decay
# t:863 I:-1.538	g:1.181	u:0.270	x:0.225	v:-4.383	current decay
# t:864 I:-1.408	g:1.181	u:0.270	x:0.225	v:-4.406	current decay
# t:865 I:-1.289	g:1.181	u:0.270	x:0.225	v:-4.429	current decay
# t:866 I:-1.180	g:1.181	u:0.270	x:0.225	v:-4.452	current decay
# t:867 I:-1.081	g:1.181	u:0.270	x:0.225	v:-4.475	current decay
# t:868 I:-0.989	g:1.181	u:0.270	x:0.225	v:-4.498	current decay
# t:869 I:-0.906	g:1.181	u:0.270	x:0.225	v:-4.522	current decay
# t:870 I:-0.829	g:1.181	u:0.270	x:0.225	v:-4.545	current decay
# t:871 I:-0.759	g:1.181	u:0.270	x:0.225	v:-4.568	current decay
# t:872 I:-0.695	g:1.181	u:0.270	x:0.225	v:-4.591	current decay
# t:873 I:-0.636	g:1.181	u:0.270	x:0.225	v:-4.615	current decay
# t:874 I:-0.583	g:1.181	u:0.270	x:0.225	v:-4.638	current decay
# t:875 I:-0.533	g:1.181	u:0.270	x:0.225	v:-4.661	current decay
# t:876 I:-0.488	g:1.181	u:0.270	x:0.225	v:-4.684	current decay
# t:877 I:-0.447	g:1.181	u:0.270	x:0.225	v:-4.707	current decay
# t:878 I:-0.409	g:1.181	u:0.270	x:0.225	v:-4.730	current decay
# t:879 I:-0.374	g:1.181	u:0.270	x:0.225	v:-4.753	current decay
# t:880 I:-0.343	g:1.181	u:0.270	x:0.225	v:-4.775	current decay
# t:881 I:-0.314	g:1.181	u:0.270	x:0.225	v:-4.798	current decay
# t:882 I:-0.287	g:1.181	u:0.270	x:0.225	v:-4.821	current decay
# t:883 I:-0.263	g:1.181	u:0.270	x:0.225	v:-4.843	current decay
# t:884 I:-0.240	g:1.181	u:0.270	x:0.225	v:-4.866	current decay
# t:885 I:-0.220	g:1.181	u:0.270	x:0.225	v:-4.888	current decay
# t:886 I:-0.201	g:1.181	u:0.270	x:0.225	v:-4.910	current decay
# t:887 I:-0.184	g:1.181	u:0.270	x:0.225	v:-4.933	current decay
# t:888 I:-0.168	g:1.181	u:0.270	x:0.225	v:-4.955	current decay
# t:889 I:-0.154	g:1.181	u:0.270	x:0.225	v:-4.977	current decay
# t:890 I:-0.141	g:1.181	u:0.270	x:0.225	v:-4.999	current decay
# t:891 I:-0.129	g:1.181	u:0.270	x:0.225	v:-5.021	current decay
# t:892 I:-0.118	g:1.181	u:0.270	x:0.225	v:-5.043	current decay
# t:893 I:-0.108	g:1.181	u:0.270	x:0.225	v:-5.065	current decay
# t:894 I:-0.099	g:1.181	u:0.270	x:0.225	v:-5.087	current decay
# t:895 I:-0.090	g:1.181	u:0.270	x:0.225	v:-5.109	current decay
# t:896 I:-0.083	g:1.181	u:0.270	x:0.225	v:-5.130	current decay
# t:897 I:-0.076	g:1.181	u:0.270	x:0.225	v:-5.152	current decay
# t:898 I:-0.069	g:1.181	u:0.270	x:0.225	v:-5.174	current decay
# t:899 I:-0.063	g:1.181	u:0.270	x:0.225	v:-5.195	current decay
# t:900 I:-0.058	g:1.181	u:0.270	x:0.225	v:-5.217	current decay
# t:901 I:-0.058	g:1.181	u:0.270	x:0.226	v:-5.239	synaptic spike
# t:901 I:-6.189	g:1.181	u:0.270	x:0.226	v:-5.239	current decay
# t:902 I:-5.644	g:1.181	u:0.270	x:0.226	v:-5.244	current decay
# t:903 I:-5.149	g:1.181	u:0.270	x:0.226	v:-5.253	current decay
# t:904 I:-4.700	g:1.181	u:0.270	x:0.226	v:-5.264	current decay
# t:905 I:-4.292	g:1.181	u:0.270	x:0.226	v:-5.278	current decay
# t:906 I:-3.921	g:1.181	u:0.270	x:0.226	v:-5.293	current decay
# t:907 I:-3.583	g:1.181	u:0.270	x:0.226	v:-5.310	current decay
# t:908 I:-3.275	g:1.181	u:0.270	x:0.226	v:-5.329	current decay
# t:909 I:-2.994	g:1.181	u:0.270	x:0.226	v:-5.348	current decay
# t:910 I:-2.737	g:1.181	u:0.270	x:0.226	v:-5.368	current decay
# t:911 I:-2.503	g:1.181	u:0.270	x:0.226	v:-5.389	current decay
# t:912 I:-2.289	g:1.181	u:0.270	x:0.226	v:-5.410	current decay
# t:913 I:-2.093	g:1.181	u:0.270	x:0.226	v:-5.432	current decay
# t:914 I:-1.915	g:1.181	u:0.270	x:0.226	v:-5.454	current decay
# t:915 I:-1.751	g:1.181	u:0.270	x:0.226	v:-5.477	current decay
# t:916 I:-1.602	g:1.181	u:0.270	x:0.226	v:-5.500	current decay
# t:917 I:-1.465	g:1.181	u:0.270	x:0.226	v:-5.523	current decay
# t:918 I:-1.340	g:1.181	u:0.270	x:0.226	v:-5.545	current decay
# t:919 I:-1.226	g:1.181	u:0.270	x:0.226	v:-5.568	current decay
# t:920 I:-1.121	g:1.181	u:0.270	x:0.226	v:-5.591	current decay
# t:921 I:-1.025	g:1.181	u:0.270	x:0.226	v:-5.614	current decay
# t:922 I:-0.938	g:1.181	u:0.270	x:0.226	v:-5.637	current decay
# t:923 I:-0.858	g:1.181	u:0.270	x:0.226	v:-5.660	current decay
# t:924 I:-0.784	g:1.181	u:0.270	x:0.226	v:-5.683	current decay
# t:925 I:-0.717	g:1.181	u:0.270	x:0.226	v:-5.706	current decay
# t:926 I:-0.656	g:1.181	u:0.270	x:0.226	v:-5.729	current decay
# t:927 I:-0.600	g:1.181	u:0.270	x:0.226	v:-5.751	current decay
# t:928 I:-0.548	g:1.181	u:0.270	x:0.226	v:-5.774	current decay
# t:929 I:-0.501	g:1.181	u:0.270	x:0.226	v:-5.796	current decay
# t:930 I:-0.459	g:1.181	u:0.270	x:0.226	v:-5.819	current decay
# t:931 I:-0.419	g:1.181	u:0.270	x:0.226	v:-5.841	current decay
# t:932 I:-0.383	g:1.181	u:0.270	x:0.226	v:-5.863	current decay
# t:933 I:-0.350	g:1.181	u:0.270	x:0.226	v:-5.885	current decay
# t:934 I:-0.320	g:1.181	u:0.270	x:0.226	v:-5.907	current decay
# t:935 I:-0.293	g:1.181	u:0.270	x:0.226	v:-5.929	current decay
# t:936 I:-0.268	g:1.181	u:0.270	x:0.226	v:-5.951	current decay
# t:937 I:-0.245	g:1.181	u:0.270	x:0.226	v:-5.972	current decay
# t:938 I:-0.224	g:1.181	u:0.270	x:0.226	v:-5.994	current decay
# t:939 I:-0.205	g:1.181	u:0.270	x:0.226	v:-6.016	current decay
# t:940 I:-0.187	g:1.181	u:0.270	x:0.226	v:-6.037	current decay
# t:941 I:-0.171	g:1.181	u:0.270	x:0.226	v:-6.058	current decay
# t:942 I:-0.156	g:1.181	u:0.270	x:0.226	v:-6.080	current decay
# t:943 I:-0.143	g:1.181	u:0.270	x:0.226	v:-6.101	current decay
# t:944 I:-0.131	g:1.181	u:0.270	x:0.226	v:-6.122	current decay
# t:945 I:-0.119	g:1.181	u:0.270	x:0.226	v:-6.143	current decay
# t:946 I:-0.109	g:1.181	u:0.270	x:0.226	v:-6.164	current decay
# t:947 I:-0.100	g:1.181	u:0.270	x:0.226	v:-6.185	current decay
# t:948 I:-0.091	g:1.181	u:0.270	x:0.226	v:-6.206	current decay
# t:949 I:-0.083	g:1.181	u:0.270	x:0.226	v:-6.227	current decay
# t:950 I:-0.076	g:1.181	u:0.270	x:0.226	v:-6.248	current decay
# t:951 I:-0.070	g:1.181	u:0.270	x:0.226	v:-6.269	current decay
# t:952 I:-0.070	g:1.182	u:0.270	x:0.226	v:-6.290	synaptic spike
# t:952 I:-7.433	g:1.182	u:0.270	x:0.226	v:-6.290	current decay
# t:953 I:-6.773	g:1.182	u:0.270	x:0.226	v:-6.291	current decay
# t:954 I:-6.174	g:1.182	u:0.270	x:0.226	v:-6.297	current decay
# t:955 I:-5.632	g:1.182	u:0.270	x:0.226	v:-6.306	current decay
# t:956 I:-5.139	g:1.182	u:0.270	x:0.226	v:-6.317	current decay
# t:957 I:-4.691	g:1.182	u:0.270	x:0.226	v:-6.330	current decay
# t:958 I:-4.283	g:1.182	u:0.270	x:0.226	v:-6.346	current decay
# t:959 I:-3.912	g:1.182	u:0.270	x:0.226	v:-6.363	current decay
# t:960 I:-3.573	g:1.182	u:0.270	x:0.226	v:-6.381	current decay
# t:961 I:-3.265	g:1.182	u:0.270	x:0.226	v:-6.400	current decay
# t:962 I:-2.983	g:1.182	u:0.270	x:0.226	v:-6.420	current decay
# t:963 I:-2.726	g:1.182	u:0.270	x:0.226	v:-6.441	current decay
# t:964 I:-2.491	g:1.182	u:0.270	x:0.226	v:-6.462	current decay
# t:965 I:-2.277	g:1.182	u:0.270	x:0.226	v:-6.484	current decay
# t:966 I:-2.081	g:1.182	u:0.270	x:0.226	v:-6.506	current decay
# t:967 I:-1.902	g:1.182	u:0.270	x:0.226	v:-6.528	current decay
# t:968 I:-1.738	g:1.182	u:0.270	x:0.226	v:-6.551	current decay
# t:969 I:-1.589	g:1.182	u:0.270	x:0.226	v:-6.573	current decay
# t:970 I:-1.452	g:1.182	u:0.270	x:0.226	v:-6.595	current decay
# t:971 I:-1.327	g:1.182	u:0.270	x:0.226	v:-6.618	current decay
# t:972 I:-1.213	g:1.182	u:0.270	x:0.226	v:-6.640	current decay
# t:973 I:-1.109	g:1.182	u:0.270	x:0.226	v:-6.663	current decay
# t:974 I:-1.013	g:1.182	u:0.270	x:0.226	v:-6.685	current decay
# t:975 I:-0.926	g:1.182	u:0.270	x:0.226	v:-6.707	current decay
# t:976 I:-0.846	g:1.182	u:0.270	x:0.226	v:-6.730	current decay
# t:977 I:-0.773	g:1.182	u:0.270	x:0.226	v:-6.752	current decay
# t:978 I:-0.707	g:1.182	u:0.270	x:0.226	v:-6.774	current decay
# t:979 I:-0.646	g:1.182	u:0.270	x:0.226	v:-6.796	current decay
# t:980 I:-0.590	g:1.182	u:0.270	x:0.226	v:-6.817	current decay
# t:981 I:-0.539	g:1.182	u:0.270	x:0.226	v:-6.839	current decay
# t:982 I:-0.493	g:1.182	u:0.270	x:0.226	v:-6.860	current decay
# t:983 I:-0.450	g:1.182	u:0.270	x:0.226	v:-6.882	current decay
# t:984 I:-0.411	g:1.182	u:0.270	x:0.226	v:-6.903	current decay
# t:985 I:-0.376	g:1.182	u:0.270	x:0.226	v:-6.924	current decay
# t:986 I:-0.343	g:1.182	u:0.270	x:0.226	v:-6.945	current decay
# t:987 I:-0.314	g:1.182	u:0.270	x:0.226	v:-6.966	current decay
# t:988 I:-0.287	g:1.182	u:0.270	x:0.226	v:-6.987	current decay
# t:989 I:-0.262	g:1.182	u:0.270	x:0.226	v:-7.008	current decay
# t:990 I:-0.239	g:1.182	u:0.270	x:0.226	v:-7.028	current decay
# t:991 I:-0.218	g:1.182	u:0.270	x:0.226	v:-7.049	current decay
# t:992 I:-0.200	g:1.182	u:0.270	x:0.226	v:-7.069	current decay
# t:993 I:-0.182	g:1.182	u:0.270	x:0.226	v:-7.090	current decay
# t:994 I:-0.167	g:1.182	u:0.270	x:0.226	v:-7.110	current decay
# t:995 I:-0.152	g:1.182	u:0.270	x:0.226	v:-7.130	current decay
# t:996 I:-0.139	g:1.182	u:0.270	x:0.226	v:-7.151	current decay
# t:997 I:-0.127	g:1.182	u:0.270	x:0.226	v:-7.171	current decay
# t:998 I:-0.116	g:1.182	u:0.270	x:0.226	v:-7.191	current decay
# t:999 I:-0.106	g:1.182	u:0.270	x:0.226	v:-7.211	current decay
# /tmp/ipykernel_39264/1576372369.py:263: DeprecationWarning: scipy.conj is deprecated and will be removed in SciPy 2.0.0, use numpy.conj instead
#   c = scipy.ifft(af * scipy.conj(bf))
# /tmp/ipykernel_39264/1576372369.py:263: DeprecationWarning: scipy.ifft is deprecated and will be removed in SciPy 2.0.0, use scipy.fft.ifft instead
#   c = scipy.ifft(af * scipy.conj(bf))
# /tmp/ipykernel_39264/1576372369.py:298: RuntimeWarning: invalid value encountered in true_divide
#   pctErrorI = abs((I_2 - I_syn_2)/I_syn_2)

# %%
# Print stats related to the differences between the voltage computed via Keivan's model and CARLsim
print(maxErrorV)
print(minErrorV)
print(meanErrorV)
print(medianErrorV)
print(mismatchV)
# Out:
# 0.0005537050967232892
# 1.4406427631404644e-06
# 0.0002935743608628468
# 0.0003518081076378919
# 7.5325434774792025e-06

# %%
# Print stats related to the differences between the current computed via Keivan's model and CARLsim
print(maxErrorI)
print(minErrorI)
print(meanErrorI)
print(medianErrorI)
print(mismatchI)
# Out:
# 1.0
# 2.3351885965391782e-06
# 0.022663087706716347
# 0.01522615489638712
# 0.00032158528745553755
