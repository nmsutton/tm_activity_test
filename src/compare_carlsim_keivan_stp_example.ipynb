# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import statistics as st
from collections import Counter
import os
import os.path
import scipy
import csv
from scipy import signal
import pandas as pd

# %%
# Create time points
Tmin, Tmax, dt = 0, 1000, 0.025  # Step size
T = np.arange(Tmin, Tmax + dt, dt)

# Declare the current to be used
I_ext = 150

## Nine parameters for IM model
# Axo_Axonic
k, a, b, d, C, vr, vt, c, vpeak = 3.961462878, 0.004638608, 8.683644937, 15, 165, -57.09978287, \
                                  -51.71875628, -73.96850421, 27.79863559

preNeuronType = "Axo-Axonic"

## Make a state vector that has a (v, u) pair for each timestep
s = np.zeros((len(T), 2))

# Create a vector to store spike times
spike_times = np.array([])
isi_mode_list = np.array([])


## Initial values
s[0, 0] = vr
s[0, 1] = 0


# Note that s1[0] is v, s1[1] is u. This is Izhikevich equation in vector form
def s_dt(s1, I):
  v_dt = (k*(s1[0] - vr)*(s1[0] - vt) - s1[1] + I)*(1/C)
  u_dt = a*(b*(s1[0] - vr) - s1[1])
  return np.array([v_dt, u_dt])


## SIMULATE
for t in range(len(T)-1):
  # Calculate the four constants of Runge-Kutta method
  k_1 = s_dt(s[t], I_ext)
  k_2 = s_dt(s[t] + 0.5*dt*k_1, I_ext)
  k_3 = s_dt(s[t] + 0.5*dt*k_2, I_ext)
  k_4 = s_dt(s[t] + dt*k_3, I_ext)

  s[t+1] = s[t] + (1.0/6)*dt*(k_1 + 2*k_2 + 2*k_3 + k_4)

  # Reset the neuron if it has spiked
  if s[t+1, 0] >= vpeak:
    s[t, 0]   = vpeak # add Dirac pulse for visualisation
    s[t+1, 0] = c   # Reset to resting potential
    s[t+1, 1] += d  # Update recovery variable
    spike_times = np.append(spike_times, math.ceil(t*dt))

v = s[:, 0]
u = s[:, 1]


## Nine parameters for IM model
# Pyramidal
postNeuronType = "Pyramidal"
a, b, c, d, k, vr, vt, C, vpeak = 0.00838350334098279, -42.5524776883928, -38.8680990294091, 588.0, \
                                  0.792338703789581, -63.2044008171655, -33.6041733124267, 366.0, 35.8614648558726

# Synaptic Parameters and equations
synaptic_event_times = list(spike_times)

# TPM parameters
g0, tau_d, tau_f, tau_r, Utilization, e_rev = 3.644261648, 10.71107251, 17.20004939, 435.8103009, 0.259914361, -70

tm_model = 'Carlsim'#'Keivan'

if tm_model == 'Keivan':
    # in CARLsim there is no change to the g param from the value it is set as in connect()
    # Note: NS is unclear why this calculation exists and is related to eq. 13 in (Moradi, 2022) supp mat.
    g0 /= Utilization

def synaptic_event(delta_t_, g, g0, tau_d_, tau_r_, tau_f_, utilization, x0, y0, u0, e_syn):
    if tm_model != 'Carlsim':
        # TM Model that depends on tau_d
        tau1r = tau_d_ / ((tau_d_ - tau_r_) if tau_d_ != tau_r_ else 1e-13)
        y_ = y0 * math.exp(-delta_t_ / tau_d_)
        x_ = 1 + (x0 - 1 + tau1r * y0) * math.exp(-delta_t_ / tau_r_) - tau1r * y_
        u_ = u0 * math.exp(-delta_t_ / tau_f_)
        u0 = u_ + utilization * (1 - u_)
        y0 = y_ + u0 * x_
        x0 = x_ - u0 * x_
        g  = g0 * y0
        #print("%f  = %f * %f; u0:%f x0:%f x_:%f" % (g, g0, y0, u0, x0, x_))
    else:
        # Carlsim's TM Model
        A  = 1 / Utilization # this seems to serve the same function as g0 /= Utilization would
        u_ = u0 + ((-u0/tau_f_) + utilization * (1 - u0))
        x_ = x0 + ((1 - x0)/tau_r_ - u_ * x0)
        #print("%f + %f * (%f * %f * %f)" % (g, g0, A, u_, x_))        
        g  = g + g0 * (A * u_ * x0)
        u0 = u_
        x0 = x_
        
    return g, x0, y0, u0


def synaptic_current(I, g, delta_t_, tau_d_, e_syn_, tm_model):
    if tm_model == 'Keivan':
        #g = g * math.exp(-delta_t_ / tau_d_) * e_syn_
        I = g * math.exp(-delta_t_ / tau_d_) * e_syn_
    if tm_model == 'Carlsim':
        I = g * e_syn_
        #print("%f * (1 - (1 / %f))" % (g,tau_d))
    return I

def synaptic_decay(g, tau_d_, tm_model):
    g = g * (1 - (1 / tau_d_))
    return g

def stp_variable_update(u, x, tau_f, tau_r, tm_model):
    tau_f_inv = 1/tau_f
    tau_r_inv = 1/tau_r
    u = u * (1 - tau_f_inv)
    x = x + (1 - x) * tau_r_inv
    #u = u + -u/tau_f
    #x = x + (1 - x)/tau_r
    return u, x

# Initialize synaptic state variables
g, x0, y0 = 0.0, 1.0, 0.0
I = 0.0
if tm_model == 'Carlsim':
    u0 = 0 #Utilization # NS does not see evidence in CARLsim that this is initialized as other than 0
else:
    u0 = 0

# Make a state vector that has a (v, u) pair for each timestep
s = np.zeros((len(T), 2))

# Initial Izhikevich state variables
s[0, 0] = vr
s[0, 1] = 0


# Note that s1[0] is v, s1[1] is u. This is Izhikevich equation in vector form
def s_dt(s1, I):
    v_dt = (k * (s1[0] - vr) * (s1[0] - vt) - s1[1] + I) * (1 / C)
    u_dt = a * (b * (s1[0] - vr) - s1[1])
    return np.array([v_dt, u_dt])

# SIMULATE
next_synaptic_event_time, delta_t, I_syn = synaptic_event_times[0], 0.0, [0]
synaptic_event_time = next_synaptic_event_time
spike_times = np.array([])
for t in range(len(T) - 1):
    v = s[t, 0]
    e_syn = v - e_rev
    time = T[t]

    # in CARLsim this occurs before the synaptic spike current update. doSTPUpdateAndDecayCond() is before globalStateUpdate().
    if (tm_model == 'Carlsim' and t % (1/dt) == 0): # run every whole number millisecond
        g = synaptic_decay(g, tau_d, tm_model)
        u0, x0 = stp_variable_update(u0, x0, tau_f, tau_r, tm_model)

    if next_synaptic_event_time <= time:
        inter_event_time = next_synaptic_event_time - synaptic_event_time
        g, x0, y0, u0 = synaptic_event(inter_event_time, g, g0, tau_d, tau_r, tau_f, Utilization, x0, y0, u0, e_syn)
        # NS addition: shouldn't g be a rolling total rather than equal to g here? Such would accomidate past g from prior spikes?
        # NS updated g for carlsim calcs
        #print(g, time, synaptic_event_time, next_synaptic_event_time)
        print("t:%d I:%.3f\tg:%.3f\tu:%.3f\tx:%.3f\tv:%.3f\tsynaptic spike" % (time,I,g,u0,x0,e_syn))
        synaptic_event_time = time
        if len(synaptic_event_times) > 1:
            del synaptic_event_times[0]
            next_synaptic_event_time = synaptic_event_times[0]
        else:
            next_synaptic_event_time = math.inf

    delta_t = time - synaptic_event_time
    if delta_t >= 0:
        if (t % (1/dt) == 0):
            I = synaptic_current(I, g, delta_t, tau_d, e_syn, tm_model)
            print("t:%d I:%.3f\tg:%.3f\tu:%.3f\tx:%.3f\tv:%.3f\tcurrent decay" % (t/(1/dt),I,g,u0,x0,e_syn))
    I_syn.append(I)

    # Calculate the four constants of Runge-Kutta method
    k_1 = s_dt(s[t], -I)
    k_2 = s_dt(s[t] + 0.5 * dt * k_1, -I)
    k_3 = s_dt(s[t] + 0.5 * dt * k_2, -I)
    k_4 = s_dt(s[t] + dt * k_3, -I)

    s[t + 1] = s[t] + (1.0 / 6) * dt * (k_1 + 2 * k_2 + 2 * k_3 + k_4)

    # Reset the neuron if it has spiked
    if s[t + 1, 0] >= vpeak:
        s[t, 0] = vpeak  # add Dirac pulse for visualisation
        s[t + 1, 0] = c  # Reset to resting potential
        s[t + 1, 1] += d  # Update recovery variable
        spike_times = np.append(spike_times, math.floor(t * dt))

v = s[:, 0]
u = s[:, 1]

# First define function to flip the sign of the current
def sign(lst): 
    return [ -i for i in lst ]

# Compare to CARLsim simulation output
FH = np.loadtxt("HC_IM_05_26_aac_pyr_I_150pA_fast_1_slow_0.txt")
I = FH[1::2]
V = FH[0::2]
I = sign(I)
I = I[0:len(I_syn)-1]
V = V[0:len(I_syn)-1]
ax1 = plt.subplot(211)
ax1.plot(T,np.append(V, [V[-1]]), label = "CARLsim TM") # added the last value of V to ensure the same length as time vector
plt.ylabel('Membrane potential (mV)')
ax2 = plt.subplot(212)
ax2.plot(T,np.append(I, [I[-1]]), label = "CARLsim TM") # added the last value of I to ensure the same length as time vector
plt.ylabel('Synaptic Current (pA)')
plt.xlabel('Time (ms)')
plt.legend(loc = "center right")
plt.tight_layout()

## Plot the membrane potential
ax1 = plt.subplot(211)
ax1.plot(T, v, color = "orange", linestyle='dotted', label = "Keivan TM", alpha=0.85)
plt.ylabel('Membrane potential (mV)')
plt.title(f"{postNeuronType}")
ax2 = plt.subplot(212)
ax2.plot(T, I_syn, color = "orange", linestyle='dotted', label = "Keivan TM", alpha=0.85)
plt.ylabel('Synaptic Current (pA)')
plt.xlabel('Time (ms)')
plt.legend(loc = "center right")
plt.tight_layout()
fileOutputName = preNeuronType + '_' + postNeuronType + '_' + str(I_ext) + 'pA' + \
      '_CARLsim_vs_Keivan_superimposed.png'
plt.savefig(fileOutputName, dpi=800)
plt.clf()


# Look at the error between CARLsim and python computed synaptic signal
I = np.append(I, [I[-1]])
V = np.append(V, [V[-1]])

af = scipy.fft.fft(I_syn)
bf = scipy.fft.fft(I)
c = scipy.ifft(af * scipy.conj(bf))
time_shift = np.argmax(abs(c))
#         print(time_shift)

I_2 = I[:-1]
I_2 = I_2[::int(1/dt)]
I_syn_2 = I_syn[0+time_shift:]
I_syn_2 = I_syn_2[::int(1/dt)]
I_syn_2 = np.array(np.array(I_syn_2,dtype=np.float32))
V_2 = V[:-1]
V_2 = V_2[::int(1/dt)]
v_2 = v[0+time_shift:]
v_2 = v_2[::int(1/dt)]

if len(V_2) == len(v_2):
    ax1 = plt.subplot(211)
    ax1.plot(abs(V_2 - v_2))
    plt.ylabel('Membrane potential (mV)')
    plt.title(f"{postNeuronType}")
    ax2 = plt.subplot(212)
    ax2.plot(abs(I_2 - I_syn_2))
    plt.ylabel('I_syn diff (HCO - Carlsim) (pA)')
    plt.xlabel('Time (ms)')
    plt.tight_layout()
    fileOutputName = preNeuronType + '_' + postNeuronType + '_' + str(I_ext) + 'pA' + \
          '_CARLsim_vs_Keivan_error.png'
    plt.savefig(fileOutputName, dpi=800)
    plt.clf()

    # Append min, max, mean, and median of errors between V and I
    pctErrorV = abs((V_2 - v_2)/v_2)
    pctErrorI = abs((I_2 - I_syn_2)/I_syn_2)
    maxErrorV = max(pctErrorV[~np.isnan(pctErrorV)])
    maxErrorI = max(pctErrorI[~np.isnan(pctErrorI)])
    minErrorV = min(pctErrorV[~np.isnan(pctErrorV)])
    minErrorI = min(pctErrorI[~np.isnan(pctErrorI)])
    meanErrorV = np.mean(pctErrorV[~np.isnan(pctErrorV)])
    meanErrorI = np.mean(pctErrorI[~np.isnan(pctErrorI)])
    medianErrorV = np.median(pctErrorV[~np.isnan(pctErrorV)])
    medianErrorI = np.median(pctErrorI[~np.isnan(pctErrorI)])
    mismatchV = sum(abs(V_2-v_2)*dt)/sum(abs((V_2 + v_2)/2))
    mismatchI = sum(abs(I_2-I_syn_2)*dt)/sum(abs((I_2 + I_syn_2)/2))
# Out:
# t:15 I:0.000	g:3.644	u:0.260	x:0.740	v:6.796	synaptic spike
# t:15 I:24.765	g:3.644	u:0.260	x:0.740	v:6.796	current decay
# t:16 I:22.236	g:3.304	u:0.245	x:0.741	v:6.730	current decay
# t:17 I:19.996	g:2.996	u:0.231	x:0.741	v:6.675	current decay
# t:18 I:18.005	g:2.716	u:0.217	x:0.742	v:6.630	current decay
# t:19 I:16.232	g:2.462	u:0.205	x:0.742	v:6.592	current decay
# t:20 I:14.648	g:2.232	u:0.193	x:0.743	v:6.561	current decay
# t:21 I:13.230	g:2.024	u:0.181	x:0.744	v:6.536	current decay
# t:22 I:11.958	g:1.835	u:0.171	x:0.744	v:6.517	current decay
# t:23 I:10.816	g:1.664	u:0.161	x:0.745	v:6.501	current decay
# t:24 I:9.789	g:1.508	u:0.152	x:0.745	v:6.490	current decay
# t:25 I:8.863	g:1.368	u:0.143	x:0.746	v:6.481	current decay
# t:26 I:8.029	g:1.240	u:0.134	x:0.747	v:6.475	current decay
# t:27 I:7.275	g:1.124	u:0.127	x:0.747	v:6.472	current decay
# t:28 I:6.594	g:1.019	u:0.119	x:0.748	v:6.470	current decay
# t:29 I:5.979	g:0.924	u:0.112	x:0.748	v:6.470	current decay
# t:30 I:5.422	g:0.838	u:0.106	x:0.749	v:6.472	current decay
# t:31 I:4.918	g:0.760	u:0.100	x:0.749	v:6.474	current decay
# t:32 I:4.461	g:0.689	u:0.094	x:0.750	v:6.478	current decay
# t:33 I:4.047	g:0.624	u:0.088	x:0.751	v:6.482	current decay
# t:34 I:3.672	g:0.566	u:0.083	x:0.751	v:6.487	current decay
# t:35 I:3.332	g:0.513	u:0.078	x:0.752	v:6.492	current decay
# t:36 I:3.023	g:0.465	u:0.074	x:0.752	v:6.497	current decay
# t:37 I:2.743	g:0.422	u:0.070	x:0.753	v:6.503	current decay
# t:38 I:2.743	g:3.600	u:0.305	x:0.525	v:6.509	synaptic spike
# t:38 I:23.434	g:3.600	u:0.305	x:0.525	v:6.509	current decay
# t:39 I:21.085	g:3.264	u:0.287	x:0.526	v:6.459	current decay
# t:40 I:18.997	g:2.960	u:0.270	x:0.527	v:6.419	current decay
# t:41 I:17.136	g:2.683	u:0.255	x:0.528	v:6.386	current decay
# t:42 I:15.473	g:2.433	u:0.240	x:0.529	v:6.360	current decay
# t:43 I:13.984	g:2.206	u:0.226	x:0.530	v:6.340	current decay
# t:44 I:12.647	g:2.000	u:0.213	x:0.531	v:6.325	current decay
# t:45 I:11.446	g:1.813	u:0.200	x:0.532	v:6.313	current decay
# t:46 I:10.365	g:1.644	u:0.189	x:0.533	v:6.306	current decay
# t:47 I:9.390	g:1.490	u:0.178	x:0.534	v:6.301	current decay
# t:48 I:8.510	g:1.351	u:0.167	x:0.535	v:6.299	current decay
# t:49 I:7.715	g:1.225	u:0.158	x:0.536	v:6.298	current decay
# t:50 I:6.997	g:1.111	u:0.148	x:0.537	v:6.300	current decay
# t:51 I:6.346	g:1.007	u:0.140	x:0.539	v:6.303	current decay
# t:52 I:5.758	g:0.913	u:0.132	x:0.540	v:6.307	current decay
# t:53 I:5.224	g:0.828	u:0.124	x:0.541	v:6.312	current decay
# t:54 I:4.741	g:0.750	u:0.117	x:0.542	v:6.318	current decay
# t:55 I:4.302	g:0.680	u:0.110	x:0.543	v:6.324	current decay
# t:56 I:3.905	g:0.617	u:0.104	x:0.544	v:6.330	current decay
# t:57 I:3.544	g:0.559	u:0.098	x:0.545	v:6.337	current decay
# t:58 I:3.217	g:0.507	u:0.092	x:0.546	v:6.345	current decay
# t:59 I:2.920	g:0.460	u:0.087	x:0.547	v:6.352	current decay
# t:60 I:2.650	g:0.417	u:0.082	x:0.548	v:6.359	current decay
# t:61 I:2.406	g:0.378	u:0.077	x:0.549	v:6.366	current decay
# t:62 I:2.183	g:0.343	u:0.072	x:0.550	v:6.373	current decay
# t:63 I:1.982	g:0.311	u:0.068	x:0.551	v:6.380	current decay
# t:64 I:1.982	g:2.632	u:0.304	x:0.385	v:6.387	synaptic spike
# t:64 I:16.813	g:2.632	u:0.304	x:0.385	v:6.387	current decay
# t:65 I:15.164	g:2.387	u:0.286	x:0.387	v:6.354	current decay
# t:66 I:13.690	g:2.164	u:0.269	x:0.388	v:6.327	current decay
# t:67 I:12.369	g:1.962	u:0.254	x:0.390	v:6.305	current decay
# t:68 I:11.184	g:1.779	u:0.239	x:0.391	v:6.288	current decay
# t:69 I:10.119	g:1.613	u:0.225	x:0.392	v:6.275	current decay
# t:70 I:9.159	g:1.462	u:0.212	x:0.394	v:6.265	current decay
# t:71 I:8.295	g:1.326	u:0.200	x:0.395	v:6.258	current decay
# t:72 I:7.515	g:1.202	u:0.188	x:0.397	v:6.253	current decay
# t:73 I:6.810	g:1.090	u:0.177	x:0.398	v:6.250	current decay
# t:74 I:6.173	g:0.988	u:0.167	x:0.399	v:6.249	current decay
# t:75 I:5.597	g:0.896	u:0.157	x:0.401	v:6.250	current decay
# t:76 I:5.076	g:0.812	u:0.148	x:0.402	v:6.251	current decay
# t:77 I:4.604	g:0.736	u:0.139	x:0.404	v:6.253	current decay
# t:78 I:4.176	g:0.667	u:0.131	x:0.405	v:6.256	current decay
# t:79 I:3.788	g:0.605	u:0.124	x:0.406	v:6.260	current decay
# t:80 I:3.437	g:0.549	u:0.116	x:0.408	v:6.264	current decay
# t:81 I:3.118	g:0.497	u:0.110	x:0.409	v:6.269	current decay
# t:82 I:2.829	g:0.451	u:0.103	x:0.410	v:6.273	current decay
# t:83 I:2.567	g:0.409	u:0.097	x:0.412	v:6.278	current decay
# t:84 I:2.329	g:0.371	u:0.092	x:0.413	v:6.283	current decay
# t:85 I:2.113	g:0.336	u:0.086	x:0.414	v:6.288	current decay
# t:86 I:1.918	g:0.305	u:0.081	x:0.416	v:6.293	current decay
# t:87 I:1.740	g:0.276	u:0.077	x:0.417	v:6.298	current decay
# t:88 I:1.579	g:0.250	u:0.072	x:0.418	v:6.302	current decay
# t:89 I:1.432	g:0.227	u:0.068	x:0.420	v:6.307	current decay
# t:90 I:1.299	g:0.206	u:0.064	x:0.421	v:6.311	current decay
# t:91 I:1.179	g:0.187	u:0.060	x:0.422	v:6.315	current decay
# t:92 I:1.179	g:1.943	u:0.299	x:0.299	v:6.319	synaptic spike
# t:92 I:12.281	g:1.943	u:0.299	x:0.299	v:6.319	current decay
# t:93 I:11.089	g:1.762	u:0.281	x:0.300	v:6.293	current decay
# t:94 I:10.020	g:1.597	u:0.265	x:0.302	v:6.272	current decay
# t:95 I:9.059	g:1.448	u:0.250	x:0.303	v:6.255	current decay
# t:96 I:8.195	g:1.313	u:0.235	x:0.305	v:6.240	current decay
# t:97 I:7.416	g:1.191	u:0.221	x:0.307	v:6.229	current decay
# t:98 I:6.714	g:1.079	u:0.208	x:0.308	v:6.220	current decay
# t:99 I:6.081	g:0.979	u:0.196	x:0.310	v:6.214	current decay
# t:100 I:5.509	g:0.887	u:0.185	x:0.311	v:6.209	current decay
# t:101 I:4.992	g:0.804	u:0.174	x:0.313	v:6.205	current decay
# t:102 I:4.524	g:0.729	u:0.164	x:0.314	v:6.203	current decay
# t:103 I:4.101	g:0.661	u:0.155	x:0.316	v:6.202	current decay
# t:104 I:3.718	g:0.599	u:0.146	x:0.318	v:6.202	current decay
# t:105 I:3.371	g:0.544	u:0.137	x:0.319	v:6.202	current decay
# t:106 I:3.057	g:0.493	u:0.129	x:0.321	v:6.203	current decay
# t:107 I:2.772	g:0.447	u:0.122	x:0.322	v:6.205	current decay
# t:108 I:2.514	g:0.405	u:0.115	x:0.324	v:6.206	current decay
# t:109 I:2.280	g:0.367	u:0.108	x:0.325	v:6.208	current decay
# t:110 I:2.068	g:0.333	u:0.102	x:0.327	v:6.211	current decay
# t:111 I:1.875	g:0.302	u:0.096	x:0.328	v:6.213	current decay
# t:112 I:1.701	g:0.274	u:0.090	x:0.330	v:6.215	current decay
# t:113 I:1.543	g:0.248	u:0.085	x:0.332	v:6.218	current decay
# t:114 I:1.399	g:0.225	u:0.080	x:0.333	v:6.220	current decay
# t:115 I:1.269	g:0.204	u:0.075	x:0.335	v:6.222	current decay
# t:116 I:1.151	g:0.185	u:0.071	x:0.336	v:6.224	current decay
# t:117 I:1.044	g:0.168	u:0.067	x:0.338	v:6.226	current decay
# t:118 I:0.947	g:0.152	u:0.063	x:0.339	v:6.228	current decay
# t:119 I:0.859	g:0.138	u:0.059	x:0.341	v:6.230	current decay
# t:120 I:0.779	g:0.125	u:0.056	x:0.342	v:6.232	current decay
# t:121 I:0.706	g:0.113	u:0.053	x:0.344	v:6.233	current decay
# t:122 I:0.640	g:0.103	u:0.050	x:0.345	v:6.235	current decay
# t:123 I:0.581	g:0.093	u:0.047	x:0.347	v:6.236	current decay
# t:124 I:0.581	g:1.500	u:0.290	x:0.249	v:6.237	synaptic spike
# t:124 I:9.354	g:1.500	u:0.290	x:0.249	v:6.237	current decay
# t:125 I:8.450	g:1.360	u:0.273	x:0.251	v:6.214	current decay
# t:126 I:7.638	g:1.233	u:0.257	x:0.252	v:6.195	current decay
# t:127 I:6.907	g:1.118	u:0.242	x:0.254	v:6.180	current decay
# t:128 I:6.249	g:1.013	u:0.228	x:0.256	v:6.166	current decay
# t:129 I:5.655	g:0.919	u:0.215	x:0.257	v:6.155	current decay
# t:130 I:5.120	g:0.833	u:0.202	x:0.259	v:6.146	current decay
# t:131 I:4.636	g:0.755	u:0.191	x:0.261	v:6.139	current decay
# t:132 I:4.199	g:0.685	u:0.180	x:0.262	v:6.133	current decay
# t:133 I:3.804	g:0.621	u:0.169	x:0.264	v:6.129	current decay
# t:134 I:3.447	g:0.563	u:0.159	x:0.266	v:6.125	current decay
# t:135 I:3.124	g:0.510	u:0.150	x:0.268	v:6.122	current decay
# t:136 I:2.831	g:0.463	u:0.141	x:0.269	v:6.120	current decay
# t:137 I:2.566	g:0.419	u:0.133	x:0.271	v:6.119	current decay
# t:138 I:2.326	g:0.380	u:0.125	x:0.273	v:6.118	current decay
# t:139 I:2.109	g:0.345	u:0.118	x:0.274	v:6.117	current decay
# t:140 I:1.912	g:0.313	u:0.111	x:0.276	v:6.117	current decay
# t:141 I:1.733	g:0.283	u:0.105	x:0.278	v:6.116	current decay
# t:142 I:1.572	g:0.257	u:0.099	x:0.279	v:6.116	current decay
# t:143 I:1.425	g:0.233	u:0.093	x:0.281	v:6.117	current decay
# t:144 I:1.292	g:0.211	u:0.087	x:0.283	v:6.117	current decay
# t:145 I:1.171	g:0.191	u:0.082	x:0.284	v:6.117	current decay
# t:146 I:1.062	g:0.174	u:0.078	x:0.286	v:6.117	current decay
# t:147 I:0.963	g:0.157	u:0.073	x:0.287	v:6.117	current decay
# t:148 I:0.873	g:0.143	u:0.069	x:0.289	v:6.118	current decay
# t:149 I:0.792	g:0.129	u:0.065	x:0.291	v:6.118	current decay
# t:150 I:0.718	g:0.117	u:0.061	x:0.292	v:6.118	current decay
# t:151 I:0.651	g:0.106	u:0.058	x:0.294	v:6.117	current decay
# t:152 I:0.590	g:0.096	u:0.054	x:0.296	v:6.117	current decay
# t:153 I:0.535	g:0.087	u:0.051	x:0.297	v:6.117	current decay
# t:154 I:0.485	g:0.079	u:0.048	x:0.299	v:6.116	current decay
# t:155 I:0.439	g:0.072	u:0.045	x:0.300	v:6.116	current decay
# t:156 I:0.398	g:0.065	u:0.043	x:0.302	v:6.115	current decay
# t:157 I:0.361	g:0.059	u:0.040	x:0.304	v:6.114	current decay
# t:158 I:0.327	g:0.054	u:0.038	x:0.305	v:6.113	current decay
# t:159 I:0.327	g:1.271	u:0.284	x:0.221	v:6.112	synaptic spike
# t:159 I:7.770	g:1.271	u:0.284	x:0.221	v:6.112	current decay
# t:160 I:7.020	g:1.153	u:0.268	x:0.223	v:6.091	current decay
# t:161 I:6.346	g:1.045	u:0.252	x:0.225	v:6.073	current decay
# t:162 I:5.739	g:0.947	u:0.237	x:0.227	v:6.058	current decay
# t:163 I:5.192	g:0.859	u:0.224	x:0.228	v:6.045	current decay
# t:164 I:4.699	g:0.779	u:0.211	x:0.230	v:6.034	current decay
# t:165 I:4.254	g:0.706	u:0.198	x:0.232	v:6.025	current decay
# t:166 I:3.851	g:0.640	u:0.187	x:0.234	v:6.017	current decay
# t:167 I:3.488	g:0.580	u:0.176	x:0.235	v:6.010	current decay
# t:168 I:3.159	g:0.526	u:0.166	x:0.237	v:6.004	current decay
# t:169 I:2.862	g:0.477	u:0.156	x:0.239	v:6.000	current decay
# t:170 I:2.593	g:0.433	u:0.147	x:0.241	v:5.996	current decay
# t:171 I:2.350	g:0.392	u:0.139	x:0.242	v:5.992	current decay
# t:172 I:2.129	g:0.356	u:0.130	x:0.244	v:5.989	current decay
# t:173 I:1.930	g:0.322	u:0.123	x:0.246	v:5.987	current decay
# t:174 I:1.749	g:0.292	u:0.116	x:0.248	v:5.985	current decay
# t:175 I:1.585	g:0.265	u:0.109	x:0.249	v:5.983	current decay
# t:176 I:1.437	g:0.240	u:0.103	x:0.251	v:5.981	current decay
# t:177 I:1.302	g:0.218	u:0.097	x:0.253	v:5.979	current decay
# t:178 I:1.180	g:0.197	u:0.091	x:0.254	v:5.978	current decay
# t:179 I:1.070	g:0.179	u:0.086	x:0.256	v:5.977	current decay
# t:180 I:0.970	g:0.162	u:0.081	x:0.258	v:5.975	current decay
# t:181 I:0.879	g:0.147	u:0.076	x:0.260	v:5.974	current decay
# t:182 I:0.797	g:0.133	u:0.072	x:0.261	v:5.973	current decay
# t:183 I:0.722	g:0.121	u:0.068	x:0.263	v:5.971	current decay
# t:184 I:0.655	g:0.110	u:0.064	x:0.265	v:5.970	current decay
# t:185 I:0.593	g:0.099	u:0.060	x:0.266	v:5.968	current decay
# t:186 I:0.538	g:0.090	u:0.056	x:0.268	v:5.967	current decay
# t:187 I:0.488	g:0.082	u:0.053	x:0.270	v:5.965	current decay
# t:188 I:0.442	g:0.074	u:0.050	x:0.271	v:5.963	current decay
# t:189 I:0.400	g:0.067	u:0.047	x:0.273	v:5.961	current decay
# t:190 I:0.363	g:0.061	u:0.044	x:0.275	v:5.959	current decay
# t:191 I:0.329	g:0.055	u:0.042	x:0.276	v:5.957	current decay
# t:192 I:0.298	g:0.050	u:0.039	x:0.278	v:5.955	current decay
# t:193 I:0.270	g:0.045	u:0.037	x:0.280	v:5.953	current decay
# t:194 I:0.245	g:0.041	u:0.035	x:0.281	v:5.950	current decay
# t:195 I:0.222	g:0.037	u:0.033	x:0.283	v:5.948	current decay
# t:196 I:0.201	g:0.034	u:0.031	x:0.285	v:5.945	current decay
# t:197 I:0.201	g:1.154	u:0.280	x:0.208	v:5.943	synaptic spike
# t:197 I:6.858	g:1.154	u:0.280	x:0.208	v:5.943	current decay
# t:198 I:6.196	g:1.046	u:0.264	x:0.210	v:5.922	current decay
# t:199 I:5.601	g:0.949	u:0.248	x:0.211	v:5.904	current decay
# t:200 I:5.065	g:0.860	u:0.234	x:0.213	v:5.889	current decay
# t:201 I:4.581	g:0.780	u:0.220	x:0.215	v:5.876	current decay
# t:202 I:4.146	g:0.707	u:0.207	x:0.217	v:5.864	current decay
# t:203 I:3.752	g:0.641	u:0.195	x:0.219	v:5.854	current decay
# t:204 I:3.397	g:0.581	u:0.184	x:0.220	v:5.846	current decay
# t:205 I:3.076	g:0.527	u:0.173	x:0.222	v:5.838	current decay
# t:206 I:2.785	g:0.478	u:0.163	x:0.224	v:5.831	current decay
# t:207 I:2.523	g:0.433	u:0.154	x:0.226	v:5.826	current decay
# t:208 I:2.285	g:0.393	u:0.145	x:0.228	v:5.820	current decay
# t:209 I:2.070	g:0.356	u:0.136	x:0.229	v:5.816	current decay
# t:210 I:1.876	g:0.323	u:0.128	x:0.231	v:5.812	current decay
# t:211 I:1.699	g:0.293	u:0.121	x:0.233	v:5.808	current decay
# t:212 I:1.540	g:0.265	u:0.114	x:0.235	v:5.804	current decay
# t:213 I:1.395	g:0.241	u:0.107	x:0.236	v:5.801	current decay
# t:214 I:1.264	g:0.218	u:0.101	x:0.238	v:5.798	current decay
# t:215 I:1.146	g:0.198	u:0.095	x:0.240	v:5.795	current decay
# t:216 I:1.038	g:0.179	u:0.090	x:0.242	v:5.792	current decay
# t:217 I:0.941	g:0.163	u:0.084	x:0.243	v:5.790	current decay
# t:218 I:0.853	g:0.147	u:0.080	x:0.245	v:5.787	current decay
# t:219 I:0.773	g:0.134	u:0.075	x:0.247	v:5.784	current decay
# t:220 I:0.700	g:0.121	u:0.071	x:0.249	v:5.782	current decay
# t:221 I:0.635	g:0.110	u:0.066	x:0.250	v:5.779	current decay
# t:222 I:0.575	g:0.100	u:0.063	x:0.252	v:5.776	current decay
# t:223 I:0.521	g:0.090	u:0.059	x:0.254	v:5.773	current decay
# t:224 I:0.472	g:0.082	u:0.056	x:0.255	v:5.770	current decay
# t:225 I:0.428	g:0.074	u:0.052	x:0.257	v:5.767	current decay
# t:226 I:0.388	g:0.067	u:0.049	x:0.259	v:5.764	current decay
# t:227 I:0.351	g:0.061	u:0.046	x:0.261	v:5.761	current decay
# t:228 I:0.318	g:0.055	u:0.044	x:0.262	v:5.758	current decay
# t:229 I:0.288	g:0.050	u:0.041	x:0.264	v:5.754	current decay
# t:230 I:0.261	g:0.045	u:0.039	x:0.266	v:5.751	current decay
# t:231 I:0.237	g:0.041	u:0.037	x:0.267	v:5.747	current decay
# t:232 I:0.215	g:0.037	u:0.034	x:0.269	v:5.744	current decay
# t:233 I:0.194	g:0.034	u:0.032	x:0.271	v:5.740	current decay
# t:234 I:0.176	g:0.031	u:0.031	x:0.272	v:5.736	current decay
# t:235 I:0.160	g:0.028	u:0.029	x:0.274	v:5.732	current decay
# t:236 I:0.145	g:0.025	u:0.027	x:0.276	v:5.728	current decay
# t:237 I:0.131	g:0.023	u:0.025	x:0.277	v:5.724	current decay
# t:238 I:0.119	g:0.021	u:0.024	x:0.279	v:5.720	current decay
# t:239 I:0.119	g:1.102	u:0.275	x:0.205	v:5.715	synaptic spike
# t:239 I:6.301	g:1.102	u:0.275	x:0.205	v:5.715	current decay
# t:240 I:5.692	g:1.000	u:0.259	x:0.207	v:5.694	current decay
# t:241 I:5.144	g:0.906	u:0.244	x:0.209	v:5.676	current decay
# t:242 I:4.650	g:0.822	u:0.230	x:0.211	v:5.660	current decay
# t:243 I:4.206	g:0.745	u:0.217	x:0.212	v:5.646	current decay
# t:244 I:3.805	g:0.675	u:0.204	x:0.214	v:5.634	current decay
# t:245 I:3.443	g:0.612	u:0.192	x:0.216	v:5.623	current decay
# t:246 I:3.116	g:0.555	u:0.181	x:0.218	v:5.613	current decay
# t:247 I:2.821	g:0.503	u:0.171	x:0.220	v:5.604	current decay
# t:248 I:2.554	g:0.456	u:0.161	x:0.221	v:5.597	current decay
# t:249 I:2.312	g:0.414	u:0.151	x:0.223	v:5.589	current decay
# t:250 I:2.094	g:0.375	u:0.142	x:0.225	v:5.583	current decay
# t:251 I:1.897	g:0.340	u:0.134	x:0.227	v:5.577	current decay
# t:252 I:1.718	g:0.308	u:0.126	x:0.228	v:5.572	current decay
# t:253 I:1.556	g:0.280	u:0.119	x:0.230	v:5.566	current decay
# t:254 I:1.409	g:0.253	u:0.112	x:0.232	v:5.562	current decay
# t:255 I:1.277	g:0.230	u:0.106	x:0.234	v:5.557	current decay
# t:256 I:1.157	g:0.208	u:0.099	x:0.236	v:5.553	current decay
# t:257 I:1.048	g:0.189	u:0.094	x:0.237	v:5.548	current decay
# t:258 I:0.949	g:0.171	u:0.088	x:0.239	v:5.544	current decay
# t:259 I:0.860	g:0.155	u:0.083	x:0.241	v:5.540	current decay
# t:260 I:0.779	g:0.141	u:0.078	x:0.243	v:5.536	current decay
# t:261 I:0.706	g:0.128	u:0.074	x:0.244	v:5.531	current decay
# t:262 I:0.640	g:0.116	u:0.069	x:0.246	v:5.527	current decay
# t:263 I:0.579	g:0.105	u:0.065	x:0.248	v:5.523	current decay
# t:264 I:0.525	g:0.095	u:0.062	x:0.249	v:5.519	current decay
# t:265 I:0.475	g:0.086	u:0.058	x:0.251	v:5.514	current decay
# t:266 I:0.431	g:0.078	u:0.055	x:0.253	v:5.510	current decay
# t:267 I:0.390	g:0.071	u:0.051	x:0.255	v:5.506	current decay
# t:268 I:0.354	g:0.064	u:0.048	x:0.256	v:5.501	current decay
# t:269 I:0.320	g:0.058	u:0.046	x:0.258	v:5.496	current decay
# t:270 I:0.290	g:0.053	u:0.043	x:0.260	v:5.492	current decay
# t:271 I:0.263	g:0.048	u:0.040	x:0.261	v:5.487	current decay
# t:272 I:0.238	g:0.043	u:0.038	x:0.263	v:5.482	current decay
# t:273 I:0.216	g:0.039	u:0.036	x:0.265	v:5.477	current decay
# t:274 I:0.195	g:0.036	u:0.034	x:0.266	v:5.472	current decay
# t:275 I:0.177	g:0.032	u:0.032	x:0.268	v:5.467	current decay
# t:276 I:0.160	g:0.029	u:0.030	x:0.270	v:5.462	current decay
# t:277 I:0.145	g:0.027	u:0.028	x:0.272	v:5.456	current decay
# t:278 I:0.131	g:0.024	u:0.027	x:0.273	v:5.451	current decay
# t:279 I:0.119	g:0.022	u:0.025	x:0.275	v:5.445	current decay
# t:280 I:0.108	g:0.020	u:0.024	x:0.277	v:5.439	current decay
# t:281 I:0.098	g:0.018	u:0.022	x:0.278	v:5.434	current decay
# t:282 I:0.088	g:0.016	u:0.021	x:0.280	v:5.428	current decay
# t:283 I:0.088	g:1.094	u:0.273	x:0.206	v:5.422	synaptic spike
# t:283 I:5.930	g:1.094	u:0.273	x:0.206	v:5.422	current decay
# t:284 I:5.355	g:0.992	u:0.257	x:0.208	v:5.401	current decay
# t:285 I:4.838	g:0.899	u:0.243	x:0.210	v:5.382	current decay
# t:286 I:4.373	g:0.815	u:0.228	x:0.212	v:5.365	current decay
# t:287 I:3.953	g:0.739	u:0.215	x:0.213	v:5.350	current decay
# t:288 I:3.575	g:0.670	u:0.203	x:0.215	v:5.336	current decay
# t:289 I:3.234	g:0.607	u:0.191	x:0.217	v:5.324	current decay
# t:290 I:2.926	g:0.551	u:0.180	x:0.219	v:5.313	current decay
# t:291 I:2.648	g:0.499	u:0.169	x:0.221	v:5.303	current decay
# t:292 I:2.397	g:0.453	u:0.159	x:0.222	v:5.294	current decay
# t:293 I:2.169	g:0.410	u:0.150	x:0.224	v:5.286	current decay
# t:294 I:1.964	g:0.372	u:0.141	x:0.226	v:5.278	current decay
# t:295 I:1.778	g:0.337	u:0.133	x:0.228	v:5.271	current decay
# t:296 I:1.610	g:0.306	u:0.125	x:0.230	v:5.264	current decay
# t:297 I:1.458	g:0.277	u:0.118	x:0.231	v:5.257	current decay
# t:298 I:1.320	g:0.251	u:0.111	x:0.233	v:5.251	current decay
# t:299 I:1.196	g:0.228	u:0.105	x:0.235	v:5.245	current decay
# t:300 I:1.083	g:0.207	u:0.099	x:0.237	v:5.239	current decay
# t:301 I:0.981	g:0.187	u:0.093	x:0.238	v:5.233	current decay
# t:302 I:0.888	g:0.170	u:0.088	x:0.240	v:5.227	current decay
# t:303 I:0.804	g:0.154	u:0.083	x:0.242	v:5.221	current decay
# t:304 I:0.728	g:0.140	u:0.078	x:0.244	v:5.216	current decay
# t:305 I:0.660	g:0.127	u:0.073	x:0.245	v:5.210	current decay
# t:306 I:0.597	g:0.115	u:0.069	x:0.247	v:5.204	current decay
# t:307 I:0.541	g:0.104	u:0.065	x:0.249	v:5.198	current decay
# t:308 I:0.490	g:0.094	u:0.061	x:0.250	v:5.193	current decay
# t:309 I:0.444	g:0.086	u:0.058	x:0.252	v:5.187	current decay
# t:310 I:0.402	g:0.078	u:0.054	x:0.254	v:5.181	current decay
# t:311 I:0.364	g:0.070	u:0.051	x:0.256	v:5.175	current decay
# t:312 I:0.330	g:0.064	u:0.048	x:0.257	v:5.169	current decay
# t:313 I:0.298	g:0.058	u:0.045	x:0.259	v:5.162	current decay
# t:314 I:0.270	g:0.052	u:0.043	x:0.261	v:5.156	current decay
# t:315 I:0.245	g:0.048	u:0.040	x:0.262	v:5.150	current decay
# t:316 I:0.222	g:0.043	u:0.038	x:0.264	v:5.143	current decay
# t:317 I:0.201	g:0.039	u:0.036	x:0.266	v:5.137	current decay
# t:318 I:0.182	g:0.035	u:0.034	x:0.268	v:5.130	current decay
# t:319 I:0.164	g:0.032	u:0.032	x:0.269	v:5.123	current decay
# t:320 I:0.149	g:0.029	u:0.030	x:0.271	v:5.116	current decay
# t:321 I:0.135	g:0.026	u:0.028	x:0.273	v:5.109	current decay
# t:322 I:0.122	g:0.024	u:0.026	x:0.274	v:5.102	current decay
# t:323 I:0.111	g:0.022	u:0.025	x:0.276	v:5.095	current decay
# t:324 I:0.100	g:0.020	u:0.023	x:0.278	v:5.088	current decay
# t:325 I:0.091	g:0.018	u:0.022	x:0.279	v:5.081	current decay
# t:326 I:0.082	g:0.016	u:0.021	x:0.281	v:5.073	current decay
# t:327 I:0.074	g:0.015	u:0.020	x:0.282	v:5.066	current decay
# t:328 I:0.067	g:0.013	u:0.018	x:0.284	v:5.058	current decay
# t:329 I:0.061	g:0.012	u:0.017	x:0.286	v:5.051	current decay
# t:330 I:0.061	g:1.103	u:0.271	x:0.211	v:5.043	synaptic spike
# t:330 I:5.564	g:1.103	u:0.271	x:0.211	v:5.043	current decay
# t:331 I:5.022	g:1.000	u:0.255	x:0.213	v:5.020	current decay
# t:332 I:4.535	g:0.907	u:0.240	x:0.215	v:5.000	current decay
# t:333 I:4.097	g:0.822	u:0.226	x:0.217	v:4.982	current decay
# t:334 I:3.702	g:0.746	u:0.213	x:0.218	v:4.966	current decay
# t:335 I:3.347	g:0.676	u:0.201	x:0.220	v:4.952	current decay
# t:336 I:3.026	g:0.613	u:0.189	x:0.222	v:4.938	current decay
# t:337 I:2.737	g:0.556	u:0.178	x:0.224	v:4.926	current decay
# t:338 I:2.475	g:0.504	u:0.168	x:0.226	v:4.914	current decay
# t:339 I:2.239	g:0.457	u:0.158	x:0.227	v:4.904	current decay
# t:340 I:2.026	g:0.414	u:0.149	x:0.229	v:4.894	current decay
# t:341 I:1.834	g:0.375	u:0.140	x:0.231	v:4.884	current decay
# t:342 I:1.659	g:0.340	u:0.132	x:0.233	v:4.875	current decay
# t:343 I:1.502	g:0.309	u:0.124	x:0.234	v:4.867	current decay
# t:344 I:1.359	g:0.280	u:0.117	x:0.236	v:4.858	current decay
# t:345 I:1.230	g:0.254	u:0.110	x:0.238	v:4.850	current decay
# t:346 I:1.114	g:0.230	u:0.104	x:0.240	v:4.842	current decay
# t:347 I:1.008	g:0.208	u:0.098	x:0.241	v:4.835	current decay
# t:348 I:0.912	g:0.189	u:0.092	x:0.243	v:4.827	current decay
# t:349 I:0.826	g:0.171	u:0.087	x:0.245	v:4.819	current decay
# t:350 I:0.748	g:0.155	u:0.082	x:0.247	v:4.812	current decay
# t:351 I:0.677	g:0.141	u:0.077	x:0.248	v:4.804	current decay
# t:352 I:0.613	g:0.128	u:0.073	x:0.250	v:4.797	current decay
# t:353 I:0.555	g:0.116	u:0.068	x:0.252	v:4.789	current decay
# t:354 I:0.502	g:0.105	u:0.064	x:0.253	v:4.781	current decay
# t:355 I:0.454	g:0.095	u:0.061	x:0.255	v:4.774	current decay
# t:356 I:0.411	g:0.086	u:0.057	x:0.257	v:4.766	current decay
# t:357 I:0.372	g:0.078	u:0.054	x:0.259	v:4.758	current decay
# t:358 I:0.337	g:0.071	u:0.051	x:0.260	v:4.750	current decay
# t:359 I:0.305	g:0.064	u:0.048	x:0.262	v:4.742	current decay
# t:360 I:0.276	g:0.058	u:0.045	x:0.264	v:4.734	current decay
# t:361 I:0.250	g:0.053	u:0.042	x:0.265	v:4.726	current decay
# t:362 I:0.226	g:0.048	u:0.040	x:0.267	v:4.718	current decay
# t:363 I:0.205	g:0.043	u:0.038	x:0.269	v:4.710	current decay
# t:364 I:0.185	g:0.039	u:0.035	x:0.270	v:4.701	current decay
# t:365 I:0.168	g:0.036	u:0.033	x:0.272	v:4.693	current decay
# t:366 I:0.152	g:0.032	u:0.031	x:0.274	v:4.684	current decay
# t:367 I:0.137	g:0.029	u:0.030	x:0.275	v:4.675	current decay
# t:368 I:0.124	g:0.027	u:0.028	x:0.277	v:4.666	current decay
# t:369 I:0.112	g:0.024	u:0.026	x:0.279	v:4.657	current decay
# t:370 I:0.102	g:0.022	u:0.025	x:0.280	v:4.648	current decay
# t:371 I:0.092	g:0.020	u:0.023	x:0.282	v:4.639	current decay
# t:372 I:0.083	g:0.018	u:0.022	x:0.284	v:4.630	current decay
# t:373 I:0.075	g:0.016	u:0.021	x:0.285	v:4.621	current decay
# t:374 I:0.068	g:0.015	u:0.019	x:0.287	v:4.612	current decay
# t:375 I:0.062	g:0.013	u:0.018	x:0.289	v:4.602	current decay
# t:376 I:0.056	g:0.012	u:0.017	x:0.290	v:4.593	current decay
# t:377 I:0.050	g:0.011	u:0.016	x:0.292	v:4.583	current decay
# t:378 I:0.050	g:1.123	u:0.270	x:0.216	v:4.573	synaptic spike
# t:378 I:5.134	g:1.123	u:0.270	x:0.216	v:4.573	current decay
# t:379 I:4.631	g:1.018	u:0.255	x:0.218	v:4.550	current decay
# t:380 I:4.179	g:0.923	u:0.240	x:0.219	v:4.529	current decay
# t:381 I:3.773	g:0.837	u:0.226	x:0.221	v:4.510	current decay
# t:382 I:3.407	g:0.758	u:0.213	x:0.223	v:4.493	current decay
# t:383 I:3.078	g:0.688	u:0.200	x:0.225	v:4.477	current decay
# t:384 I:2.782	g:0.623	u:0.189	x:0.227	v:4.462	current decay
# t:385 I:2.514	g:0.565	u:0.178	x:0.228	v:4.448	current decay
# t:386 I:2.273	g:0.512	u:0.167	x:0.230	v:4.435	current decay
# t:387 I:2.055	g:0.465	u:0.158	x:0.232	v:4.423	current decay
# t:388 I:1.858	g:0.421	u:0.149	x:0.234	v:4.411	current decay
# t:389 I:1.680	g:0.382	u:0.140	x:0.235	v:4.400	current decay
# t:390 I:1.520	g:0.346	u:0.132	x:0.237	v:4.389	current decay
# t:391 I:1.375	g:0.314	u:0.124	x:0.239	v:4.378	current decay
# t:392 I:1.243	g:0.285	u:0.117	x:0.241	v:4.368	current decay
# t:393 I:1.125	g:0.258	u:0.110	x:0.242	v:4.358	current decay
# t:394 I:1.017	g:0.234	u:0.104	x:0.244	v:4.348	current decay
# t:395 I:0.920	g:0.212	u:0.098	x:0.246	v:4.339	current decay
# t:396 I:0.833	g:0.192	u:0.092	x:0.248	v:4.329	current decay
# t:397 I:0.753	g:0.174	u:0.087	x:0.249	v:4.319	current decay
# t:398 I:0.681	g:0.158	u:0.082	x:0.251	v:4.310	current decay
# t:399 I:0.616	g:0.143	u:0.077	x:0.253	v:4.300	current decay
# t:400 I:0.558	g:0.130	u:0.072	x:0.254	v:4.291	current decay
# t:401 I:0.504	g:0.118	u:0.068	x:0.256	v:4.281	current decay
# t:402 I:0.456	g:0.107	u:0.064	x:0.258	v:4.272	current decay
# t:403 I:0.413	g:0.097	u:0.060	x:0.260	v:4.262	current decay
# t:404 I:0.373	g:0.088	u:0.057	x:0.261	v:4.252	current decay
# t:405 I:0.338	g:0.080	u:0.054	x:0.263	v:4.242	current decay
# t:406 I:0.305	g:0.072	u:0.051	x:0.265	v:4.232	current decay
# t:407 I:0.276	g:0.065	u:0.048	x:0.266	v:4.222	current decay
# t:408 I:0.250	g:0.059	u:0.045	x:0.268	v:4.212	current decay
# t:409 I:0.226	g:0.054	u:0.042	x:0.270	v:4.202	current decay
# t:410 I:0.204	g:0.049	u:0.040	x:0.271	v:4.192	current decay
# t:411 I:0.185	g:0.044	u:0.037	x:0.273	v:4.181	current decay
# t:412 I:0.167	g:0.040	u:0.035	x:0.275	v:4.171	current decay
# t:413 I:0.151	g:0.036	u:0.033	x:0.276	v:4.160	current decay
# t:414 I:0.137	g:0.033	u:0.031	x:0.278	v:4.149	current decay
# t:415 I:0.124	g:0.030	u:0.029	x:0.280	v:4.139	current decay
# t:416 I:0.112	g:0.027	u:0.028	x:0.281	v:4.128	current decay
# t:417 I:0.101	g:0.025	u:0.026	x:0.283	v:4.117	current decay
# t:418 I:0.091	g:0.022	u:0.025	x:0.285	v:4.106	current decay
# t:419 I:0.083	g:0.020	u:0.023	x:0.286	v:4.095	current decay
# t:420 I:0.075	g:0.018	u:0.022	x:0.288	v:4.083	current decay
# t:421 I:0.068	g:0.017	u:0.021	x:0.290	v:4.072	current decay
# t:422 I:0.061	g:0.015	u:0.019	x:0.291	v:4.061	current decay
# t:423 I:0.055	g:0.014	u:0.018	x:0.293	v:4.049	current decay
# t:424 I:0.050	g:0.012	u:0.017	x:0.294	v:4.038	current decay
# t:425 I:0.045	g:0.011	u:0.016	x:0.296	v:4.026	current decay
# t:426 I:0.045	g:1.138	u:0.270	x:0.219	v:4.014	synaptic spike
# t:426 I:4.569	g:1.138	u:0.270	x:0.219	v:4.014	current decay
# t:427 I:4.118	g:1.032	u:0.255	x:0.221	v:3.991	current decay
# t:428 I:3.714	g:0.936	u:0.240	x:0.222	v:3.969	current decay
# t:429 I:3.350	g:0.848	u:0.226	x:0.224	v:3.949	current decay
# t:430 I:3.023	g:0.769	u:0.213	x:0.226	v:3.930	current decay
# t:431 I:2.729	g:0.697	u:0.200	x:0.228	v:3.913	current decay
# t:432 I:2.463	g:0.632	u:0.189	x:0.230	v:3.897	current decay
# t:433 I:2.225	g:0.573	u:0.178	x:0.231	v:3.881	current decay
# t:434 I:2.009	g:0.520	u:0.167	x:0.233	v:3.867	current decay
# t:435 I:1.815	g:0.471	u:0.158	x:0.235	v:3.853	current decay
# t:436 I:1.640	g:0.427	u:0.149	x:0.237	v:3.839	current decay
# t:437 I:1.482	g:0.387	u:0.140	x:0.238	v:3.826	current decay
# t:438 I:1.339	g:0.351	u:0.132	x:0.240	v:3.813	current decay
# t:439 I:1.210	g:0.318	u:0.124	x:0.242	v:3.801	current decay
# t:440 I:1.094	g:0.289	u:0.117	x:0.244	v:3.789	current decay
# t:441 I:0.988	g:0.262	u:0.110	x:0.245	v:3.777	current decay
# t:442 I:0.893	g:0.237	u:0.104	x:0.247	v:3.765	current decay
# t:443 I:0.807	g:0.215	u:0.098	x:0.249	v:3.753	current decay
# t:444 I:0.730	g:0.195	u:0.092	x:0.250	v:3.741	current decay
# t:445 I:0.659	g:0.177	u:0.087	x:0.252	v:3.730	current decay
# t:446 I:0.596	g:0.160	u:0.082	x:0.254	v:3.718	current decay
# t:447 I:0.539	g:0.145	u:0.077	x:0.256	v:3.706	current decay
# t:448 I:0.487	g:0.132	u:0.072	x:0.257	v:3.695	current decay
# t:449 I:0.440	g:0.119	u:0.068	x:0.259	v:3.683	current decay
# t:450 I:0.398	g:0.108	u:0.064	x:0.261	v:3.671	current decay
# t:451 I:0.359	g:0.098	u:0.060	x:0.262	v:3.659	current decay
# t:452 I:0.325	g:0.089	u:0.057	x:0.264	v:3.647	current decay
# t:453 I:0.293	g:0.081	u:0.054	x:0.266	v:3.635	current decay
# t:454 I:0.265	g:0.073	u:0.051	x:0.267	v:3.623	current decay
# t:455 I:0.240	g:0.066	u:0.048	x:0.269	v:3.611	current decay
# t:456 I:0.216	g:0.060	u:0.045	x:0.271	v:3.599	current decay
# t:457 I:0.196	g:0.055	u:0.042	x:0.273	v:3.586	current decay
# t:458 I:0.177	g:0.049	u:0.040	x:0.274	v:3.574	current decay
# t:459 I:0.160	g:0.045	u:0.037	x:0.276	v:3.561	current decay
# t:460 I:0.144	g:0.041	u:0.035	x:0.277	v:3.548	current decay
# t:461 I:0.130	g:0.037	u:0.033	x:0.279	v:3.536	current decay
# t:462 I:0.118	g:0.033	u:0.031	x:0.281	v:3.523	current decay
# t:463 I:0.106	g:0.030	u:0.029	x:0.282	v:3.510	current decay
# t:464 I:0.096	g:0.027	u:0.028	x:0.284	v:3.497	current decay
# t:465 I:0.087	g:0.025	u:0.026	x:0.286	v:3.484	current decay
# t:466 I:0.078	g:0.023	u:0.025	x:0.287	v:3.471	current decay
# t:467 I:0.071	g:0.020	u:0.023	x:0.289	v:3.457	current decay
# t:468 I:0.064	g:0.019	u:0.022	x:0.291	v:3.444	current decay
# t:469 I:0.058	g:0.017	u:0.021	x:0.292	v:3.431	current decay
# t:470 I:0.052	g:0.015	u:0.019	x:0.294	v:3.417	current decay
# t:471 I:0.047	g:0.014	u:0.018	x:0.296	v:3.403	current decay
# t:472 I:0.043	g:0.013	u:0.017	x:0.297	v:3.390	current decay
# t:473 I:0.038	g:0.011	u:0.016	x:0.299	v:3.376	current decay
# t:474 I:0.035	g:0.010	u:0.015	x:0.300	v:3.362	current decay
# t:475 I:0.031	g:0.009	u:0.014	x:0.302	v:3.348	current decay
# t:476 I:0.031	g:1.154	u:0.269	x:0.223	v:3.334	synaptic spike
# t:476 I:3.848	g:1.154	u:0.269	x:0.223	v:3.334	current decay
# t:477 I:3.464	g:1.046	u:0.253	x:0.225	v:3.310	current decay
# t:478 I:3.119	g:0.949	u:0.239	x:0.227	v:3.288	current decay
# t:479 I:2.810	g:0.860	u:0.225	x:0.229	v:3.267	current decay
# t:480 I:2.532	g:0.780	u:0.212	x:0.231	v:3.247	current decay
# t:481 I:2.283	g:0.707	u:0.199	x:0.232	v:3.229	current decay
# t:482 I:2.058	g:0.641	u:0.188	x:0.234	v:3.211	current decay
# t:483 I:1.856	g:0.581	u:0.177	x:0.236	v:3.194	current decay
# t:484 I:1.674	g:0.527	u:0.167	x:0.238	v:3.178	current decay
# t:485 I:1.510	g:0.478	u:0.157	x:0.239	v:3.162	current decay
# t:486 I:1.363	g:0.433	u:0.148	x:0.241	v:3.147	current decay
# t:487 I:1.230	g:0.393	u:0.139	x:0.243	v:3.132	current decay
# t:488 I:1.110	g:0.356	u:0.131	x:0.245	v:3.117	current decay
# t:489 I:1.001	g:0.323	u:0.124	x:0.246	v:3.102	current decay
# t:490 I:0.904	g:0.293	u:0.116	x:0.248	v:3.088	current decay
# t:491 I:0.815	g:0.265	u:0.110	x:0.250	v:3.074	current decay
# t:492 I:0.736	g:0.241	u:0.103	x:0.251	v:3.060	current decay
# t:493 I:0.664	g:0.218	u:0.097	x:0.253	v:3.046	current decay
# t:494 I:0.599	g:0.198	u:0.092	x:0.255	v:3.032	current decay
# t:495 I:0.541	g:0.179	u:0.086	x:0.257	v:3.018	current decay
# t:496 I:0.488	g:0.163	u:0.081	x:0.258	v:3.004	current decay
# t:497 I:0.441	g:0.147	u:0.077	x:0.260	v:2.990	current decay
# t:498 I:0.398	g:0.134	u:0.072	x:0.262	v:2.976	current decay
# t:499 I:0.359	g:0.121	u:0.068	x:0.263	v:2.962	current decay
# t:500 I:0.324	g:0.110	u:0.064	x:0.265	v:2.948	current decay
# t:501 I:0.292	g:0.100	u:0.060	x:0.267	v:2.933	current decay
# t:502 I:0.263	g:0.090	u:0.057	x:0.268	v:2.919	current decay
# t:503 I:0.238	g:0.082	u:0.053	x:0.270	v:2.905	current decay
# t:504 I:0.214	g:0.074	u:0.050	x:0.272	v:2.890	current decay
# t:505 I:0.193	g:0.067	u:0.047	x:0.274	v:2.876	current decay
# t:506 I:0.174	g:0.061	u:0.045	x:0.275	v:2.861	current decay
# t:507 I:0.157	g:0.055	u:0.042	x:0.277	v:2.847	current decay
# t:508 I:0.142	g:0.050	u:0.040	x:0.279	v:2.832	current decay
# t:509 I:0.128	g:0.045	u:0.037	x:0.280	v:2.817	current decay
# t:510 I:0.115	g:0.041	u:0.035	x:0.282	v:2.802	current decay
# t:511 I:0.104	g:0.037	u:0.033	x:0.283	v:2.787	current decay
# t:512 I:0.094	g:0.034	u:0.031	x:0.285	v:2.772	current decay
# t:513 I:0.085	g:0.031	u:0.029	x:0.287	v:2.757	current decay
# t:514 I:0.076	g:0.028	u:0.028	x:0.288	v:2.741	current decay
# t:515 I:0.069	g:0.025	u:0.026	x:0.290	v:2.726	current decay
# t:516 I:0.062	g:0.023	u:0.025	x:0.292	v:2.711	current decay
# t:517 I:0.056	g:0.021	u:0.023	x:0.293	v:2.695	current decay
# t:518 I:0.050	g:0.019	u:0.022	x:0.295	v:2.680	current decay
# t:519 I:0.045	g:0.017	u:0.020	x:0.297	v:2.664	current decay
# t:520 I:0.041	g:0.015	u:0.019	x:0.298	v:2.648	current decay
# t:521 I:0.037	g:0.014	u:0.018	x:0.300	v:2.633	current decay
# t:522 I:0.033	g:0.013	u:0.017	x:0.301	v:2.617	current decay
# t:523 I:0.030	g:0.012	u:0.016	x:0.303	v:2.601	current decay
# t:524 I:0.027	g:0.010	u:0.015	x:0.305	v:2.585	current decay
# t:525 I:0.027	g:1.167	u:0.270	x:0.225	v:2.569	synaptic spike
# t:525 I:2.998	g:1.167	u:0.270	x:0.225	v:2.569	current decay
# t:526 I:2.693	g:1.058	u:0.254	x:0.227	v:2.545	current decay
# t:527 I:2.420	g:0.959	u:0.239	x:0.229	v:2.523	current decay
# t:528 I:2.175	g:0.870	u:0.225	x:0.230	v:2.501	current decay
# t:529 I:1.956	g:0.788	u:0.212	x:0.232	v:2.481	current decay
# t:530 I:1.759	g:0.715	u:0.200	x:0.234	v:2.461	current decay
# t:531 I:1.583	g:0.648	u:0.188	x:0.236	v:2.442	current decay
# t:532 I:1.424	g:0.588	u:0.177	x:0.238	v:2.424	current decay
# t:533 I:1.282	g:0.533	u:0.167	x:0.239	v:2.406	current decay
# t:534 I:1.154	g:0.483	u:0.157	x:0.241	v:2.389	current decay
# t:535 I:1.039	g:0.438	u:0.148	x:0.243	v:2.372	current decay
# t:536 I:0.935	g:0.397	u:0.140	x:0.245	v:2.355	current decay
# t:537 I:0.842	g:0.360	u:0.131	x:0.246	v:2.338	current decay
# t:538 I:0.758	g:0.326	u:0.124	x:0.248	v:2.322	current decay
# t:539 I:0.682	g:0.296	u:0.117	x:0.250	v:2.305	current decay
# t:540 I:0.614	g:0.268	u:0.110	x:0.251	v:2.289	current decay
# t:541 I:0.553	g:0.243	u:0.103	x:0.253	v:2.273	current decay
# t:542 I:0.498	g:0.221	u:0.097	x:0.255	v:2.257	current decay
# t:543 I:0.448	g:0.200	u:0.092	x:0.257	v:2.241	current decay
# t:544 I:0.403	g:0.181	u:0.086	x:0.258	v:2.224	current decay
# t:545 I:0.363	g:0.164	u:0.081	x:0.260	v:2.208	current decay
# t:546 I:0.327	g:0.149	u:0.077	x:0.262	v:2.192	current decay
# t:547 I:0.294	g:0.135	u:0.072	x:0.263	v:2.176	current decay
# t:548 I:0.264	g:0.122	u:0.068	x:0.265	v:2.159	current decay
# t:549 I:0.238	g:0.111	u:0.064	x:0.267	v:2.143	current decay
# t:550 I:0.214	g:0.101	u:0.060	x:0.268	v:2.127	current decay
# t:551 I:0.193	g:0.091	u:0.057	x:0.270	v:2.110	current decay
# t:552 I:0.173	g:0.083	u:0.054	x:0.272	v:2.094	current decay
# t:553 I:0.156	g:0.075	u:0.050	x:0.273	v:2.077	current decay
# t:554 I:0.140	g:0.068	u:0.047	x:0.275	v:2.061	current decay
# t:555 I:0.126	g:0.062	u:0.045	x:0.277	v:2.044	current decay
# t:556 I:0.113	g:0.056	u:0.042	x:0.278	v:2.027	current decay
# t:557 I:0.102	g:0.051	u:0.040	x:0.280	v:2.010	current decay
# t:558 I:0.092	g:0.046	u:0.037	x:0.282	v:1.993	current decay
# t:559 I:0.082	g:0.042	u:0.035	x:0.283	v:1.976	current decay
# t:560 I:0.074	g:0.038	u:0.033	x:0.285	v:1.959	current decay
# t:561 I:0.067	g:0.034	u:0.031	x:0.287	v:1.942	current decay
# t:562 I:0.060	g:0.031	u:0.029	x:0.288	v:1.925	current decay
# t:563 I:0.054	g:0.028	u:0.028	x:0.290	v:1.907	current decay
# t:564 I:0.048	g:0.026	u:0.026	x:0.292	v:1.890	current decay
# t:565 I:0.043	g:0.023	u:0.025	x:0.293	v:1.872	current decay
# t:566 I:0.039	g:0.021	u:0.023	x:0.295	v:1.855	current decay
# t:567 I:0.035	g:0.019	u:0.022	x:0.296	v:1.837	current decay
# t:568 I:0.031	g:0.017	u:0.021	x:0.298	v:1.820	current decay
# t:569 I:0.028	g:0.016	u:0.019	x:0.300	v:1.802	current decay
# t:570 I:0.025	g:0.014	u:0.018	x:0.301	v:1.784	current decay
# t:571 I:0.023	g:0.013	u:0.017	x:0.303	v:1.767	current decay
# t:572 I:0.020	g:0.012	u:0.016	x:0.304	v:1.749	current decay
# t:573 I:0.018	g:0.011	u:0.015	x:0.306	v:1.731	current decay
# t:574 I:0.016	g:0.010	u:0.014	x:0.308	v:1.713	current decay
# t:575 I:0.016	g:1.176	u:0.269	x:0.228	v:1.695	synaptic spike
# t:575 I:1.992	g:1.176	u:0.269	x:0.228	v:1.695	current decay
# t:576 I:1.782	g:1.066	u:0.253	x:0.229	v:1.672	current decay
# t:577 I:1.594	g:0.966	u:0.239	x:0.231	v:1.649	current decay
# t:578 I:1.426	g:0.876	u:0.225	x:0.233	v:1.628	current decay
# t:579 I:1.276	g:0.794	u:0.212	x:0.235	v:1.607	current decay
# t:580 I:1.143	g:0.720	u:0.199	x:0.236	v:1.587	current decay
# t:581 I:1.023	g:0.653	u:0.188	x:0.238	v:1.567	current decay
# t:582 I:0.916	g:0.592	u:0.177	x:0.240	v:1.547	current decay
# t:583 I:0.820	g:0.537	u:0.167	x:0.242	v:1.528	current decay
# t:584 I:0.734	g:0.487	u:0.157	x:0.243	v:1.509	current decay
# t:585 I:0.658	g:0.441	u:0.148	x:0.245	v:1.490	current decay
# t:586 I:0.589	g:0.400	u:0.139	x:0.247	v:1.472	current decay
# t:587 I:0.527	g:0.363	u:0.131	x:0.249	v:1.453	current decay
# t:588 I:0.472	g:0.329	u:0.124	x:0.250	v:1.435	current decay
# t:589 I:0.422	g:0.298	u:0.116	x:0.252	v:1.417	current decay
# t:590 I:0.378	g:0.270	u:0.110	x:0.254	v:1.399	current decay
# t:591 I:0.338	g:0.245	u:0.103	x:0.255	v:1.380	current decay
# t:592 I:0.303	g:0.222	u:0.097	x:0.257	v:1.362	current decay
# t:593 I:0.271	g:0.201	u:0.092	x:0.259	v:1.344	current decay
# t:594 I:0.242	g:0.183	u:0.086	x:0.261	v:1.326	current decay
# t:595 I:0.216	g:0.166	u:0.081	x:0.262	v:1.308	current decay
# t:596 I:0.194	g:0.150	u:0.076	x:0.264	v:1.289	current decay
# t:597 I:0.173	g:0.136	u:0.072	x:0.266	v:1.271	current decay
# t:598 I:0.155	g:0.123	u:0.068	x:0.267	v:1.253	current decay
# t:599 I:0.138	g:0.112	u:0.064	x:0.269	v:1.234	current decay
# t:600 I:0.123	g:0.101	u:0.060	x:0.271	v:1.216	current decay
# t:601 I:0.110	g:0.092	u:0.057	x:0.272	v:1.197	current decay
# t:602 I:0.098	g:0.083	u:0.053	x:0.274	v:1.179	current decay
# t:603 I:0.088	g:0.076	u:0.050	x:0.276	v:1.160	current decay
# t:604 I:0.078	g:0.069	u:0.047	x:0.277	v:1.141	current decay
# t:605 I:0.070	g:0.062	u:0.045	x:0.279	v:1.123	current decay
# t:606 I:0.062	g:0.056	u:0.042	x:0.281	v:1.104	current decay
# t:607 I:0.055	g:0.051	u:0.040	x:0.282	v:1.085	current decay
# t:608 I:0.049	g:0.046	u:0.037	x:0.284	v:1.066	current decay
# t:609 I:0.044	g:0.042	u:0.035	x:0.286	v:1.047	current decay
# t:610 I:0.039	g:0.038	u:0.033	x:0.287	v:1.028	current decay
# t:611 I:0.035	g:0.035	u:0.031	x:0.289	v:1.009	current decay
# t:612 I:0.031	g:0.031	u:0.029	x:0.291	v:0.990	current decay
# t:613 I:0.028	g:0.028	u:0.028	x:0.292	v:0.971	current decay
# t:614 I:0.024	g:0.026	u:0.026	x:0.294	v:0.952	current decay
# t:615 I:0.022	g:0.023	u:0.025	x:0.295	v:0.932	current decay
# t:616 I:0.019	g:0.021	u:0.023	x:0.297	v:0.913	current decay
# t:617 I:0.017	g:0.019	u:0.022	x:0.299	v:0.894	current decay
# t:618 I:0.015	g:0.017	u:0.020	x:0.300	v:0.874	current decay
# t:619 I:0.013	g:0.016	u:0.019	x:0.302	v:0.855	current decay
# t:620 I:0.012	g:0.014	u:0.018	x:0.303	v:0.836	current decay
# t:621 I:0.011	g:0.013	u:0.017	x:0.305	v:0.816	current decay
# t:622 I:0.009	g:0.012	u:0.016	x:0.307	v:0.796	current decay
# t:623 I:0.008	g:0.011	u:0.015	x:0.308	v:0.777	current decay
# t:624 I:0.007	g:0.010	u:0.014	x:0.310	v:0.757	current decay
# t:625 I:0.007	g:1.184	u:0.269	x:0.229	v:0.737	synaptic spike
# t:625 I:0.873	g:1.184	u:0.269	x:0.229	v:0.737	current decay
# t:626 I:0.768	g:1.073	u:0.253	x:0.231	v:0.715	current decay
# t:627 I:0.675	g:0.973	u:0.239	x:0.233	v:0.694	current decay
# t:628 I:0.593	g:0.882	u:0.225	x:0.234	v:0.673	current decay
# t:629 I:0.521	g:0.800	u:0.212	x:0.236	v:0.652	current decay
# t:630 I:0.458	g:0.725	u:0.199	x:0.238	v:0.631	current decay
# t:631 I:0.402	g:0.657	u:0.188	x:0.240	v:0.611	current decay
# t:632 I:0.352	g:0.596	u:0.177	x:0.241	v:0.590	current decay
# t:633 I:0.308	g:0.540	u:0.167	x:0.243	v:0.570	current decay
# t:634 I:0.270	g:0.490	u:0.157	x:0.245	v:0.550	current decay
# t:635 I:0.235	g:0.444	u:0.148	x:0.247	v:0.530	current decay
# t:636 I:0.205	g:0.403	u:0.139	x:0.248	v:0.510	current decay
# t:637 I:0.179	g:0.365	u:0.131	x:0.250	v:0.490	current decay
# t:638 I:0.156	g:0.331	u:0.124	x:0.252	v:0.470	current decay
# t:639 I:0.135	g:0.300	u:0.116	x:0.254	v:0.450	current decay
# t:640 I:0.117	g:0.272	u:0.110	x:0.255	v:0.430	current decay
# t:641 I:0.101	g:0.247	u:0.103	x:0.257	v:0.410	current decay
# t:642 I:0.087	g:0.224	u:0.097	x:0.259	v:0.391	current decay
# t:643 I:0.075	g:0.203	u:0.092	x:0.260	v:0.371	current decay
# t:644 I:0.064	g:0.184	u:0.086	x:0.262	v:0.351	current decay
# t:645 I:0.055	g:0.167	u:0.081	x:0.264	v:0.331	current decay
# t:646 I:0.047	g:0.151	u:0.076	x:0.266	v:0.310	current decay
# t:647 I:0.040	g:0.137	u:0.072	x:0.267	v:0.290	current decay
# t:648 I:0.034	g:0.124	u:0.068	x:0.269	v:0.270	current decay
# t:649 I:0.028	g:0.113	u:0.064	x:0.271	v:0.250	current decay
# t:650 I:0.023	g:0.102	u:0.060	x:0.272	v:0.230	current decay
# t:651 I:0.019	g:0.093	u:0.057	x:0.274	v:0.210	current decay
# t:652 I:0.016	g:0.084	u:0.053	x:0.276	v:0.189	current decay
# t:653 I:0.013	g:0.076	u:0.050	x:0.277	v:0.169	current decay
# t:654 I:0.010	g:0.069	u:0.047	x:0.279	v:0.149	current decay
# t:655 I:0.008	g:0.063	u:0.045	x:0.281	v:0.128	current decay
# t:656 I:0.006	g:0.057	u:0.042	x:0.282	v:0.108	current decay
# t:657 I:0.004	g:0.051	u:0.040	x:0.284	v:0.087	current decay
# t:658 I:0.003	g:0.047	u:0.037	x:0.285	v:0.067	current decay
# t:659 I:0.002	g:0.042	u:0.035	x:0.287	v:0.046	current decay
# t:660 I:0.001	g:0.038	u:0.033	x:0.289	v:0.026	current decay
# t:661 I:0.000	g:0.035	u:0.031	x:0.290	v:0.005	current decay
# t:662 I:-0.000	g:0.032	u:0.029	x:0.292	v:-0.015	current decay
# t:663 I:-0.001	g:0.029	u:0.028	x:0.294	v:-0.036	current decay
# t:664 I:-0.001	g:0.026	u:0.026	x:0.295	v:-0.057	current decay
# t:665 I:-0.002	g:0.023	u:0.025	x:0.297	v:-0.077	current decay
# t:666 I:-0.002	g:0.021	u:0.023	x:0.298	v:-0.098	current decay
# t:667 I:-0.002	g:0.019	u:0.022	x:0.300	v:-0.119	current decay
# t:668 I:-0.002	g:0.017	u:0.020	x:0.302	v:-0.140	current decay
# t:669 I:-0.003	g:0.016	u:0.019	x:0.303	v:-0.161	current decay
# t:670 I:-0.003	g:0.014	u:0.018	x:0.305	v:-0.181	current decay
# t:671 I:-0.003	g:0.013	u:0.017	x:0.306	v:-0.202	current decay
# t:672 I:-0.003	g:0.012	u:0.016	x:0.308	v:-0.223	current decay
# t:673 I:-0.003	g:0.011	u:0.015	x:0.310	v:-0.244	current decay
# t:674 I:-0.003	g:0.010	u:0.014	x:0.311	v:-0.265	current decay
# t:675 I:-0.003	g:1.189	u:0.269	x:0.230	v:-0.286	synaptic spike
# t:675 I:-0.340	g:1.189	u:0.269	x:0.230	v:-0.286	current decay
# t:676 I:-0.330	g:1.078	u:0.253	x:0.232	v:-0.306	current decay
# t:677 I:-0.319	g:0.977	u:0.239	x:0.234	v:-0.326	current decay
# t:678 I:-0.307	g:0.886	u:0.225	x:0.236	v:-0.347	current decay
# t:679 I:-0.295	g:0.803	u:0.212	x:0.237	v:-0.367	current decay
# t:680 I:-0.283	g:0.728	u:0.199	x:0.239	v:-0.388	current decay
# t:681 I:-0.270	g:0.660	u:0.188	x:0.241	v:-0.409	current decay
# t:682 I:-0.257	g:0.599	u:0.177	x:0.243	v:-0.429	current decay
# t:683 I:-0.244	g:0.543	u:0.167	x:0.244	v:-0.450	current decay
# t:684 I:-0.232	g:0.492	u:0.157	x:0.246	v:-0.471	current decay
# t:685 I:-0.220	g:0.446	u:0.148	x:0.248	v:-0.492	current decay
# t:686 I:-0.208	g:0.405	u:0.139	x:0.249	v:-0.513	current decay
# t:687 I:-0.196	g:0.367	u:0.131	x:0.251	v:-0.534	current decay
# t:688 I:-0.185	g:0.333	u:0.124	x:0.253	v:-0.556	current decay
# t:689 I:-0.174	g:0.302	u:0.116	x:0.255	v:-0.577	current decay
# t:690 I:-0.163	g:0.273	u:0.110	x:0.256	v:-0.598	current decay
# t:691 I:-0.154	g:0.248	u:0.103	x:0.258	v:-0.619	current decay
# t:692 I:-0.144	g:0.225	u:0.097	x:0.260	v:-0.641	current decay
# t:693 I:-0.135	g:0.204	u:0.092	x:0.261	v:-0.662	current decay
# t:694 I:-0.126	g:0.185	u:0.086	x:0.263	v:-0.684	current decay
# t:695 I:-0.118	g:0.167	u:0.081	x:0.265	v:-0.705	current decay
# t:696 I:-0.110	g:0.152	u:0.076	x:0.266	v:-0.726	current decay
# t:697 I:-0.103	g:0.138	u:0.072	x:0.268	v:-0.748	current decay
# t:698 I:-0.096	g:0.125	u:0.068	x:0.270	v:-0.769	current decay
# t:699 I:-0.090	g:0.113	u:0.064	x:0.272	v:-0.791	current decay
# t:700 I:-0.083	g:0.103	u:0.060	x:0.273	v:-0.813	current decay
# t:701 I:-0.078	g:0.093	u:0.057	x:0.275	v:-0.834	current decay
# t:702 I:-0.072	g:0.084	u:0.053	x:0.277	v:-0.856	current decay
# t:703 I:-0.067	g:0.076	u:0.050	x:0.278	v:-0.877	current decay
# t:704 I:-0.062	g:0.069	u:0.047	x:0.280	v:-0.899	current decay
# t:705 I:-0.058	g:0.063	u:0.045	x:0.281	v:-0.921	current decay
# t:706 I:-0.054	g:0.057	u:0.042	x:0.283	v:-0.942	current decay
# t:707 I:-0.050	g:0.052	u:0.040	x:0.285	v:-0.964	current decay
# t:708 I:-0.046	g:0.047	u:0.037	x:0.286	v:-0.986	current decay
# t:709 I:-0.043	g:0.042	u:0.035	x:0.288	v:-1.007	current decay
# t:710 I:-0.040	g:0.038	u:0.033	x:0.290	v:-1.029	current decay
# t:711 I:-0.037	g:0.035	u:0.031	x:0.291	v:-1.051	current decay
# t:712 I:-0.034	g:0.032	u:0.029	x:0.293	v:-1.073	current decay
# t:713 I:-0.031	g:0.029	u:0.028	x:0.295	v:-1.094	current decay
# t:714 I:-0.029	g:0.026	u:0.026	x:0.296	v:-1.116	current decay
# t:715 I:-0.027	g:0.024	u:0.025	x:0.298	v:-1.138	current decay
# t:716 I:-0.025	g:0.021	u:0.023	x:0.299	v:-1.160	current decay
# t:717 I:-0.023	g:0.019	u:0.022	x:0.301	v:-1.181	current decay
# t:718 I:-0.021	g:0.018	u:0.020	x:0.303	v:-1.203	current decay
# t:719 I:-0.020	g:0.016	u:0.019	x:0.304	v:-1.225	current decay
# t:720 I:-0.018	g:0.014	u:0.018	x:0.306	v:-1.247	current decay
# t:721 I:-0.017	g:0.013	u:0.017	x:0.307	v:-1.269	current decay
# t:722 I:-0.015	g:0.012	u:0.016	x:0.309	v:-1.290	current decay
# t:723 I:-0.014	g:0.011	u:0.015	x:0.311	v:-1.312	current decay
# t:724 I:-0.013	g:0.010	u:0.014	x:0.312	v:-1.334	current decay
# t:725 I:-0.013	g:1.193	u:0.269	x:0.231	v:-1.356	synaptic spike
# t:725 I:-1.617	g:1.193	u:0.269	x:0.231	v:-1.356	current decay
# t:726 I:-1.485	g:1.081	u:0.253	x:0.233	v:-1.374	current decay
# t:727 I:-1.365	g:0.980	u:0.239	x:0.234	v:-1.392	current decay
# t:728 I:-1.254	g:0.889	u:0.225	x:0.236	v:-1.411	current decay
# t:729 I:-1.153	g:0.806	u:0.212	x:0.238	v:-1.431	current decay
# t:730 I:-1.060	g:0.731	u:0.199	x:0.240	v:-1.451	current decay
# t:731 I:-0.975	g:0.662	u:0.188	x:0.241	v:-1.471	current decay
# t:732 I:-0.896	g:0.601	u:0.177	x:0.243	v:-1.492	current decay
# t:733 I:-0.824	g:0.544	u:0.167	x:0.245	v:-1.513	current decay
# t:734 I:-0.758	g:0.494	u:0.157	x:0.247	v:-1.535	current decay
# t:735 I:-0.697	g:0.448	u:0.148	x:0.248	v:-1.556	current decay
# t:736 I:-0.640	g:0.406	u:0.139	x:0.250	v:-1.578	current decay
# t:737 I:-0.589	g:0.368	u:0.131	x:0.252	v:-1.600	current decay
# t:738 I:-0.541	g:0.334	u:0.124	x:0.254	v:-1.622	current decay
# t:739 I:-0.497	g:0.302	u:0.116	x:0.255	v:-1.644	current decay
# t:740 I:-0.457	g:0.274	u:0.110	x:0.257	v:-1.666	current decay
# t:741 I:-0.420	g:0.249	u:0.103	x:0.259	v:-1.689	current decay
# t:742 I:-0.386	g:0.225	u:0.097	x:0.260	v:-1.711	current decay
# t:743 I:-0.354	g:0.204	u:0.092	x:0.262	v:-1.734	current decay
# t:744 I:-0.325	g:0.185	u:0.086	x:0.264	v:-1.756	current decay
# t:745 I:-0.299	g:0.168	u:0.081	x:0.265	v:-1.779	current decay
# t:746 I:-0.274	g:0.152	u:0.076	x:0.267	v:-1.801	current decay
# t:747 I:-0.252	g:0.138	u:0.072	x:0.269	v:-1.824	current decay
# t:748 I:-0.231	g:0.125	u:0.068	x:0.270	v:-1.846	current decay
# t:749 I:-0.212	g:0.113	u:0.064	x:0.272	v:-1.869	current decay
# t:750 I:-0.195	g:0.103	u:0.060	x:0.274	v:-1.891	current decay
# t:751 I:-0.179	g:0.093	u:0.057	x:0.275	v:-1.914	current decay
# t:752 I:-0.164	g:0.085	u:0.053	x:0.277	v:-1.936	current decay
# t:753 I:-0.150	g:0.077	u:0.050	x:0.279	v:-1.959	current decay
# t:754 I:-0.138	g:0.070	u:0.047	x:0.280	v:-1.981	current decay
# t:755 I:-0.126	g:0.063	u:0.045	x:0.282	v:-2.004	current decay
# t:756 I:-0.116	g:0.057	u:0.042	x:0.284	v:-2.026	current decay
# t:757 I:-0.106	g:0.052	u:0.040	x:0.285	v:-2.048	current decay
# t:758 I:-0.097	g:0.047	u:0.037	x:0.287	v:-2.071	current decay
# t:759 I:-0.089	g:0.043	u:0.035	x:0.289	v:-2.093	current decay
# t:760 I:-0.082	g:0.039	u:0.033	x:0.290	v:-2.116	current decay
# t:761 I:-0.075	g:0.035	u:0.031	x:0.292	v:-2.138	current decay
# t:762 I:-0.069	g:0.032	u:0.029	x:0.294	v:-2.161	current decay
# t:763 I:-0.063	g:0.029	u:0.028	x:0.295	v:-2.183	current decay
# t:764 I:-0.058	g:0.026	u:0.026	x:0.297	v:-2.205	current decay
# t:765 I:-0.053	g:0.024	u:0.025	x:0.298	v:-2.228	current decay
# t:766 I:-0.048	g:0.021	u:0.023	x:0.300	v:-2.250	current decay
# t:767 I:-0.044	g:0.019	u:0.022	x:0.302	v:-2.272	current decay
# t:768 I:-0.040	g:0.018	u:0.020	x:0.303	v:-2.295	current decay
# t:769 I:-0.037	g:0.016	u:0.019	x:0.305	v:-2.317	current decay
# t:770 I:-0.034	g:0.014	u:0.018	x:0.306	v:-2.339	current decay
# t:771 I:-0.031	g:0.013	u:0.017	x:0.308	v:-2.362	current decay
# t:772 I:-0.028	g:0.012	u:0.016	x:0.310	v:-2.384	current decay
# t:773 I:-0.026	g:0.011	u:0.015	x:0.311	v:-2.406	current decay
# t:774 I:-0.026	g:1.192	u:0.270	x:0.230	v:-2.428	synaptic spike
# t:774 I:-2.896	g:1.192	u:0.270	x:0.230	v:-2.428	current decay
# t:775 I:-2.641	g:1.081	u:0.254	x:0.232	v:-2.443	current decay
# t:776 I:-2.411	g:0.980	u:0.239	x:0.234	v:-2.459	current decay
# t:777 I:-2.201	g:0.889	u:0.225	x:0.235	v:-2.477	current decay
# t:778 I:-2.010	g:0.806	u:0.212	x:0.237	v:-2.495	current decay
# t:779 I:-1.837	g:0.730	u:0.200	x:0.239	v:-2.514	current decay
# t:780 I:-1.678	g:0.662	u:0.188	x:0.241	v:-2.534	current decay
# t:781 I:-1.534	g:0.600	u:0.177	x:0.242	v:-2.555	current decay
# t:782 I:-1.402	g:0.544	u:0.167	x:0.244	v:-2.576	current decay
# t:783 I:-1.282	g:0.494	u:0.157	x:0.246	v:-2.597	current decay
# t:784 I:-1.172	g:0.447	u:0.148	x:0.247	v:-2.619	current decay
# t:785 I:-1.072	g:0.406	u:0.140	x:0.249	v:-2.641	current decay
# t:786 I:-0.980	g:0.368	u:0.131	x:0.251	v:-2.664	current decay
# t:787 I:-0.896	g:0.333	u:0.124	x:0.253	v:-2.686	current decay
# t:788 I:-0.819	g:0.302	u:0.117	x:0.254	v:-2.709	current decay
# t:789 I:-0.749	g:0.274	u:0.110	x:0.256	v:-2.732	current decay
# t:790 I:-0.685	g:0.249	u:0.103	x:0.258	v:-2.755	current decay
# t:791 I:-0.626	g:0.225	u:0.097	x:0.260	v:-2.778	current decay
# t:792 I:-0.572	g:0.204	u:0.092	x:0.261	v:-2.801	current decay
# t:793 I:-0.523	g:0.185	u:0.086	x:0.263	v:-2.824	current decay
# t:794 I:-0.478	g:0.168	u:0.081	x:0.265	v:-2.847	current decay
# t:795 I:-0.437	g:0.152	u:0.077	x:0.266	v:-2.870	current decay
# t:796 I:-0.399	g:0.138	u:0.072	x:0.268	v:-2.893	current decay
# t:797 I:-0.365	g:0.125	u:0.068	x:0.270	v:-2.916	current decay
# t:798 I:-0.334	g:0.113	u:0.064	x:0.271	v:-2.939	current decay
# t:799 I:-0.305	g:0.103	u:0.060	x:0.273	v:-2.962	current decay
# t:800 I:-0.278	g:0.093	u:0.057	x:0.275	v:-2.985	current decay
# t:801 I:-0.254	g:0.085	u:0.054	x:0.276	v:-3.008	current decay
# t:802 I:-0.232	g:0.077	u:0.050	x:0.278	v:-3.031	current decay
# t:803 I:-0.212	g:0.070	u:0.047	x:0.280	v:-3.054	current decay
# t:804 I:-0.194	g:0.063	u:0.045	x:0.281	v:-3.077	current decay
# t:805 I:-0.177	g:0.057	u:0.042	x:0.283	v:-3.100	current decay
# t:806 I:-0.162	g:0.052	u:0.040	x:0.285	v:-3.123	current decay
# t:807 I:-0.148	g:0.047	u:0.037	x:0.286	v:-3.146	current decay
# t:808 I:-0.135	g:0.043	u:0.035	x:0.288	v:-3.168	current decay
# t:809 I:-0.123	g:0.039	u:0.033	x:0.289	v:-3.191	current decay
# t:810 I:-0.112	g:0.035	u:0.031	x:0.291	v:-3.214	current decay
# t:811 I:-0.103	g:0.032	u:0.029	x:0.293	v:-3.236	current decay
# t:812 I:-0.094	g:0.029	u:0.028	x:0.294	v:-3.259	current decay
# t:813 I:-0.086	g:0.026	u:0.026	x:0.296	v:-3.281	current decay
# t:814 I:-0.078	g:0.024	u:0.025	x:0.298	v:-3.304	current decay
# t:815 I:-0.071	g:0.021	u:0.023	x:0.299	v:-3.326	current decay
# t:816 I:-0.065	g:0.019	u:0.022	x:0.301	v:-3.349	current decay
# t:817 I:-0.059	g:0.018	u:0.021	x:0.302	v:-3.371	current decay
# t:818 I:-0.054	g:0.016	u:0.019	x:0.304	v:-3.394	current decay
# t:819 I:-0.049	g:0.014	u:0.018	x:0.306	v:-3.416	current decay
# t:820 I:-0.045	g:0.013	u:0.017	x:0.307	v:-3.438	current decay
# t:821 I:-0.041	g:0.012	u:0.016	x:0.309	v:-3.461	current decay
# t:822 I:-0.038	g:0.011	u:0.015	x:0.310	v:-3.483	current decay
# t:823 I:-0.034	g:0.010	u:0.014	x:0.312	v:-3.505	current decay
# t:824 I:-0.034	g:1.192	u:0.269	x:0.231	v:-3.528	synaptic spike
# t:824 I:-4.205	g:1.192	u:0.269	x:0.231	v:-3.528	current decay
# t:825 I:-3.825	g:1.081	u:0.253	x:0.233	v:-3.539	current decay
# t:826 I:-3.481	g:0.980	u:0.239	x:0.234	v:-3.553	current decay
# t:827 I:-3.170	g:0.888	u:0.225	x:0.236	v:-3.568	current decay
# t:828 I:-2.887	g:0.805	u:0.212	x:0.238	v:-3.585	current decay
# t:829 I:-2.631	g:0.730	u:0.199	x:0.240	v:-3.603	current decay
# t:830 I:-2.398	g:0.662	u:0.188	x:0.241	v:-3.622	current decay
# t:831 I:-2.186	g:0.600	u:0.177	x:0.243	v:-3.642	current decay
# t:832 I:-1.993	g:0.544	u:0.167	x:0.245	v:-3.662	current decay
# t:833 I:-1.817	g:0.493	u:0.157	x:0.246	v:-3.683	current decay
# t:834 I:-1.657	g:0.447	u:0.148	x:0.248	v:-3.705	current decay
# t:835 I:-1.512	g:0.406	u:0.139	x:0.250	v:-3.727	current decay
# t:836 I:-1.379	g:0.368	u:0.131	x:0.252	v:-3.750	current decay
# t:837 I:-1.258	g:0.333	u:0.124	x:0.253	v:-3.773	current decay
# t:838 I:-1.147	g:0.302	u:0.116	x:0.255	v:-3.795	current decay
# t:839 I:-1.046	g:0.274	u:0.110	x:0.257	v:-3.819	current decay
# t:840 I:-0.954	g:0.248	u:0.103	x:0.259	v:-3.842	current decay
# t:841 I:-0.871	g:0.225	u:0.097	x:0.260	v:-3.865	current decay
# t:842 I:-0.794	g:0.204	u:0.092	x:0.262	v:-3.888	current decay
# t:843 I:-0.724	g:0.185	u:0.086	x:0.264	v:-3.912	current decay
# t:844 I:-0.661	g:0.168	u:0.081	x:0.265	v:-3.935	current decay
# t:845 I:-0.602	g:0.152	u:0.076	x:0.267	v:-3.958	current decay
# t:846 I:-0.549	g:0.138	u:0.072	x:0.269	v:-3.982	current decay
# t:847 I:-0.501	g:0.125	u:0.068	x:0.270	v:-4.005	current decay
# t:848 I:-0.457	g:0.113	u:0.064	x:0.272	v:-4.028	current decay
# t:849 I:-0.417	g:0.103	u:0.060	x:0.274	v:-4.051	current decay
# t:850 I:-0.380	g:0.093	u:0.057	x:0.275	v:-4.074	current decay
# t:851 I:-0.346	g:0.085	u:0.053	x:0.277	v:-4.097	current decay
# t:852 I:-0.316	g:0.077	u:0.050	x:0.279	v:-4.120	current decay
# t:853 I:-0.288	g:0.069	u:0.047	x:0.280	v:-4.143	current decay
# t:854 I:-0.262	g:0.063	u:0.045	x:0.282	v:-4.166	current decay
# t:855 I:-0.239	g:0.057	u:0.042	x:0.284	v:-4.189	current decay
# t:856 I:-0.218	g:0.052	u:0.040	x:0.285	v:-4.212	current decay
# t:857 I:-0.199	g:0.047	u:0.037	x:0.287	v:-4.234	current decay
# t:858 I:-0.181	g:0.043	u:0.035	x:0.289	v:-4.257	current decay
# t:859 I:-0.165	g:0.039	u:0.033	x:0.290	v:-4.280	current decay
# t:860 I:-0.151	g:0.035	u:0.031	x:0.292	v:-4.302	current decay
# t:861 I:-0.137	g:0.032	u:0.029	x:0.293	v:-4.325	current decay
# t:862 I:-0.125	g:0.029	u:0.028	x:0.295	v:-4.347	current decay
# t:863 I:-0.114	g:0.026	u:0.026	x:0.297	v:-4.369	current decay
# t:864 I:-0.104	g:0.024	u:0.025	x:0.298	v:-4.392	current decay
# t:865 I:-0.095	g:0.021	u:0.023	x:0.300	v:-4.414	current decay
# t:866 I:-0.086	g:0.019	u:0.022	x:0.302	v:-4.436	current decay
# t:867 I:-0.079	g:0.018	u:0.020	x:0.303	v:-4.458	current decay
# t:868 I:-0.072	g:0.016	u:0.019	x:0.305	v:-4.481	current decay
# t:869 I:-0.065	g:0.014	u:0.018	x:0.306	v:-4.503	current decay
# t:870 I:-0.059	g:0.013	u:0.017	x:0.308	v:-4.525	current decay
# t:871 I:-0.054	g:0.012	u:0.016	x:0.309	v:-4.547	current decay
# t:872 I:-0.049	g:0.011	u:0.015	x:0.311	v:-4.569	current decay
# t:873 I:-0.045	g:0.010	u:0.014	x:0.313	v:-4.591	current decay
# t:874 I:-0.045	g:1.194	u:0.269	x:0.231	v:-4.613	synaptic spike
# t:874 I:-5.509	g:1.194	u:0.269	x:0.231	v:-4.613	current decay
# t:875 I:-5.004	g:1.083	u:0.253	x:0.233	v:-4.620	current decay
# t:876 I:-4.547	g:0.982	u:0.239	x:0.235	v:-4.631	current decay
# t:877 I:-4.134	g:0.890	u:0.225	x:0.237	v:-4.644	current decay
# t:878 I:-3.760	g:0.807	u:0.212	x:0.238	v:-4.659	current decay
# t:879 I:-3.421	g:0.732	u:0.199	x:0.240	v:-4.675	current decay
# t:880 I:-3.113	g:0.663	u:0.188	x:0.242	v:-4.693	current decay
# t:881 I:-2.834	g:0.601	u:0.177	x:0.244	v:-4.712	current decay
# t:882 I:-2.580	g:0.545	u:0.167	x:0.245	v:-4.732	current decay
# t:883 I:-2.350	g:0.494	u:0.157	x:0.247	v:-4.753	current decay
# t:884 I:-2.140	g:0.448	u:0.148	x:0.249	v:-4.774	current decay
# t:885 I:-1.949	g:0.406	u:0.139	x:0.250	v:-4.796	current decay
# t:886 I:-1.775	g:0.368	u:0.131	x:0.252	v:-4.818	current decay
# t:887 I:-1.617	g:0.334	u:0.124	x:0.254	v:-4.841	current decay
# t:888 I:-1.473	g:0.303	u:0.116	x:0.256	v:-4.863	current decay
# t:889 I:-1.342	g:0.275	u:0.110	x:0.257	v:-4.886	current decay
# t:890 I:-1.222	g:0.249	u:0.103	x:0.259	v:-4.910	current decay
# t:891 I:-1.113	g:0.226	u:0.097	x:0.261	v:-4.933	current decay
# t:892 I:-1.014	g:0.205	u:0.092	x:0.262	v:-4.956	current decay
# t:893 I:-0.924	g:0.186	u:0.086	x:0.264	v:-4.979	current decay
# t:894 I:-0.841	g:0.168	u:0.081	x:0.266	v:-5.002	current decay
# t:895 I:-0.766	g:0.153	u:0.076	x:0.267	v:-5.026	current decay
# t:896 I:-0.698	g:0.138	u:0.072	x:0.269	v:-5.049	current decay
# t:897 I:-0.636	g:0.125	u:0.068	x:0.271	v:-5.072	current decay
# t:898 I:-0.579	g:0.114	u:0.064	x:0.272	v:-5.095	current decay
# t:899 I:-0.527	g:0.103	u:0.060	x:0.274	v:-5.118	current decay
# t:900 I:-0.480	g:0.093	u:0.057	x:0.276	v:-5.141	current decay
# t:901 I:-0.437	g:0.085	u:0.053	x:0.277	v:-5.164	current decay
# t:902 I:-0.398	g:0.077	u:0.050	x:0.279	v:-5.186	current decay
# t:903 I:-0.363	g:0.070	u:0.047	x:0.281	v:-5.209	current decay
# t:904 I:-0.330	g:0.063	u:0.045	x:0.282	v:-5.232	current decay
# t:905 I:-0.301	g:0.057	u:0.042	x:0.284	v:-5.254	current decay
# t:906 I:-0.274	g:0.052	u:0.040	x:0.286	v:-5.276	current decay
# t:907 I:-0.249	g:0.047	u:0.037	x:0.287	v:-5.299	current decay
# t:908 I:-0.227	g:0.043	u:0.035	x:0.289	v:-5.321	current decay
# t:909 I:-0.207	g:0.039	u:0.033	x:0.291	v:-5.343	current decay
# t:910 I:-0.188	g:0.035	u:0.031	x:0.292	v:-5.365	current decay
# t:911 I:-0.171	g:0.032	u:0.029	x:0.294	v:-5.387	current decay
# t:912 I:-0.156	g:0.029	u:0.028	x:0.296	v:-5.409	current decay
# t:913 I:-0.142	g:0.026	u:0.026	x:0.297	v:-5.431	current decay
# t:914 I:-0.129	g:0.024	u:0.025	x:0.299	v:-5.453	current decay
# t:915 I:-0.118	g:0.021	u:0.023	x:0.300	v:-5.474	current decay
# t:916 I:-0.107	g:0.019	u:0.022	x:0.302	v:-5.496	current decay
# t:917 I:-0.097	g:0.018	u:0.020	x:0.304	v:-5.518	current decay
# t:918 I:-0.089	g:0.016	u:0.019	x:0.305	v:-5.539	current decay
# t:919 I:-0.081	g:0.015	u:0.018	x:0.307	v:-5.561	current decay
# t:920 I:-0.073	g:0.013	u:0.017	x:0.308	v:-5.582	current decay
# t:921 I:-0.067	g:0.012	u:0.016	x:0.310	v:-5.603	current decay
# t:922 I:-0.061	g:0.011	u:0.015	x:0.312	v:-5.625	current decay
# t:923 I:-0.055	g:0.010	u:0.014	x:0.313	v:-5.646	current decay
# t:924 I:-0.055	g:1.196	u:0.269	x:0.232	v:-5.667	synaptic spike
# t:924 I:-6.779	g:1.196	u:0.269	x:0.232	v:-5.667	current decay
# t:925 I:-6.150	g:1.084	u:0.253	x:0.233	v:-5.671	current decay
# t:926 I:-5.583	g:0.983	u:0.239	x:0.235	v:-5.679	current decay
# t:927 I:-5.071	g:0.891	u:0.225	x:0.237	v:-5.689	current decay
# t:928 I:-4.608	g:0.808	u:0.212	x:0.239	v:-5.702	current decay
# t:929 I:-4.189	g:0.733	u:0.199	x:0.240	v:-5.717	current decay
# t:930 I:-3.808	g:0.664	u:0.188	x:0.242	v:-5.733	current decay
# t:931 I:-3.464	g:0.602	u:0.177	x:0.244	v:-5.751	current decay
# t:932 I:-3.151	g:0.546	u:0.167	x:0.246	v:-5.770	current decay
# t:933 I:-2.866	g:0.495	u:0.157	x:0.247	v:-5.790	current decay
# t:934 I:-2.608	g:0.449	u:0.148	x:0.249	v:-5.811	current decay
# t:935 I:-2.373	g:0.407	u:0.139	x:0.251	v:-5.832	current decay
# t:936 I:-2.160	g:0.369	u:0.131	x:0.252	v:-5.854	current decay
# t:937 I:-1.966	g:0.335	u:0.124	x:0.254	v:-5.876	current decay
# t:938 I:-1.789	g:0.303	u:0.116	x:0.256	v:-5.898	current decay
# t:939 I:-1.628	g:0.275	u:0.110	x:0.258	v:-5.921	current decay
# t:940 I:-1.482	g:0.249	u:0.103	x:0.259	v:-5.944	current decay
# t:941 I:-1.349	g:0.226	u:0.097	x:0.261	v:-5.967	current decay
# t:942 I:-1.227	g:0.205	u:0.092	x:0.263	v:-5.989	current decay
# t:943 I:-1.117	g:0.186	u:0.086	x:0.264	v:-6.012	current decay
# t:944 I:-1.017	g:0.168	u:0.081	x:0.266	v:-6.035	current decay
# t:945 I:-0.925	g:0.153	u:0.076	x:0.268	v:-6.058	current decay
# t:946 I:-0.842	g:0.138	u:0.072	x:0.269	v:-6.081	current decay
# t:947 I:-0.766	g:0.126	u:0.068	x:0.271	v:-6.103	current decay
# t:948 I:-0.697	g:0.114	u:0.064	x:0.273	v:-6.126	current decay
# t:949 I:-0.634	g:0.103	u:0.060	x:0.274	v:-6.148	current decay
# t:950 I:-0.577	g:0.094	u:0.057	x:0.276	v:-6.171	current decay
# t:951 I:-0.525	g:0.085	u:0.053	x:0.278	v:-6.193	current decay
# t:952 I:-0.478	g:0.077	u:0.050	x:0.279	v:-6.215	current decay
# t:953 I:-0.435	g:0.070	u:0.047	x:0.281	v:-6.237	current decay
# t:954 I:-0.396	g:0.063	u:0.045	x:0.283	v:-6.259	current decay
# t:955 I:-0.360	g:0.057	u:0.042	x:0.284	v:-6.281	current decay
# t:956 I:-0.327	g:0.052	u:0.040	x:0.286	v:-6.303	current decay
# t:957 I:-0.298	g:0.047	u:0.037	x:0.288	v:-6.324	current decay
# t:958 I:-0.271	g:0.043	u:0.035	x:0.289	v:-6.346	current decay
# t:959 I:-0.247	g:0.039	u:0.033	x:0.291	v:-6.367	current decay
# t:960 I:-0.224	g:0.035	u:0.031	x:0.293	v:-6.389	current decay
# t:961 I:-0.204	g:0.032	u:0.029	x:0.294	v:-6.410	current decay
# t:962 I:-0.186	g:0.029	u:0.028	x:0.296	v:-6.431	current decay
# t:963 I:-0.169	g:0.026	u:0.026	x:0.297	v:-6.452	current decay
# t:964 I:-0.154	g:0.024	u:0.025	x:0.299	v:-6.473	current decay
# t:965 I:-0.140	g:0.022	u:0.023	x:0.301	v:-6.494	current decay
# t:966 I:-0.127	g:0.019	u:0.022	x:0.302	v:-6.515	current decay
# t:967 I:-0.116	g:0.018	u:0.020	x:0.304	v:-6.536	current decay
# t:968 I:-0.105	g:0.016	u:0.019	x:0.305	v:-6.557	current decay
# t:969 I:-0.096	g:0.015	u:0.018	x:0.307	v:-6.577	current decay
# t:970 I:-0.087	g:0.013	u:0.017	x:0.309	v:-6.598	current decay
# t:971 I:-0.079	g:0.012	u:0.016	x:0.310	v:-6.618	current decay
# t:972 I:-0.072	g:0.011	u:0.015	x:0.312	v:-6.639	current decay
# t:973 I:-0.065	g:0.010	u:0.014	x:0.313	v:-6.659	current decay
# t:974 I:-0.065	g:1.197	u:0.269	x:0.232	v:-6.680	synaptic spike
# t:974 I:-7.997	g:1.197	u:0.269	x:0.232	v:-6.680	current decay
# t:975 I:-7.250	g:1.085	u:0.253	x:0.234	v:-6.679	current decay
# t:976 I:-6.577	g:0.984	u:0.239	x:0.235	v:-6.684	current decay
# t:977 I:-5.970	g:0.892	u:0.225	x:0.237	v:-6.691	current decay
# t:978 I:-5.421	g:0.809	u:0.212	x:0.239	v:-6.702	current decay
# t:979 I:-4.924	g:0.733	u:0.199	x:0.241	v:-6.715	current decay
# t:980 I:-4.475	g:0.665	u:0.188	x:0.242	v:-6.730	current decay
# t:981 I:-4.067	g:0.603	u:0.177	x:0.244	v:-6.746	current decay
# t:982 I:-3.697	g:0.547	u:0.167	x:0.246	v:-6.764	current decay
# t:983 I:-3.361	g:0.496	u:0.157	x:0.247	v:-6.783	current decay
# t:984 I:-3.056	g:0.449	u:0.148	x:0.249	v:-6.803	current decay
# t:985 I:-2.779	g:0.407	u:0.139	x:0.251	v:-6.824	current decay
# t:986 I:-2.528	g:0.369	u:0.131	x:0.253	v:-6.845	current decay
# t:987 I:-2.299	g:0.335	u:0.124	x:0.254	v:-6.867	current decay
# t:988 I:-2.091	g:0.304	u:0.116	x:0.256	v:-6.888	current decay
# t:989 I:-1.902	g:0.275	u:0.110	x:0.258	v:-6.910	current decay
# t:990 I:-1.730	g:0.250	u:0.103	x:0.259	v:-6.933	current decay
# t:991 I:-1.573	g:0.226	u:0.097	x:0.261	v:-6.955	current decay
# t:992 I:-1.431	g:0.205	u:0.092	x:0.263	v:-6.977	current decay
# t:993 I:-1.302	g:0.186	u:0.086	x:0.265	v:-7.000	current decay
# t:994 I:-1.184	g:0.169	u:0.081	x:0.266	v:-7.022	current decay
# t:995 I:-1.077	g:0.153	u:0.076	x:0.268	v:-7.044	current decay
# t:996 I:-0.979	g:0.139	u:0.072	x:0.270	v:-7.066	current decay
# t:997 I:-0.891	g:0.126	u:0.068	x:0.271	v:-7.088	current decay
# t:998 I:-0.810	g:0.114	u:0.064	x:0.273	v:-7.110	current decay
# t:999 I:-0.737	g:0.103	u:0.060	x:0.275	v:-7.132	current decay
# /tmp/ipykernel_158441/55680725.py:241: DeprecationWarning: scipy.conj is deprecated and will be removed in SciPy 2.0.0, use numpy.conj instead
#   c = scipy.ifft(af * scipy.conj(bf))
# /tmp/ipykernel_158441/55680725.py:241: DeprecationWarning: scipy.ifft is deprecated and will be removed in SciPy 2.0.0, use scipy.fft.ifft instead
#   c = scipy.ifft(af * scipy.conj(bf))
# /tmp/ipykernel_158441/55680725.py:272: RuntimeWarning: invalid value encountered in true_divide
#   pctErrorI = abs((I_2 - I_syn_2)/I_syn_2)

# %%
# Print stats related to the differences between the voltage computed via Keivan's model and CARLsim
print(maxErrorV)
print(minErrorV)
print(meanErrorV)
print(medianErrorV)
print(mismatchV)
# Out:
# 0.0005537050967232892
# 1.4406427631404644e-06
# 0.0002935743608628468
# 0.0003518081076378919
# 7.5325434774792025e-06

# %%
# Print stats related to the differences between the current computed via Keivan's model and CARLsim
print(maxErrorI)
print(minErrorI)
print(meanErrorI)
print(medianErrorI)
print(mismatchI)
# Out:
# 1.0
# 2.3351885965391782e-06
# 0.022663087706716347
# 0.01522615489638712
# 0.00032158528745553755
