# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import statistics as st
from collections import Counter
import os
import os.path
import scipy
import csv
from scipy import signal
import pandas as pd

# %%
plot_source="neuronmonitor" # choose "neuronmonitor" or "jk_custom" for CARLsim data file source
# Create time points
Tmin, Tmax, dt = 0, 1000, 0.025  # Step size
T = np.arange(Tmin, Tmax + dt, dt)

# Declare the current to be used
I_ext = 150

## Nine parameters for IM model
# Axo_Axonic
k, a, b, d, C, vr, vt, c, vpeak = 3.961462878, 0.004638608, 8.683644937, 15, 165, -57.09978287, \
                                  -51.71875628, -73.96850421, 27.79863559

preNeuronType = "Axo-Axonic"

## Make a state vector that has a (v, u) pair for each timestep
s = np.zeros((len(T), 2))

# Create a vector to store spike times
if plot_source=="neuronmonitor":
    spike_times = np.array([15, 40, 67, 97, 130, 166, 206, 249, 295, 343, 392, 442, 493, 544, 595, 646, 697, 748, 799, 850, 901, 952])
if plot_source=="jk_custom":
    spike_times = np.array([])
isi_mode_list = np.array([])


## Initial values
s[0, 0] = vr
s[0, 1] = 0


# Note that s1[0] is v, s1[1] is u. This is Izhikevich equation in vector form
def s_dt(s1, I):
  v_dt = (k*(s1[0] - vr)*(s1[0] - vt) - s1[1] + I)*(1/C)
  u_dt = a*(b*(s1[0] - vr) - s1[1])
  return np.array([v_dt, u_dt])


## SIMULATE
for t in range(len(T)-1):
  # Calculate the four constants of Runge-Kutta method
  k_1 = s_dt(s[t], I_ext)
  k_2 = s_dt(s[t] + 0.5*dt*k_1, I_ext)
  k_3 = s_dt(s[t] + 0.5*dt*k_2, I_ext)
  k_4 = s_dt(s[t] + dt*k_3, I_ext)

  s[t+1] = s[t] + (1.0/6)*dt*(k_1 + 2*k_2 + 2*k_3 + k_4)

  # Reset the neuron if it has spiked
  if s[t+1, 0] >= vpeak:
    s[t, 0]   = vpeak # add Dirac pulse for visualisation
    s[t+1, 0] = c   # Reset to resting potential
    s[t+1, 1] += d  # Update recovery variable
    if plot_source=="jk_custom":
        spike_times = np.append(spike_times, math.ceil(t*dt))
    #print(math.floor(t * dt))

v = s[:, 0]
u = s[:, 1]


## Nine parameters for IM model
# Pyramidal
postNeuronType = "Pyramidal"
a, b, c, d, k, vr, vt, C, vpeak = 0.00838350334098279, -42.5524776883928, -38.8680990294091, 588.0, \
                                  0.792338703789581, -63.2044008171655, -33.6041733124267, 366.0, 35.8614648558726

# Synaptic Parameters and equations
synaptic_event_times = list(spike_times)
print(synaptic_event_times)

# TPM parameters
g0, tau_d, tau_f, tau_r, Utilization, e_rev = 3.644261648, 10.71107251, 17.20004939, 435.8103009, 0.259914361, -70

tm_model = 'Carlsim'#'Keivan'

if tm_model == 'Keivan':
    # in CARLsim there is no change to the g param from the value it is set as in connect()
    # Note: NS is unclear why this calculation exists and is related to eq. 13 in (Moradi, 2022) supp mat.
    g0 /= Utilization

def synaptic_event(delta_t_, g, g0, tau_d_, tau_r_, tau_f_, utilization, x0, y0, u0, e_syn):
    if tm_model != 'Carlsim':
        # TM Model that depends on tau_d
        tau1r = tau_d_ / ((tau_d_ - tau_r_) if tau_d_ != tau_r_ else 1e-13)
        y_ = y0 * math.exp(-delta_t_ / tau_d_)
        x_ = 1 + (x0 - 1 + tau1r * y0) * math.exp(-delta_t_ / tau_r_) - tau1r * y_
        u_ = u0 * math.exp(-delta_t_ / tau_f_)
        u0 = u_ + utilization * (1 - u_)
        y0 = y_ + u0 * x_
        x0 = x_ - u0 * x_
        g  = g0 * y0
        #print("%f  = %f * %f; u0:%f x0:%f x_:%f" % (g, g0, y0, u0, x0, x_))
    else:
        # Carlsim's TM Model
        A  = 1 / Utilization # this seems to serve the same function as g0 /= Utilization would
        u_ = u0 + utilization * (1 - u0)
        x_ = x0 - u_ * x0
        #print("%f + %f * (%f * %f * %f)" % (g, g0, A, u_, x_))        
        g  = g + g0 * (A * u_ * x0)
        u0 = u_
        x0 = x_
        
    return g, x0, y0, u0


def synaptic_current(I, g, delta_t_, tau_d_, e_syn_, tm_model):
    if tm_model == 'Keivan':
        #g = g * math.exp(-delta_t_ / tau_d_) * e_syn_
        I = g * math.exp(-delta_t_ / tau_d_) * e_syn_
    if tm_model == 'Carlsim':
        I = g * e_syn_
        #print("%f * (1 - (1 / %f))" % (g,tau_d))
    return I

def synaptic_decay(g, tau_d_, tm_model):
    g = g * (1 - (1 / tau_d_))
    return g

def stp_variable_update(u, x, tau_f, tau_r, tm_model):
    tau_f_inv = 1/tau_f
    tau_r_inv = 1/tau_r
    u = u * (1 - tau_f_inv)
    x = x + (1 - x) * tau_r_inv
    #u = u + -u/tau_f
    #x = x + (1 - x)/tau_r
    return u, x

# Initialize synaptic state variables
g, x0, y0 = 0.0, 1.0, 0.0
I = 0.0
if tm_model == 'Carlsim':
    u0 = 0 #Utilization # NS does not see evidence in CARLsim that this is initialized as other than 0
else:
    u0 = 0

# Make a state vector that has a (v, u) pair for each timestep
s = np.zeros((len(T), 2))

# Initial Izhikevich state variables
s[0, 0] = vr
s[0, 1] = 0


# Note that s1[0] is v, s1[1] is u. This is Izhikevich equation in vector form
def s_dt(s1, I):
    v_dt = (k * (s1[0] - vr) * (s1[0] - vt) - s1[1] + I) * (1 / C)
    u_dt = a * (b * (s1[0] - vr) - s1[1])
    return np.array([v_dt, u_dt])

# SIMULATE
next_synaptic_event_time, delta_t, I_syn = synaptic_event_times[0], 0.0, [0]
synaptic_event_time = next_synaptic_event_time
spike_times = np.array([])
for t in range(len(T) - 1):
    v = s[t, 0]
    e_syn = v - e_rev
    time = T[t]

    # in CARLsim this occurs before the synaptic spike current update. doSTPUpdateAndDecayCond() is before globalStateUpdate().
    if (tm_model == 'Carlsim' and t % (1/dt) == 0): # run every whole number millisecond
        g = synaptic_decay(g, tau_d, tm_model)
        u0, x0 = stp_variable_update(u0, x0, tau_f, tau_r, tm_model)

    if next_synaptic_event_time <= time:
        inter_event_time = next_synaptic_event_time - synaptic_event_time
        g, x0, y0, u0 = synaptic_event(inter_event_time, g, g0, tau_d, tau_r, tau_f, Utilization, x0, y0, u0, e_syn)
        # NS updated g for carlsim calcs
        #print(g, time, synaptic_event_time, next_synaptic_event_time)
        print("t:%d I:%.3f\tg:%.3f\tu:%.3f\tx:%.3f\tv:%.3f\tsynaptic spike" % (time,I,g,u0,x0,e_syn))
        synaptic_event_time = time
        if len(synaptic_event_times) > 1:
            del synaptic_event_times[0]
            next_synaptic_event_time = synaptic_event_times[0]
        else:
            next_synaptic_event_time = math.inf

    delta_t = time - synaptic_event_time
    if delta_t >= 0:
        if (t % (1/dt) == 0):
            I = synaptic_current(I, g, delta_t, tau_d, e_syn, tm_model)
            print("t:%d I:%.3f\tg:%.3f\tu:%.3f\tx:%.3f\tv:%.3f\tcurrent decay" % (t/(1/dt),I,g,u0,x0,e_syn))
    I_syn.append(I)

    # Calculate the four constants of Runge-Kutta method
    k_1 = s_dt(s[t], -I)
    k_2 = s_dt(s[t] + 0.5 * dt * k_1, -I)
    k_3 = s_dt(s[t] + 0.5 * dt * k_2, -I)
    k_4 = s_dt(s[t] + dt * k_3, -I)

    s[t + 1] = s[t] + (1.0 / 6) * dt * (k_1 + 2 * k_2 + 2 * k_3 + k_4)

    # Reset the neuron if it has spiked
    if s[t + 1, 0] >= vpeak:
        s[t, 0] = vpeak  # add Dirac pulse for visualisation
        s[t + 1, 0] = c  # Reset to resting potential
        s[t + 1, 1] += d  # Update recovery variable
        spike_times = np.append(spike_times, math.floor(t * dt))

v = s[:, 0]
u = s[:, 1]

# First define function to flip the sign of the current
def sign(lst): 
    return [ -i for i in lst ]

# downsample
if plot_source=="neuronmonitor":
    steps = 40 #1/dt
    dt = 1  # Step size
    T = np.arange(Tmin, Tmax + dt, dt)

# Compare to CARLsim simulation output
if plot_source=="neuronmonitor":
    FH = np.loadtxt("stp_compare_results.csv")
elif plot_source=="jk_custom":
    FH = np.loadtxt("HC_IM_05_26_aac_pyr_I_150pA_fast_1_slow_0.txt")
I = FH[1::2]
V = FH[0::2]
I = sign(I)
I = I[0:len(I_syn)-1]
V = V[0:len(I_syn)-1]
ax1 = plt.subplot(211)
ax1.plot(T,np.append(V, [V[-1]]), label = "CARLsim TM") # added the last value of V to ensure the same length as time vector
plt.ylabel('Membrane potential (mV)')
ax2 = plt.subplot(212)
ax2.plot(T,np.append(I, [I[-1]]), label = "CARLsim TM") # added the last value of I to ensure the same length as time vector
plt.ylabel('Synaptic Current (pA)')
plt.xlabel('Time (ms)')
plt.legend(loc = "center right")
plt.tight_layout()

# downsample
if plot_source=="neuronmonitor":
    v = v[0:v.size:steps]
    I_syn = I_syn[0:len(I_syn):steps]

## Plot the membrane potential
ax1 = plt.subplot(211)
ax1.plot(T, v, color = "orange", linestyle='dotted', label = "Keivan TM", alpha=0.85)
plt.ylabel('Membrane potential (mV)')
plt.title(f"{postNeuronType}")
ax2 = plt.subplot(212)
ax2.plot(T, I_syn, color = "orange", linestyle='dotted', label = "Keivan TM", alpha=0.85)
plt.ylabel('Synaptic Current (pA)')
plt.xlabel('Time (ms)')
plt.legend(loc = "center right")
plt.tight_layout()
fileOutputName = preNeuronType + '_' + postNeuronType + '_' + str(I_ext) + 'pA' + \
      '_CARLsim_vs_Keivan_superimposed.png'
plt.savefig(fileOutputName, dpi=800)
plt.clf()


# Look at the error between CARLsim and python computed synaptic signal
I = np.append(I, [I[-1]])
V = np.append(V, [V[-1]])

af = scipy.fft.fft(I_syn)
bf = scipy.fft.fft(I)
c = scipy.ifft(af * scipy.conj(bf))
time_shift = np.argmax(abs(c))
#         print(time_shift)

I_2 = I[:-1]
I_2 = I_2[::int(1/dt)]
I_syn_2 = I_syn[0+time_shift:]
I_syn_2 = I_syn_2[::int(1/dt)]
I_syn_2 = np.array(np.array(I_syn_2,dtype=np.float32))
V_2 = V[:-1]
V_2 = V_2[::int(1/dt)]
v_2 = v[0+time_shift:]
v_2 = v_2[::int(1/dt)]

if len(V_2) == len(v_2):
    ax1 = plt.subplot(211)
    ax1.plot(abs(V_2 - v_2))
    plt.ylabel('Membrane potential (mV)')
    plt.title(f"{postNeuronType}")
    ax2 = plt.subplot(212)
    ax2.plot(abs(I_2 - I_syn_2))
    plt.ylabel('I_syn diff (HCO - Carlsim) (pA)')
    plt.xlabel('Time (ms)')
    plt.tight_layout()
    fileOutputName = preNeuronType + '_' + postNeuronType + '_' + str(I_ext) + 'pA' + \
          '_CARLsim_vs_Keivan_error.png'
    plt.savefig(fileOutputName, dpi=800)
    plt.clf()

    # Append min, max, mean, and median of errors between V and I
    pctErrorV = abs((V_2 - v_2)/v_2)
    pctErrorI = abs((I_2 - I_syn_2)/I_syn_2)
    maxErrorV = max(pctErrorV[~np.isnan(pctErrorV)])
    maxErrorI = max(pctErrorI[~np.isnan(pctErrorI)])
    minErrorV = min(pctErrorV[~np.isnan(pctErrorV)])
    minErrorI = min(pctErrorI[~np.isnan(pctErrorI)])
    meanErrorV = np.mean(pctErrorV[~np.isnan(pctErrorV)])
    meanErrorI = np.mean(pctErrorI[~np.isnan(pctErrorI)])
    medianErrorV = np.median(pctErrorV[~np.isnan(pctErrorV)])
    medianErrorI = np.median(pctErrorI[~np.isnan(pctErrorI)])
    mismatchV = sum(abs(V_2-v_2)*dt)/sum(abs((V_2 + v_2)/2))
    mismatchI = sum(abs(I_2-I_syn_2)*dt)/sum(abs((I_2 + I_syn_2)/2))
# Out:
# [15, 40, 67, 97, 130, 166, 206, 249, 295, 343, 392, 442, 493, 544, 595, 646, 697, 748, 799, 850, 901, 952]
# t:15 I:0.000	g:3.644	u:0.260	x:0.740	v:6.796	synaptic spike
# t:15 I:24.765	g:3.644	u:0.260	x:0.740	v:6.796	current decay
# t:16 I:22.236	g:3.304	u:0.245	x:0.741	v:6.730	current decay
# t:17 I:19.996	g:2.996	u:0.231	x:0.741	v:6.675	current decay
# t:18 I:18.005	g:2.716	u:0.217	x:0.742	v:6.630	current decay
# t:19 I:16.232	g:2.462	u:0.205	x:0.742	v:6.592	current decay
# t:20 I:14.648	g:2.232	u:0.193	x:0.743	v:6.561	current decay
# t:21 I:13.230	g:2.024	u:0.181	x:0.744	v:6.536	current decay
# t:22 I:11.958	g:1.835	u:0.171	x:0.744	v:6.517	current decay
# t:23 I:10.816	g:1.664	u:0.161	x:0.745	v:6.501	current decay
# t:24 I:9.789	g:1.508	u:0.152	x:0.745	v:6.490	current decay
# t:25 I:8.863	g:1.368	u:0.143	x:0.746	v:6.481	current decay
# t:26 I:8.029	g:1.240	u:0.134	x:0.747	v:6.475	current decay
# t:27 I:7.275	g:1.124	u:0.127	x:0.747	v:6.472	current decay
# t:28 I:6.594	g:1.019	u:0.119	x:0.748	v:6.470	current decay
# t:29 I:5.979	g:0.924	u:0.112	x:0.748	v:6.470	current decay
# t:30 I:5.422	g:0.838	u:0.106	x:0.749	v:6.472	current decay
# t:31 I:4.918	g:0.760	u:0.100	x:0.749	v:6.474	current decay
# t:32 I:4.461	g:0.689	u:0.094	x:0.750	v:6.478	current decay
# t:33 I:4.047	g:0.624	u:0.088	x:0.751	v:6.482	current decay
# t:34 I:3.672	g:0.566	u:0.083	x:0.751	v:6.487	current decay
# t:35 I:3.332	g:0.513	u:0.078	x:0.752	v:6.492	current decay
# t:36 I:3.023	g:0.465	u:0.074	x:0.752	v:6.497	current decay
# t:37 I:2.743	g:0.422	u:0.070	x:0.753	v:6.503	current decay
# t:38 I:2.489	g:0.382	u:0.066	x:0.753	v:6.509	current decay
# t:39 I:2.259	g:0.347	u:0.062	x:0.754	v:6.515	current decay
# t:40 I:2.259	g:3.520	u:0.303	x:0.526	v:6.521	synaptic spike
# t:40 I:22.950	g:3.520	u:0.303	x:0.526	v:6.521	current decay
# t:41 I:20.649	g:3.191	u:0.285	x:0.527	v:6.471	current decay
# t:42 I:18.605	g:2.893	u:0.269	x:0.528	v:6.431	current decay
# t:43 I:16.782	g:2.623	u:0.253	x:0.529	v:6.398	current decay
# t:44 I:15.153	g:2.378	u:0.238	x:0.530	v:6.372	current decay
# t:45 I:13.694	g:2.156	u:0.225	x:0.531	v:6.351	current decay
# t:46 I:12.385	g:1.955	u:0.211	x:0.532	v:6.336	current decay
# t:47 I:11.208	g:1.772	u:0.199	x:0.534	v:6.324	current decay
# t:48 I:10.148	g:1.607	u:0.188	x:0.535	v:6.316	current decay
# t:49 I:9.193	g:1.457	u:0.177	x:0.536	v:6.311	current decay
# t:50 I:8.332	g:1.321	u:0.166	x:0.537	v:6.308	current decay
# t:51 I:7.553	g:1.197	u:0.157	x:0.538	v:6.307	current decay
# t:52 I:6.849	g:1.086	u:0.148	x:0.539	v:6.308	current decay
# t:53 I:6.212	g:0.984	u:0.139	x:0.540	v:6.311	current decay
# t:54 I:5.635	g:0.892	u:0.131	x:0.541	v:6.315	current decay
# t:55 I:5.113	g:0.809	u:0.123	x:0.542	v:6.319	current decay
# t:56 I:4.639	g:0.734	u:0.116	x:0.543	v:6.324	current decay
# t:57 I:4.210	g:0.665	u:0.109	x:0.544	v:6.330	current decay
# t:58 I:3.821	g:0.603	u:0.103	x:0.545	v:6.337	current decay
# t:59 I:3.468	g:0.547	u:0.097	x:0.546	v:6.343	current decay
# t:60 I:3.147	g:0.496	u:0.091	x:0.547	v:6.350	current decay
# t:61 I:2.857	g:0.449	u:0.086	x:0.548	v:6.357	current decay
# t:62 I:2.593	g:0.407	u:0.081	x:0.549	v:6.364	current decay
# t:63 I:2.353	g:0.369	u:0.076	x:0.550	v:6.371	current decay
# t:64 I:2.136	g:0.335	u:0.072	x:0.551	v:6.377	current decay
# t:65 I:1.938	g:0.304	u:0.068	x:0.552	v:6.384	current decay
# t:66 I:1.759	g:0.275	u:0.064	x:0.553	v:6.390	current decay
# t:67 I:1.759	g:2.616	u:0.304	x:0.386	v:6.397	synaptic spike
# t:67 I:16.735	g:2.616	u:0.304	x:0.386	v:6.397	current decay
# t:68 I:15.092	g:2.372	u:0.287	x:0.387	v:6.363	current decay
# t:69 I:13.623	g:2.151	u:0.270	x:0.389	v:6.335	current decay
# t:70 I:12.308	g:1.950	u:0.254	x:0.390	v:6.312	current decay
# t:71 I:11.127	g:1.768	u:0.240	x:0.391	v:6.295	current decay
# t:72 I:10.066	g:1.603	u:0.226	x:0.393	v:6.281	current decay
# t:73 I:9.111	g:1.453	u:0.213	x:0.394	v:6.270	current decay
# t:74 I:8.250	g:1.317	u:0.200	x:0.396	v:6.263	current decay
# t:75 I:7.474	g:1.194	u:0.189	x:0.397	v:6.257	current decay
# t:76 I:6.772	g:1.083	u:0.178	x:0.398	v:6.254	current decay
# t:77 I:6.139	g:0.982	u:0.167	x:0.400	v:6.252	current decay
# t:78 I:5.565	g:0.890	u:0.158	x:0.401	v:6.252	current decay
# t:79 I:5.047	g:0.807	u:0.148	x:0.402	v:6.253	current decay
# t:80 I:4.577	g:0.732	u:0.140	x:0.404	v:6.255	current decay
# t:81 I:4.151	g:0.663	u:0.132	x:0.405	v:6.258	current decay
# t:82 I:3.766	g:0.601	u:0.124	x:0.407	v:6.261	current decay
# t:83 I:3.416	g:0.545	u:0.117	x:0.408	v:6.265	current decay
# t:84 I:3.099	g:0.494	u:0.110	x:0.409	v:6.269	current decay
# t:85 I:2.812	g:0.448	u:0.104	x:0.411	v:6.274	current decay
# t:86 I:2.551	g:0.406	u:0.098	x:0.412	v:6.278	current decay
# t:87 I:2.315	g:0.368	u:0.092	x:0.413	v:6.283	current decay
# t:88 I:2.100	g:0.334	u:0.087	x:0.415	v:6.288	current decay
# t:89 I:1.906	g:0.303	u:0.082	x:0.416	v:6.292	current decay
# t:90 I:1.729	g:0.275	u:0.077	x:0.417	v:6.297	current decay
# t:91 I:1.569	g:0.249	u:0.072	x:0.419	v:6.301	current decay
# t:92 I:1.423	g:0.226	u:0.068	x:0.420	v:6.306	current decay
# t:93 I:1.291	g:0.205	u:0.064	x:0.421	v:6.310	current decay
# t:94 I:1.171	g:0.186	u:0.060	x:0.423	v:6.314	current decay
# t:95 I:1.063	g:0.168	u:0.057	x:0.424	v:6.317	current decay
# t:96 I:0.964	g:0.152	u:0.054	x:0.425	v:6.321	current decay
# t:97 I:0.964	g:1.916	u:0.297	x:0.300	v:6.324	synaptic spike
# t:97 I:12.120	g:1.916	u:0.297	x:0.300	v:6.324	current decay
# t:98 I:10.942	g:1.737	u:0.280	x:0.301	v:6.298	current decay
# t:99 I:9.886	g:1.575	u:0.264	x:0.303	v:6.276	current decay
# t:100 I:8.937	g:1.428	u:0.248	x:0.305	v:6.258	current decay
# t:101 I:8.084	g:1.295	u:0.234	x:0.306	v:6.243	current decay
# t:102 I:7.315	g:1.174	u:0.220	x:0.308	v:6.231	current decay
# t:103 I:6.622	g:1.064	u:0.208	x:0.309	v:6.222	current decay
# t:104 I:5.997	g:0.965	u:0.195	x:0.311	v:6.214	current decay
# t:105 I:5.432	g:0.875	u:0.184	x:0.313	v:6.209	current decay
# t:106 I:4.922	g:0.793	u:0.173	x:0.314	v:6.205	current decay
# t:107 I:4.460	g:0.719	u:0.163	x:0.316	v:6.202	current decay
# t:108 I:4.043	g:0.652	u:0.154	x:0.317	v:6.201	current decay
# t:109 I:3.665	g:0.591	u:0.145	x:0.319	v:6.200	current decay
# t:110 I:3.323	g:0.536	u:0.136	x:0.320	v:6.200	current decay
# t:111 I:3.013	g:0.486	u:0.129	x:0.322	v:6.200	current decay
# t:112 I:2.732	g:0.441	u:0.121	x:0.324	v:6.201	current decay
# t:113 I:2.478	g:0.399	u:0.114	x:0.325	v:6.203	current decay
# t:114 I:2.247	g:0.362	u:0.107	x:0.327	v:6.204	current decay
# t:115 I:2.038	g:0.328	u:0.101	x:0.328	v:6.206	current decay
# t:116 I:1.848	g:0.298	u:0.095	x:0.330	v:6.208	current decay
# t:117 I:1.676	g:0.270	u:0.090	x:0.331	v:6.210	current decay
# t:118 I:1.520	g:0.245	u:0.085	x:0.333	v:6.212	current decay
# t:119 I:1.379	g:0.222	u:0.080	x:0.334	v:6.214	current decay
# t:120 I:1.250	g:0.201	u:0.075	x:0.336	v:6.216	current decay
# t:121 I:1.134	g:0.182	u:0.071	x:0.337	v:6.218	current decay
# t:122 I:1.028	g:0.165	u:0.066	x:0.339	v:6.220	current decay
# t:123 I:0.933	g:0.150	u:0.063	x:0.340	v:6.222	current decay
# t:124 I:0.846	g:0.136	u:0.059	x:0.342	v:6.223	current decay
# t:125 I:0.767	g:0.123	u:0.056	x:0.343	v:6.225	current decay
# t:126 I:0.696	g:0.112	u:0.052	x:0.345	v:6.226	current decay
# t:127 I:0.631	g:0.101	u:0.049	x:0.346	v:6.227	current decay
# t:128 I:0.572	g:0.092	u:0.046	x:0.348	v:6.228	current decay
# t:129 I:0.519	g:0.083	u:0.044	x:0.349	v:6.229	current decay
# t:130 I:0.519	g:1.504	u:0.290	x:0.249	v:6.230	synaptic spike
# t:130 I:9.371	g:1.504	u:0.290	x:0.249	v:6.230	current decay
# t:131 I:8.465	g:1.364	u:0.274	x:0.251	v:6.207	current decay
# t:132 I:7.651	g:1.236	u:0.258	x:0.252	v:6.187	current decay
# t:133 I:6.918	g:1.121	u:0.243	x:0.254	v:6.171	current decay
# t:134 I:6.258	g:1.016	u:0.229	x:0.256	v:6.157	current decay
# t:135 I:5.664	g:0.921	u:0.215	x:0.258	v:6.146	current decay
# t:136 I:5.127	g:0.835	u:0.203	x:0.259	v:6.137	current decay
# t:137 I:4.643	g:0.757	u:0.191	x:0.261	v:6.129	current decay
# t:138 I:4.205	g:0.687	u:0.180	x:0.263	v:6.123	current decay
# t:139 I:3.809	g:0.623	u:0.169	x:0.264	v:6.118	current decay
# t:140 I:3.451	g:0.565	u:0.160	x:0.266	v:6.114	current decay
# t:141 I:3.128	g:0.512	u:0.150	x:0.268	v:6.111	current decay
# t:142 I:2.835	g:0.464	u:0.142	x:0.269	v:6.109	current decay
# t:143 I:2.569	g:0.421	u:0.133	x:0.271	v:6.107	current decay
# t:144 I:2.329	g:0.381	u:0.126	x:0.273	v:6.106	current decay
# t:145 I:2.111	g:0.346	u:0.118	x:0.274	v:6.105	current decay
# t:146 I:1.914	g:0.314	u:0.111	x:0.276	v:6.104	current decay
# t:147 I:1.735	g:0.284	u:0.105	x:0.278	v:6.104	current decay
# t:148 I:1.573	g:0.258	u:0.099	x:0.279	v:6.104	current decay
# t:149 I:1.426	g:0.234	u:0.093	x:0.281	v:6.104	current decay
# t:150 I:1.293	g:0.212	u:0.088	x:0.283	v:6.104	current decay
# t:151 I:1.172	g:0.192	u:0.083	x:0.284	v:6.104	current decay
# t:152 I:1.063	g:0.174	u:0.078	x:0.286	v:6.104	current decay
# t:153 I:0.964	g:0.158	u:0.073	x:0.288	v:6.104	current decay
# t:154 I:0.874	g:0.143	u:0.069	x:0.289	v:6.104	current decay
# t:155 I:0.792	g:0.130	u:0.065	x:0.291	v:6.104	current decay
# t:156 I:0.718	g:0.118	u:0.061	x:0.293	v:6.104	current decay
# t:157 I:0.651	g:0.107	u:0.058	x:0.294	v:6.104	current decay
# t:158 I:0.590	g:0.097	u:0.054	x:0.296	v:6.103	current decay
# t:159 I:0.535	g:0.088	u:0.051	x:0.297	v:6.103	current decay
# t:160 I:0.485	g:0.079	u:0.048	x:0.299	v:6.102	current decay
# t:161 I:0.440	g:0.072	u:0.045	x:0.301	v:6.102	current decay
# t:162 I:0.399	g:0.065	u:0.043	x:0.302	v:6.101	current decay
# t:163 I:0.361	g:0.059	u:0.040	x:0.304	v:6.100	current decay
# t:164 I:0.328	g:0.054	u:0.038	x:0.305	v:6.099	current decay
# t:165 I:0.297	g:0.049	u:0.036	x:0.307	v:6.098	current decay
# t:166 I:0.297	g:1.276	u:0.285	x:0.221	v:6.096	synaptic spike
# t:166 I:7.782	g:1.276	u:0.285	x:0.221	v:6.096	current decay
# t:167 I:7.031	g:1.157	u:0.268	x:0.223	v:6.075	current decay
# t:168 I:6.355	g:1.049	u:0.253	x:0.224	v:6.057	current decay
# t:169 I:5.747	g:0.951	u:0.238	x:0.226	v:6.041	current decay
# t:170 I:5.199	g:0.862	u:0.224	x:0.228	v:6.028	current decay
# t:171 I:4.705	g:0.782	u:0.211	x:0.230	v:6.017	current decay
# t:172 I:4.259	g:0.709	u:0.199	x:0.231	v:6.007	current decay
# t:173 I:3.856	g:0.643	u:0.187	x:0.233	v:5.999	current decay
# t:174 I:3.492	g:0.583	u:0.176	x:0.235	v:5.992	current decay
# t:175 I:3.163	g:0.528	u:0.166	x:0.237	v:5.986	current decay
# t:176 I:2.865	g:0.479	u:0.156	x:0.238	v:5.981	current decay
# t:177 I:2.596	g:0.434	u:0.147	x:0.240	v:5.977	current decay
# t:178 I:2.352	g:0.394	u:0.139	x:0.242	v:5.973	current decay
# t:179 I:2.131	g:0.357	u:0.131	x:0.244	v:5.970	current decay
# t:180 I:1.932	g:0.324	u:0.123	x:0.245	v:5.968	current decay
# t:181 I:1.751	g:0.293	u:0.116	x:0.247	v:5.965	current decay
# t:182 I:1.587	g:0.266	u:0.109	x:0.249	v:5.963	current decay
# t:183 I:1.438	g:0.241	u:0.103	x:0.251	v:5.961	current decay
# t:184 I:1.303	g:0.219	u:0.097	x:0.252	v:5.960	current decay
# t:185 I:1.181	g:0.198	u:0.091	x:0.254	v:5.958	current decay
# t:186 I:1.071	g:0.180	u:0.086	x:0.256	v:5.957	current decay
# t:187 I:0.971	g:0.163	u:0.081	x:0.257	v:5.955	current decay
# t:188 I:0.880	g:0.148	u:0.076	x:0.259	v:5.954	current decay
# t:189 I:0.797	g:0.134	u:0.072	x:0.261	v:5.952	current decay
# t:190 I:0.723	g:0.121	u:0.068	x:0.263	v:5.951	current decay
# t:191 I:0.655	g:0.110	u:0.064	x:0.264	v:5.949	current decay
# t:192 I:0.594	g:0.100	u:0.060	x:0.266	v:5.947	current decay
# t:193 I:0.538	g:0.091	u:0.057	x:0.268	v:5.946	current decay
# t:194 I:0.488	g:0.082	u:0.053	x:0.269	v:5.944	current decay
# t:195 I:0.442	g:0.074	u:0.050	x:0.271	v:5.942	current decay
# t:196 I:0.401	g:0.067	u:0.047	x:0.273	v:5.940	current decay
# t:197 I:0.363	g:0.061	u:0.044	x:0.274	v:5.938	current decay
# t:198 I:0.329	g:0.055	u:0.042	x:0.276	v:5.936	current decay
# t:199 I:0.298	g:0.050	u:0.039	x:0.278	v:5.933	current decay
# t:200 I:0.270	g:0.046	u:0.037	x:0.279	v:5.931	current decay
# t:201 I:0.245	g:0.041	u:0.035	x:0.281	v:5.929	current decay
# t:202 I:0.222	g:0.037	u:0.033	x:0.283	v:5.926	current decay
# t:203 I:0.201	g:0.034	u:0.031	x:0.284	v:5.923	current decay
# t:204 I:0.182	g:0.031	u:0.029	x:0.286	v:5.920	current decay
# t:205 I:0.165	g:0.028	u:0.028	x:0.288	v:5.917	current decay
# t:206 I:0.165	g:1.157	u:0.279	x:0.208	v:5.914	synaptic spike
# t:206 I:6.842	g:1.157	u:0.279	x:0.208	v:5.914	current decay
# t:207 I:6.181	g:1.049	u:0.263	x:0.210	v:5.894	current decay
# t:208 I:5.587	g:0.951	u:0.248	x:0.212	v:5.876	current decay
# t:209 I:5.052	g:0.862	u:0.233	x:0.214	v:5.860	current decay
# t:210 I:4.570	g:0.782	u:0.220	x:0.216	v:5.846	current decay
# t:211 I:4.135	g:0.709	u:0.207	x:0.217	v:5.834	current decay
# t:212 I:3.742	g:0.643	u:0.195	x:0.219	v:5.824	current decay
# t:213 I:3.388	g:0.583	u:0.184	x:0.221	v:5.815	current decay
# t:214 I:3.067	g:0.528	u:0.173	x:0.223	v:5.807	current decay
# t:215 I:2.777	g:0.479	u:0.163	x:0.225	v:5.800	current decay
# t:216 I:2.516	g:0.434	u:0.153	x:0.226	v:5.794	current decay
# t:217 I:2.279	g:0.394	u:0.144	x:0.228	v:5.789	current decay
# t:218 I:2.064	g:0.357	u:0.136	x:0.230	v:5.784	current decay
# t:219 I:1.870	g:0.324	u:0.128	x:0.232	v:5.780	current decay
# t:220 I:1.694	g:0.293	u:0.121	x:0.233	v:5.776	current decay
# t:221 I:1.535	g:0.266	u:0.114	x:0.235	v:5.772	current decay
# t:222 I:1.391	g:0.241	u:0.107	x:0.237	v:5.769	current decay
# t:223 I:1.260	g:0.219	u:0.101	x:0.239	v:5.765	current decay
# t:224 I:1.142	g:0.198	u:0.095	x:0.241	v:5.762	current decay
# t:225 I:1.035	g:0.180	u:0.089	x:0.242	v:5.759	current decay
# t:226 I:0.938	g:0.163	u:0.084	x:0.244	v:5.756	current decay
# t:227 I:0.850	g:0.148	u:0.079	x:0.246	v:5.753	current decay
# t:228 I:0.770	g:0.134	u:0.075	x:0.247	v:5.750	current decay
# t:229 I:0.698	g:0.121	u:0.070	x:0.249	v:5.747	current decay
# t:230 I:0.632	g:0.110	u:0.066	x:0.251	v:5.744	current decay
# t:231 I:0.573	g:0.100	u:0.062	x:0.253	v:5.741	current decay
# t:232 I:0.519	g:0.090	u:0.059	x:0.254	v:5.738	current decay
# t:233 I:0.470	g:0.082	u:0.055	x:0.256	v:5.735	current decay
# t:234 I:0.426	g:0.074	u:0.052	x:0.258	v:5.732	current decay
# t:235 I:0.386	g:0.067	u:0.049	x:0.259	v:5.729	current decay
# t:236 I:0.350	g:0.061	u:0.046	x:0.261	v:5.725	current decay
# t:237 I:0.317	g:0.055	u:0.044	x:0.263	v:5.722	current decay
# t:238 I:0.287	g:0.050	u:0.041	x:0.265	v:5.718	current decay
# t:239 I:0.260	g:0.046	u:0.039	x:0.266	v:5.715	current decay
# t:240 I:0.236	g:0.041	u:0.036	x:0.268	v:5.711	current decay
# t:241 I:0.214	g:0.037	u:0.034	x:0.270	v:5.707	current decay
# t:242 I:0.194	g:0.034	u:0.032	x:0.271	v:5.703	current decay
# t:243 I:0.175	g:0.031	u:0.030	x:0.273	v:5.699	current decay
# t:244 I:0.159	g:0.028	u:0.029	x:0.275	v:5.695	current decay
# t:245 I:0.144	g:0.025	u:0.027	x:0.276	v:5.691	current decay
# t:246 I:0.130	g:0.023	u:0.025	x:0.278	v:5.686	current decay
# t:247 I:0.118	g:0.021	u:0.024	x:0.280	v:5.682	current decay
# t:248 I:0.107	g:0.019	u:0.023	x:0.281	v:5.677	current decay
# t:249 I:0.107	g:1.110	u:0.276	x:0.205	v:5.673	synaptic spike
# t:249 I:6.299	g:1.110	u:0.276	x:0.205	v:5.673	current decay
# t:250 I:5.690	g:1.007	u:0.260	x:0.207	v:5.652	current decay
# t:251 I:5.142	g:0.913	u:0.245	x:0.209	v:5.633	current decay
# t:252 I:4.648	g:0.828	u:0.230	x:0.210	v:5.617	current decay
# t:253 I:4.203	g:0.750	u:0.217	x:0.212	v:5.603	current decay
# t:254 I:3.802	g:0.680	u:0.204	x:0.214	v:5.590	current decay
# t:255 I:3.440	g:0.617	u:0.192	x:0.216	v:5.579	current decay
# t:256 I:3.114	g:0.559	u:0.181	x:0.218	v:5.569	current decay
# t:257 I:2.818	g:0.507	u:0.171	x:0.219	v:5.560	current decay
# t:258 I:2.552	g:0.460	u:0.161	x:0.221	v:5.552	current decay
# t:259 I:2.310	g:0.417	u:0.151	x:0.223	v:5.544	current decay
# t:260 I:2.092	g:0.378	u:0.143	x:0.225	v:5.538	current decay
# t:261 I:1.895	g:0.343	u:0.134	x:0.227	v:5.531	current decay
# t:262 I:1.716	g:0.311	u:0.127	x:0.228	v:5.526	current decay
# t:263 I:1.554	g:0.282	u:0.119	x:0.230	v:5.520	current decay
# t:264 I:1.408	g:0.255	u:0.112	x:0.232	v:5.515	current decay
# t:265 I:1.275	g:0.231	u:0.106	x:0.234	v:5.510	current decay
# t:266 I:1.155	g:0.210	u:0.100	x:0.235	v:5.506	current decay
# t:267 I:1.047	g:0.190	u:0.094	x:0.237	v:5.501	current decay
# t:268 I:0.948	g:0.172	u:0.088	x:0.239	v:5.497	current decay
# t:269 I:0.859	g:0.156	u:0.083	x:0.241	v:5.492	current decay
# t:270 I:0.778	g:0.142	u:0.078	x:0.242	v:5.488	current decay
# t:271 I:0.705	g:0.129	u:0.074	x:0.244	v:5.483	current decay
# t:272 I:0.639	g:0.117	u:0.070	x:0.246	v:5.479	current decay
# t:273 I:0.578	g:0.106	u:0.065	x:0.248	v:5.475	current decay
# t:274 I:0.524	g:0.096	u:0.062	x:0.249	v:5.470	current decay
# t:275 I:0.475	g:0.087	u:0.058	x:0.251	v:5.466	current decay
# t:276 I:0.430	g:0.079	u:0.055	x:0.253	v:5.461	current decay
# t:277 I:0.390	g:0.071	u:0.052	x:0.254	v:5.456	current decay
# t:278 I:0.353	g:0.065	u:0.049	x:0.256	v:5.451	current decay
# t:279 I:0.320	g:0.059	u:0.046	x:0.258	v:5.447	current decay
# t:280 I:0.290	g:0.053	u:0.043	x:0.260	v:5.442	current decay
# t:281 I:0.262	g:0.048	u:0.041	x:0.261	v:5.437	current decay
# t:282 I:0.238	g:0.044	u:0.038	x:0.263	v:5.431	current decay
# t:283 I:0.215	g:0.040	u:0.036	x:0.265	v:5.426	current decay
# t:284 I:0.195	g:0.036	u:0.034	x:0.266	v:5.421	current decay
# t:285 I:0.177	g:0.033	u:0.032	x:0.268	v:5.416	current decay
# t:286 I:0.160	g:0.030	u:0.030	x:0.270	v:5.410	current decay
# t:287 I:0.145	g:0.027	u:0.028	x:0.271	v:5.404	current decay
# t:288 I:0.131	g:0.024	u:0.027	x:0.273	v:5.399	current decay
# t:289 I:0.119	g:0.022	u:0.025	x:0.275	v:5.393	current decay
# t:290 I:0.108	g:0.020	u:0.024	x:0.276	v:5.387	current decay
# t:291 I:0.097	g:0.018	u:0.022	x:0.278	v:5.381	current decay
# t:292 I:0.088	g:0.016	u:0.021	x:0.280	v:5.375	current decay
# t:293 I:0.080	g:0.015	u:0.020	x:0.281	v:5.369	current decay
# t:294 I:0.072	g:0.013	u:0.019	x:0.283	v:5.363	current decay
# t:295 I:0.072	g:1.101	u:0.273	x:0.207	v:5.356	synaptic spike
# t:295 I:5.899	g:1.101	u:0.273	x:0.207	v:5.356	current decay
# t:296 I:5.327	g:0.999	u:0.257	x:0.209	v:5.335	current decay
# t:297 I:4.812	g:0.905	u:0.242	x:0.211	v:5.315	current decay
# t:298 I:4.349	g:0.821	u:0.228	x:0.212	v:5.298	current decay
# t:299 I:3.931	g:0.744	u:0.215	x:0.214	v:5.283	current decay
# t:300 I:3.555	g:0.675	u:0.202	x:0.216	v:5.269	current decay
# t:301 I:3.215	g:0.612	u:0.191	x:0.218	v:5.257	current decay
# t:302 I:2.909	g:0.555	u:0.179	x:0.220	v:5.245	current decay
# t:303 I:2.632	g:0.503	u:0.169	x:0.221	v:5.235	current decay
# t:304 I:2.382	g:0.456	u:0.159	x:0.223	v:5.226	current decay
# t:305 I:2.156	g:0.413	u:0.150	x:0.225	v:5.217	current decay
# t:306 I:1.952	g:0.375	u:0.141	x:0.227	v:5.209	current decay
# t:307 I:1.767	g:0.340	u:0.133	x:0.229	v:5.201	current decay
# t:308 I:1.600	g:0.308	u:0.125	x:0.230	v:5.194	current decay
# t:309 I:1.448	g:0.279	u:0.118	x:0.232	v:5.187	current decay
# t:310 I:1.311	g:0.253	u:0.111	x:0.234	v:5.180	current decay
# t:311 I:1.188	g:0.230	u:0.105	x:0.236	v:5.174	current decay
# t:312 I:1.075	g:0.208	u:0.099	x:0.237	v:5.167	current decay
# t:313 I:0.974	g:0.189	u:0.093	x:0.239	v:5.161	current decay
# t:314 I:0.882	g:0.171	u:0.087	x:0.241	v:5.155	current decay
# t:315 I:0.799	g:0.155	u:0.082	x:0.243	v:5.149	current decay
# t:316 I:0.723	g:0.141	u:0.078	x:0.244	v:5.143	current decay
# t:317 I:0.655	g:0.127	u:0.073	x:0.246	v:5.137	current decay
# t:318 I:0.593	g:0.116	u:0.069	x:0.248	v:5.131	current decay
# t:319 I:0.537	g:0.105	u:0.065	x:0.250	v:5.125	current decay
# t:320 I:0.486	g:0.095	u:0.061	x:0.251	v:5.118	current decay
# t:321 I:0.440	g:0.086	u:0.057	x:0.253	v:5.112	current decay
# t:322 I:0.399	g:0.078	u:0.054	x:0.255	v:5.106	current decay
# t:323 I:0.361	g:0.071	u:0.051	x:0.256	v:5.099	current decay
# t:324 I:0.327	g:0.064	u:0.048	x:0.258	v:5.093	current decay
# t:325 I:0.296	g:0.058	u:0.045	x:0.260	v:5.086	current decay
# t:326 I:0.268	g:0.053	u:0.043	x:0.261	v:5.080	current decay
# t:327 I:0.243	g:0.048	u:0.040	x:0.263	v:5.073	current decay
# t:328 I:0.220	g:0.043	u:0.038	x:0.265	v:5.066	current decay
# t:329 I:0.199	g:0.039	u:0.036	x:0.267	v:5.059	current decay
# t:330 I:0.180	g:0.036	u:0.034	x:0.268	v:5.052	current decay
# t:331 I:0.163	g:0.032	u:0.032	x:0.270	v:5.045	current decay
# t:332 I:0.148	g:0.029	u:0.030	x:0.272	v:5.038	current decay
# t:333 I:0.134	g:0.027	u:0.028	x:0.273	v:5.031	current decay
# t:334 I:0.121	g:0.024	u:0.026	x:0.275	v:5.023	current decay
# t:335 I:0.110	g:0.022	u:0.025	x:0.277	v:5.016	current decay
# t:336 I:0.099	g:0.020	u:0.023	x:0.278	v:5.008	current decay
# t:337 I:0.090	g:0.018	u:0.022	x:0.280	v:5.001	current decay
# t:338 I:0.081	g:0.016	u:0.021	x:0.282	v:4.993	current decay
# t:339 I:0.074	g:0.015	u:0.020	x:0.283	v:4.985	current decay
# t:340 I:0.067	g:0.013	u:0.018	x:0.285	v:4.977	current decay
# t:341 I:0.060	g:0.012	u:0.017	x:0.286	v:4.969	current decay
# t:342 I:0.055	g:0.011	u:0.016	x:0.288	v:4.961	current decay
# t:343 I:0.055	g:1.112	u:0.271	x:0.211	v:4.953	synaptic spike
# t:343 I:5.509	g:1.112	u:0.271	x:0.211	v:4.953	current decay
# t:344 I:4.972	g:1.008	u:0.256	x:0.213	v:4.930	current decay
# t:345 I:4.489	g:0.914	u:0.241	x:0.215	v:4.910	current decay
# t:346 I:4.055	g:0.829	u:0.227	x:0.217	v:4.892	current decay
# t:347 I:3.664	g:0.752	u:0.214	x:0.218	v:4.875	current decay
# t:348 I:3.311	g:0.681	u:0.201	x:0.220	v:4.860	current decay
# t:349 I:2.994	g:0.618	u:0.189	x:0.222	v:4.846	current decay
# t:350 I:2.707	g:0.560	u:0.178	x:0.224	v:4.834	current decay
# t:351 I:2.448	g:0.508	u:0.168	x:0.226	v:4.822	current decay
# t:352 I:2.215	g:0.460	u:0.158	x:0.227	v:4.811	current decay
# t:353 I:2.004	g:0.417	u:0.149	x:0.229	v:4.800	current decay
# t:354 I:1.813	g:0.378	u:0.140	x:0.231	v:4.791	current decay
# t:355 I:1.640	g:0.343	u:0.132	x:0.233	v:4.781	current decay
# t:356 I:1.484	g:0.311	u:0.125	x:0.234	v:4.772	current decay
# t:357 I:1.343	g:0.282	u:0.117	x:0.236	v:4.764	current decay
# t:358 I:1.216	g:0.256	u:0.110	x:0.238	v:4.755	current decay
# t:359 I:1.100	g:0.232	u:0.104	x:0.240	v:4.747	current decay
# t:360 I:0.996	g:0.210	u:0.098	x:0.241	v:4.739	current decay
# t:361 I:0.901	g:0.191	u:0.092	x:0.243	v:4.731	current decay
# t:362 I:0.816	g:0.173	u:0.087	x:0.245	v:4.723	current decay
# t:363 I:0.738	g:0.157	u:0.082	x:0.247	v:4.715	current decay
# t:364 I:0.668	g:0.142	u:0.077	x:0.248	v:4.707	current decay
# t:365 I:0.605	g:0.129	u:0.073	x:0.250	v:4.699	current decay
# t:366 I:0.548	g:0.117	u:0.068	x:0.252	v:4.691	current decay
# t:367 I:0.496	g:0.106	u:0.064	x:0.253	v:4.683	current decay
# t:368 I:0.449	g:0.096	u:0.061	x:0.255	v:4.675	current decay
# t:369 I:0.406	g:0.087	u:0.057	x:0.257	v:4.667	current decay
# t:370 I:0.367	g:0.079	u:0.054	x:0.259	v:4.658	current decay
# t:371 I:0.333	g:0.072	u:0.051	x:0.260	v:4.650	current decay
# t:372 I:0.301	g:0.065	u:0.048	x:0.262	v:4.642	current decay
# t:373 I:0.272	g:0.059	u:0.045	x:0.264	v:4.633	current decay
# t:374 I:0.246	g:0.053	u:0.042	x:0.265	v:4.625	current decay
# t:375 I:0.223	g:0.048	u:0.040	x:0.267	v:4.616	current decay
# t:376 I:0.202	g:0.044	u:0.038	x:0.269	v:4.607	current decay
# t:377 I:0.183	g:0.040	u:0.035	x:0.270	v:4.598	current decay
# t:378 I:0.165	g:0.036	u:0.033	x:0.272	v:4.589	current decay
# t:379 I:0.150	g:0.033	u:0.031	x:0.274	v:4.580	current decay
# t:380 I:0.135	g:0.030	u:0.030	x:0.275	v:4.571	current decay
# t:381 I:0.122	g:0.027	u:0.028	x:0.277	v:4.562	current decay
# t:382 I:0.111	g:0.024	u:0.026	x:0.279	v:4.553	current decay
# t:383 I:0.100	g:0.022	u:0.025	x:0.280	v:4.543	current decay
# t:384 I:0.091	g:0.020	u:0.023	x:0.282	v:4.534	current decay
# t:385 I:0.082	g:0.018	u:0.022	x:0.284	v:4.524	current decay
# t:386 I:0.074	g:0.016	u:0.021	x:0.285	v:4.514	current decay
# t:387 I:0.067	g:0.015	u:0.019	x:0.287	v:4.505	current decay
# t:388 I:0.061	g:0.014	u:0.018	x:0.289	v:4.495	current decay
# t:389 I:0.055	g:0.012	u:0.017	x:0.290	v:4.485	current decay
# t:390 I:0.050	g:0.011	u:0.016	x:0.292	v:4.475	current decay
# t:391 I:0.045	g:0.010	u:0.015	x:0.294	v:4.465	current decay
# t:392 I:0.045	g:1.129	u:0.271	x:0.215	v:4.455	synaptic spike
# t:392 I:5.029	g:1.129	u:0.271	x:0.215	v:4.455	current decay
# t:393 I:4.535	g:1.023	u:0.255	x:0.217	v:4.431	current decay
# t:394 I:4.092	g:0.928	u:0.240	x:0.219	v:4.410	current decay
# t:395 I:3.694	g:0.841	u:0.226	x:0.221	v:4.391	current decay
# t:396 I:3.335	g:0.763	u:0.213	x:0.222	v:4.373	current decay
# t:397 I:3.013	g:0.692	u:0.201	x:0.224	v:4.357	current decay
# t:398 I:2.722	g:0.627	u:0.189	x:0.226	v:4.341	current decay
# t:399 I:2.460	g:0.568	u:0.178	x:0.228	v:4.327	current decay
# t:400 I:2.223	g:0.515	u:0.168	x:0.230	v:4.314	current decay
# t:401 I:2.010	g:0.467	u:0.158	x:0.231	v:4.301	current decay
# t:402 I:1.817	g:0.424	u:0.149	x:0.233	v:4.289	current decay
# t:403 I:1.643	g:0.384	u:0.140	x:0.235	v:4.277	current decay
# t:404 I:1.485	g:0.348	u:0.132	x:0.237	v:4.266	current decay
# t:405 I:1.343	g:0.316	u:0.124	x:0.238	v:4.255	current decay
# t:406 I:1.215	g:0.286	u:0.117	x:0.240	v:4.244	current decay
# t:407 I:1.099	g:0.259	u:0.110	x:0.242	v:4.234	current decay
# t:408 I:0.994	g:0.235	u:0.104	x:0.244	v:4.224	current decay
# t:409 I:0.899	g:0.213	u:0.098	x:0.245	v:4.214	current decay
# t:410 I:0.813	g:0.193	u:0.092	x:0.247	v:4.203	current decay
# t:411 I:0.735	g:0.175	u:0.087	x:0.249	v:4.193	current decay
# t:412 I:0.665	g:0.159	u:0.082	x:0.251	v:4.183	current decay
# t:413 I:0.601	g:0.144	u:0.077	x:0.252	v:4.173	current decay
# t:414 I:0.544	g:0.131	u:0.072	x:0.254	v:4.163	current decay
# t:415 I:0.492	g:0.118	u:0.068	x:0.256	v:4.153	current decay
# t:416 I:0.445	g:0.107	u:0.064	x:0.257	v:4.143	current decay
# t:417 I:0.402	g:0.097	u:0.061	x:0.259	v:4.133	current decay
# t:418 I:0.364	g:0.088	u:0.057	x:0.261	v:4.123	current decay
# t:419 I:0.329	g:0.080	u:0.054	x:0.262	v:4.112	current decay
# t:420 I:0.298	g:0.073	u:0.051	x:0.264	v:4.102	current decay
# t:421 I:0.269	g:0.066	u:0.048	x:0.266	v:4.091	current decay
# t:422 I:0.243	g:0.060	u:0.045	x:0.268	v:4.081	current decay
# t:423 I:0.220	g:0.054	u:0.042	x:0.269	v:4.070	current decay
# t:424 I:0.199	g:0.049	u:0.040	x:0.271	v:4.059	current decay
# t:425 I:0.180	g:0.044	u:0.037	x:0.273	v:4.048	current decay
# t:426 I:0.163	g:0.040	u:0.035	x:0.274	v:4.037	current decay
# t:427 I:0.147	g:0.037	u:0.033	x:0.276	v:4.026	current decay
# t:428 I:0.133	g:0.033	u:0.031	x:0.278	v:4.015	current decay
# t:429 I:0.120	g:0.030	u:0.029	x:0.279	v:4.004	current decay
# t:430 I:0.109	g:0.027	u:0.028	x:0.281	v:3.992	current decay
# t:431 I:0.098	g:0.025	u:0.026	x:0.283	v:3.981	current decay
# t:432 I:0.089	g:0.022	u:0.025	x:0.284	v:3.969	current decay
# t:433 I:0.080	g:0.020	u:0.023	x:0.286	v:3.958	current decay
# t:434 I:0.073	g:0.018	u:0.022	x:0.287	v:3.946	current decay
# t:435 I:0.066	g:0.017	u:0.021	x:0.289	v:3.934	current decay
# t:436 I:0.059	g:0.015	u:0.019	x:0.291	v:3.922	current decay
# t:437 I:0.054	g:0.014	u:0.018	x:0.292	v:3.910	current decay
# t:438 I:0.048	g:0.012	u:0.017	x:0.294	v:3.898	current decay
# t:439 I:0.044	g:0.011	u:0.016	x:0.296	v:3.886	current decay
# t:440 I:0.040	g:0.010	u:0.015	x:0.297	v:3.874	current decay
# t:441 I:0.036	g:0.009	u:0.014	x:0.299	v:3.862	current decay
# t:442 I:0.036	g:1.145	u:0.270	x:0.219	v:3.850	synaptic spike
# t:442 I:4.409	g:1.145	u:0.270	x:0.219	v:3.850	current decay
# t:443 I:3.973	g:1.038	u:0.254	x:0.221	v:3.826	current decay
# t:444 I:3.581	g:0.942	u:0.239	x:0.223	v:3.804	current decay
# t:445 I:3.230	g:0.854	u:0.226	x:0.225	v:3.783	current decay
# t:446 I:2.913	g:0.774	u:0.212	x:0.226	v:3.764	current decay
# t:447 I:2.629	g:0.702	u:0.200	x:0.228	v:3.747	current decay
# t:448 I:2.373	g:0.636	u:0.188	x:0.230	v:3.730	current decay
# t:449 I:2.142	g:0.577	u:0.177	x:0.232	v:3.714	current decay
# t:450 I:1.934	g:0.523	u:0.167	x:0.234	v:3.699	current decay
# t:451 I:1.747	g:0.474	u:0.157	x:0.235	v:3.684	current decay
# t:452 I:1.578	g:0.430	u:0.148	x:0.237	v:3.670	current decay
# t:453 I:1.425	g:0.390	u:0.140	x:0.239	v:3.657	current decay
# t:454 I:1.287	g:0.353	u:0.132	x:0.241	v:3.644	current decay
# t:455 I:1.163	g:0.320	u:0.124	x:0.242	v:3.631	current decay
# t:456 I:1.051	g:0.290	u:0.117	x:0.244	v:3.618	current decay
# t:457 I:0.949	g:0.263	u:0.110	x:0.246	v:3.605	current decay
# t:458 I:0.858	g:0.239	u:0.104	x:0.248	v:3.593	current decay
# t:459 I:0.775	g:0.216	u:0.098	x:0.249	v:3.581	current decay
# t:460 I:0.700	g:0.196	u:0.092	x:0.251	v:3.568	current decay
# t:461 I:0.633	g:0.178	u:0.086	x:0.253	v:3.556	current decay
# t:462 I:0.572	g:0.161	u:0.081	x:0.254	v:3.544	current decay
# t:463 I:0.516	g:0.146	u:0.077	x:0.256	v:3.531	current decay
# t:464 I:0.467	g:0.133	u:0.072	x:0.258	v:3.519	current decay
# t:465 I:0.422	g:0.120	u:0.068	x:0.260	v:3.507	current decay
# t:466 I:0.381	g:0.109	u:0.064	x:0.261	v:3.494	current decay
# t:467 I:0.344	g:0.099	u:0.060	x:0.263	v:3.482	current decay
# t:468 I:0.311	g:0.090	u:0.057	x:0.265	v:3.469	current decay
# t:469 I:0.281	g:0.081	u:0.054	x:0.266	v:3.457	current decay
# t:470 I:0.254	g:0.074	u:0.050	x:0.268	v:3.444	current decay
# t:471 I:0.229	g:0.067	u:0.048	x:0.270	v:3.431	current decay
# t:472 I:0.207	g:0.061	u:0.045	x:0.271	v:3.418	current decay
# t:473 I:0.187	g:0.055	u:0.042	x:0.273	v:3.405	current decay
# t:474 I:0.169	g:0.050	u:0.040	x:0.275	v:3.392	current decay
# t:475 I:0.152	g:0.045	u:0.037	x:0.276	v:3.379	current decay
# t:476 I:0.138	g:0.041	u:0.035	x:0.278	v:3.366	current decay
# t:477 I:0.124	g:0.037	u:0.033	x:0.280	v:3.352	current decay
# t:478 I:0.112	g:0.034	u:0.031	x:0.281	v:3.339	current decay
# t:479 I:0.101	g:0.030	u:0.029	x:0.283	v:3.325	current decay
# t:480 I:0.092	g:0.028	u:0.028	x:0.285	v:3.312	current decay
# t:481 I:0.083	g:0.025	u:0.026	x:0.286	v:3.298	current decay
# t:482 I:0.075	g:0.023	u:0.025	x:0.288	v:3.284	current decay
# t:483 I:0.067	g:0.021	u:0.023	x:0.290	v:3.271	current decay
# t:484 I:0.061	g:0.019	u:0.022	x:0.291	v:3.257	current decay
# t:485 I:0.055	g:0.017	u:0.021	x:0.293	v:3.243	current decay
# t:486 I:0.050	g:0.015	u:0.019	x:0.294	v:3.229	current decay
# t:487 I:0.045	g:0.014	u:0.018	x:0.296	v:3.214	current decay
# t:488 I:0.040	g:0.013	u:0.017	x:0.298	v:3.200	current decay
# t:489 I:0.036	g:0.011	u:0.016	x:0.299	v:3.186	current decay
# t:490 I:0.033	g:0.010	u:0.015	x:0.301	v:3.171	current decay
# t:491 I:0.030	g:0.009	u:0.014	x:0.302	v:3.157	current decay
# t:492 I:0.027	g:0.009	u:0.014	x:0.304	v:3.143	current decay
# t:493 I:0.027	g:1.162	u:0.269	x:0.223	v:3.128	synaptic spike
# t:493 I:3.634	g:1.162	u:0.269	x:0.223	v:3.128	current decay
# t:494 I:3.270	g:1.053	u:0.254	x:0.225	v:3.104	current decay
# t:495 I:2.943	g:0.955	u:0.239	x:0.227	v:3.081	current decay
# t:496 I:2.650	g:0.866	u:0.225	x:0.229	v:3.060	current decay
# t:497 I:2.387	g:0.785	u:0.212	x:0.230	v:3.040	current decay
# t:498 I:2.150	g:0.712	u:0.200	x:0.232	v:3.021	current decay
# t:499 I:1.938	g:0.645	u:0.188	x:0.234	v:3.003	current decay
# t:500 I:1.747	g:0.585	u:0.177	x:0.236	v:2.986	current decay
# t:501 I:1.575	g:0.530	u:0.167	x:0.237	v:2.969	current decay
# t:502 I:1.420	g:0.481	u:0.157	x:0.239	v:2.953	current decay
# t:503 I:1.281	g:0.436	u:0.148	x:0.241	v:2.937	current decay
# t:504 I:1.155	g:0.395	u:0.139	x:0.243	v:2.921	current decay
# t:505 I:1.042	g:0.358	u:0.131	x:0.244	v:2.906	current decay
# t:506 I:0.939	g:0.325	u:0.124	x:0.246	v:2.891	current decay
# t:507 I:0.847	g:0.295	u:0.116	x:0.248	v:2.876	current decay
# t:508 I:0.764	g:0.267	u:0.110	x:0.250	v:2.861	current decay
# t:509 I:0.689	g:0.242	u:0.103	x:0.251	v:2.846	current decay
# t:510 I:0.622	g:0.220	u:0.097	x:0.253	v:2.832	current decay
# t:511 I:0.561	g:0.199	u:0.092	x:0.255	v:2.817	current decay
# t:512 I:0.506	g:0.180	u:0.086	x:0.256	v:2.803	current decay
# t:513 I:0.456	g:0.164	u:0.081	x:0.258	v:2.788	current decay
# t:514 I:0.411	g:0.148	u:0.077	x:0.260	v:2.773	current decay
# t:515 I:0.371	g:0.134	u:0.072	x:0.262	v:2.759	current decay
# t:516 I:0.335	g:0.122	u:0.068	x:0.263	v:2.744	current decay
# t:517 I:0.302	g:0.111	u:0.064	x:0.265	v:2.729	current decay
# t:518 I:0.272	g:0.100	u:0.060	x:0.267	v:2.714	current decay
# t:519 I:0.245	g:0.091	u:0.057	x:0.268	v:2.700	current decay
# t:520 I:0.221	g:0.082	u:0.053	x:0.270	v:2.685	current decay
# t:521 I:0.199	g:0.075	u:0.050	x:0.272	v:2.669	current decay
# t:522 I:0.180	g:0.068	u:0.047	x:0.273	v:2.654	current decay
# t:523 I:0.162	g:0.061	u:0.045	x:0.275	v:2.639	current decay
# t:524 I:0.146	g:0.056	u:0.042	x:0.277	v:2.624	current decay
# t:525 I:0.132	g:0.050	u:0.040	x:0.278	v:2.608	current decay
# t:526 I:0.119	g:0.046	u:0.037	x:0.280	v:2.593	current decay
# t:527 I:0.107	g:0.041	u:0.035	x:0.282	v:2.577	current decay
# t:528 I:0.096	g:0.038	u:0.033	x:0.283	v:2.562	current decay
# t:529 I:0.087	g:0.034	u:0.031	x:0.285	v:2.546	current decay
# t:530 I:0.078	g:0.031	u:0.029	x:0.287	v:2.530	current decay
# t:531 I:0.070	g:0.028	u:0.028	x:0.288	v:2.515	current decay
# t:532 I:0.064	g:0.025	u:0.026	x:0.290	v:2.499	current decay
# t:533 I:0.057	g:0.023	u:0.025	x:0.292	v:2.483	current decay
# t:534 I:0.052	g:0.021	u:0.023	x:0.293	v:2.467	current decay
# t:535 I:0.046	g:0.019	u:0.022	x:0.295	v:2.450	current decay
# t:536 I:0.042	g:0.017	u:0.020	x:0.296	v:2.434	current decay
# t:537 I:0.038	g:0.016	u:0.019	x:0.298	v:2.418	current decay
# t:538 I:0.034	g:0.014	u:0.018	x:0.300	v:2.402	current decay
# t:539 I:0.031	g:0.013	u:0.017	x:0.301	v:2.385	current decay
# t:540 I:0.027	g:0.012	u:0.016	x:0.303	v:2.369	current decay
# t:541 I:0.025	g:0.011	u:0.015	x:0.304	v:2.352	current decay
# t:542 I:0.022	g:0.010	u:0.014	x:0.306	v:2.336	current decay
# t:543 I:0.020	g:0.009	u:0.013	x:0.308	v:2.319	current decay
# t:544 I:0.020	g:1.175	u:0.269	x:0.226	v:2.302	synaptic spike
# t:544 I:2.706	g:1.175	u:0.269	x:0.226	v:2.302	current decay
# t:545 I:2.428	g:1.066	u:0.254	x:0.228	v:2.278	current decay
# t:546 I:2.179	g:0.966	u:0.239	x:0.229	v:2.256	current decay
# t:547 I:1.957	g:0.876	u:0.225	x:0.231	v:2.234	current decay
# t:548 I:1.758	g:0.794	u:0.212	x:0.233	v:2.214	current decay
# t:549 I:1.579	g:0.720	u:0.200	x:0.235	v:2.194	current decay
# t:550 I:1.419	g:0.653	u:0.188	x:0.237	v:2.175	current decay
# t:551 I:1.276	g:0.592	u:0.177	x:0.238	v:2.156	current decay
# t:552 I:1.147	g:0.537	u:0.167	x:0.240	v:2.137	current decay
# t:553 I:1.031	g:0.486	u:0.157	x:0.242	v:2.120	current decay
# t:554 I:0.927	g:0.441	u:0.148	x:0.243	v:2.102	current decay
# t:555 I:0.834	g:0.400	u:0.139	x:0.245	v:2.084	current decay
# t:556 I:0.749	g:0.363	u:0.131	x:0.247	v:2.067	current decay
# t:557 I:0.674	g:0.329	u:0.124	x:0.249	v:2.050	current decay
# t:558 I:0.606	g:0.298	u:0.116	x:0.250	v:2.033	current decay
# t:559 I:0.545	g:0.270	u:0.110	x:0.252	v:2.016	current decay
# t:560 I:0.490	g:0.245	u:0.103	x:0.254	v:1.999	current decay
# t:561 I:0.440	g:0.222	u:0.097	x:0.256	v:1.983	current decay
# t:562 I:0.396	g:0.201	u:0.092	x:0.257	v:1.966	current decay
# t:563 I:0.356	g:0.183	u:0.086	x:0.259	v:1.949	current decay
# t:564 I:0.320	g:0.166	u:0.081	x:0.261	v:1.932	current decay
# t:565 I:0.287	g:0.150	u:0.077	x:0.262	v:1.915	current decay
# t:566 I:0.258	g:0.136	u:0.072	x:0.264	v:1.898	current decay
# t:567 I:0.232	g:0.123	u:0.068	x:0.266	v:1.881	current decay
# t:568 I:0.208	g:0.112	u:0.064	x:0.267	v:1.864	current decay
# t:569 I:0.187	g:0.101	u:0.060	x:0.269	v:1.847	current decay
# t:570 I:0.168	g:0.092	u:0.057	x:0.271	v:1.830	current decay
# t:571 I:0.151	g:0.083	u:0.053	x:0.272	v:1.813	current decay
# t:572 I:0.136	g:0.076	u:0.050	x:0.274	v:1.796	current decay
# t:573 I:0.122	g:0.069	u:0.047	x:0.276	v:1.778	current decay
# t:574 I:0.109	g:0.062	u:0.045	x:0.277	v:1.761	current decay
# t:575 I:0.098	g:0.056	u:0.042	x:0.279	v:1.743	current decay
# t:576 I:0.088	g:0.051	u:0.040	x:0.281	v:1.726	current decay
# t:577 I:0.079	g:0.046	u:0.037	x:0.282	v:1.708	current decay
# t:578 I:0.071	g:0.042	u:0.035	x:0.284	v:1.691	current decay
# t:579 I:0.064	g:0.038	u:0.033	x:0.286	v:1.673	current decay
# t:580 I:0.057	g:0.034	u:0.031	x:0.287	v:1.655	current decay
# t:581 I:0.051	g:0.031	u:0.029	x:0.289	v:1.637	current decay
# t:582 I:0.046	g:0.028	u:0.028	x:0.291	v:1.619	current decay
# t:583 I:0.041	g:0.026	u:0.026	x:0.292	v:1.601	current decay
# t:584 I:0.037	g:0.023	u:0.025	x:0.294	v:1.583	current decay
# t:585 I:0.033	g:0.021	u:0.023	x:0.295	v:1.565	current decay
# t:586 I:0.030	g:0.019	u:0.022	x:0.297	v:1.547	current decay
# t:587 I:0.027	g:0.017	u:0.020	x:0.299	v:1.529	current decay
# t:588 I:0.024	g:0.016	u:0.019	x:0.300	v:1.510	current decay
# t:589 I:0.021	g:0.014	u:0.018	x:0.302	v:1.492	current decay
# t:590 I:0.019	g:0.013	u:0.017	x:0.304	v:1.474	current decay
# t:591 I:0.017	g:0.012	u:0.016	x:0.305	v:1.455	current decay
# t:592 I:0.015	g:0.011	u:0.015	x:0.307	v:1.437	current decay
# t:593 I:0.014	g:0.010	u:0.014	x:0.308	v:1.418	current decay
# t:594 I:0.012	g:0.009	u:0.013	x:0.310	v:1.400	current decay
# t:595 I:0.012	g:1.184	u:0.269	x:0.228	v:1.381	synaptic spike
# t:595 I:1.635	g:1.184	u:0.269	x:0.228	v:1.381	current decay
# t:596 I:1.458	g:1.074	u:0.254	x:0.229	v:1.358	current decay
# t:597 I:1.300	g:0.973	u:0.239	x:0.231	v:1.336	current decay
# t:598 I:1.160	g:0.882	u:0.225	x:0.233	v:1.315	current decay
# t:599 I:1.035	g:0.800	u:0.212	x:0.235	v:1.294	current decay
# t:600 I:0.924	g:0.725	u:0.200	x:0.236	v:1.273	current decay
# t:601 I:0.824	g:0.658	u:0.188	x:0.238	v:1.253	current decay
# t:602 I:0.735	g:0.596	u:0.177	x:0.240	v:1.233	current decay
# t:603 I:0.656	g:0.541	u:0.167	x:0.242	v:1.214	current decay
# t:604 I:0.585	g:0.490	u:0.157	x:0.243	v:1.194	current decay
# t:605 I:0.522	g:0.444	u:0.148	x:0.245	v:1.175	current decay
# t:606 I:0.466	g:0.403	u:0.139	x:0.247	v:1.156	current decay
# t:607 I:0.415	g:0.365	u:0.131	x:0.249	v:1.137	current decay
# t:608 I:0.370	g:0.331	u:0.124	x:0.250	v:1.118	current decay
# t:609 I:0.330	g:0.300	u:0.116	x:0.252	v:1.099	current decay
# t:610 I:0.294	g:0.272	u:0.110	x:0.254	v:1.080	current decay
# t:611 I:0.262	g:0.247	u:0.103	x:0.255	v:1.062	current decay
# t:612 I:0.233	g:0.224	u:0.097	x:0.257	v:1.043	current decay
# t:613 I:0.208	g:0.203	u:0.092	x:0.259	v:1.024	current decay
# t:614 I:0.185	g:0.184	u:0.086	x:0.261	v:1.005	current decay
# t:615 I:0.164	g:0.167	u:0.081	x:0.262	v:0.986	current decay
# t:616 I:0.146	g:0.151	u:0.077	x:0.264	v:0.967	current decay
# t:617 I:0.130	g:0.137	u:0.072	x:0.266	v:0.948	current decay
# t:618 I:0.116	g:0.124	u:0.068	x:0.267	v:0.929	current decay
# t:619 I:0.103	g:0.113	u:0.064	x:0.269	v:0.910	current decay
# t:620 I:0.091	g:0.102	u:0.060	x:0.271	v:0.891	current decay
# t:621 I:0.081	g:0.093	u:0.057	x:0.272	v:0.872	current decay
# t:622 I:0.072	g:0.084	u:0.053	x:0.274	v:0.853	current decay
# t:623 I:0.063	g:0.076	u:0.050	x:0.276	v:0.834	current decay
# t:624 I:0.056	g:0.069	u:0.047	x:0.277	v:0.815	current decay
# t:625 I:0.050	g:0.063	u:0.045	x:0.279	v:0.795	current decay
# t:626 I:0.044	g:0.057	u:0.042	x:0.281	v:0.776	current decay
# t:627 I:0.039	g:0.051	u:0.040	x:0.282	v:0.756	current decay
# t:628 I:0.034	g:0.047	u:0.037	x:0.284	v:0.737	current decay
# t:629 I:0.030	g:0.042	u:0.035	x:0.286	v:0.717	current decay
# t:630 I:0.027	g:0.038	u:0.033	x:0.287	v:0.698	current decay
# t:631 I:0.024	g:0.035	u:0.031	x:0.289	v:0.678	current decay
# t:632 I:0.021	g:0.032	u:0.029	x:0.291	v:0.659	current decay
# t:633 I:0.018	g:0.029	u:0.028	x:0.292	v:0.639	current decay
# t:634 I:0.016	g:0.026	u:0.026	x:0.294	v:0.619	current decay
# t:635 I:0.014	g:0.023	u:0.025	x:0.295	v:0.599	current decay
# t:636 I:0.012	g:0.021	u:0.023	x:0.297	v:0.579	current decay
# t:637 I:0.011	g:0.019	u:0.022	x:0.299	v:0.560	current decay
# t:638 I:0.009	g:0.018	u:0.020	x:0.300	v:0.540	current decay
# t:639 I:0.008	g:0.016	u:0.019	x:0.302	v:0.520	current decay
# t:640 I:0.007	g:0.014	u:0.018	x:0.303	v:0.500	current decay
# t:641 I:0.006	g:0.013	u:0.017	x:0.305	v:0.480	current decay
# t:642 I:0.005	g:0.012	u:0.016	x:0.307	v:0.460	current decay
# t:643 I:0.005	g:0.011	u:0.015	x:0.308	v:0.440	current decay
# t:644 I:0.004	g:0.010	u:0.014	x:0.310	v:0.419	current decay
# t:645 I:0.004	g:0.009	u:0.013	x:0.311	v:0.399	current decay
# t:646 I:0.004	g:1.190	u:0.269	x:0.229	v:0.379	synaptic spike
# t:646 I:0.451	g:1.190	u:0.269	x:0.229	v:0.379	current decay
# t:647 I:0.386	g:1.079	u:0.254	x:0.230	v:0.358	current decay
# t:648 I:0.329	g:0.978	u:0.239	x:0.232	v:0.336	current decay
# t:649 I:0.280	g:0.887	u:0.225	x:0.234	v:0.316	current decay
# t:650 I:0.237	g:0.804	u:0.212	x:0.236	v:0.295	current decay
# t:651 I:0.200	g:0.729	u:0.200	x:0.238	v:0.274	current decay
# t:652 I:0.167	g:0.661	u:0.188	x:0.239	v:0.253	current decay
# t:653 I:0.140	g:0.599	u:0.177	x:0.241	v:0.233	current decay
# t:654 I:0.115	g:0.543	u:0.167	x:0.243	v:0.212	current decay
# t:655 I:0.095	g:0.493	u:0.157	x:0.244	v:0.192	current decay
# t:656 I:0.077	g:0.447	u:0.148	x:0.246	v:0.172	current decay
# t:657 I:0.061	g:0.405	u:0.139	x:0.248	v:0.151	current decay
# t:658 I:0.048	g:0.367	u:0.131	x:0.250	v:0.131	current decay
# t:659 I:0.037	g:0.333	u:0.124	x:0.251	v:0.110	current decay
# t:660 I:0.027	g:0.302	u:0.116	x:0.253	v:0.090	current decay
# t:661 I:0.019	g:0.274	u:0.110	x:0.255	v:0.069	current decay
# t:662 I:0.012	g:0.248	u:0.103	x:0.257	v:0.049	current decay
# t:663 I:0.006	g:0.225	u:0.097	x:0.258	v:0.029	current decay
# t:664 I:0.002	g:0.204	u:0.092	x:0.260	v:0.008	current decay
# t:665 I:-0.002	g:0.185	u:0.086	x:0.262	v:-0.013	current decay
# t:666 I:-0.006	g:0.168	u:0.081	x:0.263	v:-0.033	current decay
# t:667 I:-0.008	g:0.152	u:0.077	x:0.265	v:-0.054	current decay
# t:668 I:-0.010	g:0.138	u:0.072	x:0.267	v:-0.074	current decay
# t:669 I:-0.012	g:0.125	u:0.068	x:0.268	v:-0.095	current decay
# t:670 I:-0.013	g:0.113	u:0.064	x:0.270	v:-0.116	current decay
# t:671 I:-0.014	g:0.103	u:0.060	x:0.272	v:-0.136	current decay
# t:672 I:-0.015	g:0.093	u:0.057	x:0.273	v:-0.157	current decay
# t:673 I:-0.015	g:0.084	u:0.053	x:0.275	v:-0.178	current decay
# t:674 I:-0.015	g:0.076	u:0.050	x:0.277	v:-0.199	current decay
# t:675 I:-0.015	g:0.069	u:0.047	x:0.278	v:-0.220	current decay
# t:676 I:-0.015	g:0.063	u:0.045	x:0.280	v:-0.241	current decay
# t:677 I:-0.015	g:0.057	u:0.042	x:0.282	v:-0.262	current decay
# t:678 I:-0.015	g:0.052	u:0.040	x:0.283	v:-0.282	current decay
# t:679 I:-0.014	g:0.047	u:0.037	x:0.285	v:-0.303	current decay
# t:680 I:-0.014	g:0.042	u:0.035	x:0.287	v:-0.324	current decay
# t:681 I:-0.013	g:0.039	u:0.033	x:0.288	v:-0.345	current decay
# t:682 I:-0.013	g:0.035	u:0.031	x:0.290	v:-0.367	current decay
# t:683 I:-0.012	g:0.032	u:0.029	x:0.292	v:-0.388	current decay
# t:684 I:-0.012	g:0.029	u:0.028	x:0.293	v:-0.409	current decay
# t:685 I:-0.011	g:0.026	u:0.026	x:0.295	v:-0.430	current decay
# t:686 I:-0.011	g:0.024	u:0.025	x:0.296	v:-0.451	current decay
# t:687 I:-0.010	g:0.021	u:0.023	x:0.298	v:-0.472	current decay
# t:688 I:-0.010	g:0.019	u:0.022	x:0.300	v:-0.493	current decay
# t:689 I:-0.009	g:0.018	u:0.020	x:0.301	v:-0.514	current decay
# t:690 I:-0.009	g:0.016	u:0.019	x:0.303	v:-0.536	current decay
# t:691 I:-0.008	g:0.014	u:0.018	x:0.304	v:-0.557	current decay
# t:692 I:-0.008	g:0.013	u:0.017	x:0.306	v:-0.578	current decay
# t:693 I:-0.007	g:0.012	u:0.016	x:0.308	v:-0.600	current decay
# t:694 I:-0.007	g:0.011	u:0.015	x:0.309	v:-0.621	current decay
# t:695 I:-0.006	g:0.010	u:0.014	x:0.311	v:-0.642	current decay
# t:696 I:-0.006	g:0.009	u:0.013	x:0.312	v:-0.663	current decay
# t:697 I:-0.006	g:1.194	u:0.269	x:0.229	v:-0.685	synaptic spike
# t:697 I:-0.817	g:1.194	u:0.269	x:0.229	v:-0.685	current decay
# t:698 I:-0.762	g:1.082	u:0.254	x:0.231	v:-0.704	current decay
# t:699 I:-0.710	g:0.981	u:0.239	x:0.233	v:-0.724	current decay
# t:700 I:-0.661	g:0.890	u:0.225	x:0.235	v:-0.744	current decay
# t:701 I:-0.616	g:0.806	u:0.212	x:0.236	v:-0.764	current decay
# t:702 I:-0.573	g:0.731	u:0.200	x:0.238	v:-0.784	current decay
# t:703 I:-0.534	g:0.663	u:0.188	x:0.240	v:-0.805	current decay
# t:704 I:-0.496	g:0.601	u:0.177	x:0.242	v:-0.826	current decay
# t:705 I:-0.461	g:0.545	u:0.167	x:0.243	v:-0.847	current decay
# t:706 I:-0.429	g:0.494	u:0.157	x:0.245	v:-0.868	current decay
# t:707 I:-0.398	g:0.448	u:0.148	x:0.247	v:-0.889	current decay
# t:708 I:-0.370	g:0.406	u:0.139	x:0.249	v:-0.911	current decay
# t:709 I:-0.343	g:0.368	u:0.131	x:0.250	v:-0.932	current decay
# t:710 I:-0.318	g:0.334	u:0.124	x:0.252	v:-0.954	current decay
# t:711 I:-0.295	g:0.303	u:0.116	x:0.254	v:-0.975	current decay
# t:712 I:-0.274	g:0.274	u:0.110	x:0.256	v:-0.997	current decay
# t:713 I:-0.253	g:0.249	u:0.103	x:0.257	v:-1.019	current decay
# t:714 I:-0.235	g:0.226	u:0.097	x:0.259	v:-1.040	current decay
# t:715 I:-0.217	g:0.204	u:0.092	x:0.261	v:-1.062	current decay
# t:716 I:-0.201	g:0.185	u:0.086	x:0.262	v:-1.084	current decay
# t:717 I:-0.186	g:0.168	u:0.081	x:0.264	v:-1.106	current decay
# t:718 I:-0.172	g:0.152	u:0.077	x:0.266	v:-1.128	current decay
# t:719 I:-0.159	g:0.138	u:0.072	x:0.267	v:-1.150	current decay
# t:720 I:-0.147	g:0.125	u:0.068	x:0.269	v:-1.172	current decay
# t:721 I:-0.136	g:0.114	u:0.064	x:0.271	v:-1.194	current decay
# t:722 I:-0.125	g:0.103	u:0.060	x:0.272	v:-1.216	current decay
# t:723 I:-0.116	g:0.093	u:0.057	x:0.274	v:-1.238	current decay
# t:724 I:-0.107	g:0.085	u:0.053	x:0.276	v:-1.260	current decay
# t:725 I:-0.098	g:0.077	u:0.050	x:0.277	v:-1.282	current decay
# t:726 I:-0.091	g:0.070	u:0.047	x:0.279	v:-1.304	current decay
# t:727 I:-0.084	g:0.063	u:0.045	x:0.281	v:-1.326	current decay
# t:728 I:-0.077	g:0.057	u:0.042	x:0.282	v:-1.348	current decay
# t:729 I:-0.071	g:0.052	u:0.040	x:0.284	v:-1.370	current decay
# t:730 I:-0.065	g:0.047	u:0.037	x:0.286	v:-1.392	current decay
# t:731 I:-0.060	g:0.043	u:0.035	x:0.287	v:-1.414	current decay
# t:732 I:-0.055	g:0.039	u:0.033	x:0.289	v:-1.436	current decay
# t:733 I:-0.051	g:0.035	u:0.031	x:0.291	v:-1.458	current decay
# t:734 I:-0.047	g:0.032	u:0.029	x:0.292	v:-1.480	current decay
# t:735 I:-0.043	g:0.029	u:0.028	x:0.294	v:-1.502	current decay
# t:736 I:-0.040	g:0.026	u:0.026	x:0.295	v:-1.524	current decay
# t:737 I:-0.037	g:0.024	u:0.025	x:0.297	v:-1.546	current decay
# t:738 I:-0.034	g:0.021	u:0.023	x:0.299	v:-1.568	current decay
# t:739 I:-0.031	g:0.019	u:0.022	x:0.300	v:-1.590	current decay
# t:740 I:-0.028	g:0.018	u:0.020	x:0.302	v:-1.612	current decay
# t:741 I:-0.026	g:0.016	u:0.019	x:0.304	v:-1.634	current decay
# t:742 I:-0.024	g:0.015	u:0.018	x:0.305	v:-1.656	current decay
# t:743 I:-0.022	g:0.013	u:0.017	x:0.307	v:-1.678	current decay
# t:744 I:-0.020	g:0.012	u:0.016	x:0.308	v:-1.700	current decay
# t:745 I:-0.019	g:0.011	u:0.015	x:0.310	v:-1.722	current decay
# t:746 I:-0.017	g:0.010	u:0.014	x:0.311	v:-1.744	current decay
# t:747 I:-0.016	g:0.009	u:0.013	x:0.313	v:-1.767	current decay
# t:748 I:-0.016	g:1.196	u:0.269	x:0.230	v:-1.789	synaptic spike
# t:748 I:-2.139	g:1.196	u:0.269	x:0.230	v:-1.789	current decay
# t:749 I:-1.957	g:1.084	u:0.254	x:0.232	v:-1.805	current decay
# t:750 I:-1.792	g:0.983	u:0.239	x:0.233	v:-1.823	current decay
# t:751 I:-1.641	g:0.891	u:0.225	x:0.235	v:-1.841	current decay
# t:752 I:-1.503	g:0.808	u:0.212	x:0.237	v:-1.860	current decay
# t:753 I:-1.377	g:0.733	u:0.200	x:0.239	v:-1.880	current decay
# t:754 I:-1.262	g:0.664	u:0.188	x:0.240	v:-1.900	current decay
# t:755 I:-1.157	g:0.602	u:0.177	x:0.242	v:-1.921	current decay
# t:756 I:-1.060	g:0.546	u:0.167	x:0.244	v:-1.942	current decay
# t:757 I:-0.972	g:0.495	u:0.157	x:0.246	v:-1.964	current decay
# t:758 I:-0.891	g:0.449	u:0.148	x:0.247	v:-1.985	current decay
# t:759 I:-0.817	g:0.407	u:0.139	x:0.249	v:-2.007	current decay
# t:760 I:-0.749	g:0.369	u:0.131	x:0.251	v:-2.029	current decay
# t:761 I:-0.686	g:0.334	u:0.124	x:0.253	v:-2.052	current decay
# t:762 I:-0.629	g:0.303	u:0.116	x:0.254	v:-2.074	current decay
# t:763 I:-0.576	g:0.275	u:0.110	x:0.256	v:-2.097	current decay
# t:764 I:-0.528	g:0.249	u:0.103	x:0.258	v:-2.119	current decay
# t:765 I:-0.484	g:0.226	u:0.097	x:0.259	v:-2.142	current decay
# t:766 I:-0.444	g:0.205	u:0.092	x:0.261	v:-2.165	current decay
# t:767 I:-0.406	g:0.186	u:0.086	x:0.263	v:-2.188	current decay
# t:768 I:-0.372	g:0.168	u:0.081	x:0.264	v:-2.210	current decay
# t:769 I:-0.341	g:0.153	u:0.077	x:0.266	v:-2.233	current decay
# t:770 I:-0.312	g:0.138	u:0.072	x:0.268	v:-2.256	current decay
# t:771 I:-0.286	g:0.126	u:0.068	x:0.270	v:-2.279	current decay
# t:772 I:-0.262	g:0.114	u:0.064	x:0.271	v:-2.301	current decay
# t:773 I:-0.240	g:0.103	u:0.060	x:0.273	v:-2.324	current decay
# t:774 I:-0.220	g:0.094	u:0.057	x:0.275	v:-2.347	current decay
# t:775 I:-0.201	g:0.085	u:0.053	x:0.276	v:-2.370	current decay
# t:776 I:-0.184	g:0.077	u:0.050	x:0.278	v:-2.392	current decay
# t:777 I:-0.168	g:0.070	u:0.047	x:0.280	v:-2.415	current decay
# t:778 I:-0.154	g:0.063	u:0.045	x:0.281	v:-2.438	current decay
# t:779 I:-0.141	g:0.057	u:0.042	x:0.283	v:-2.461	current decay
# t:780 I:-0.129	g:0.052	u:0.040	x:0.284	v:-2.483	current decay
# t:781 I:-0.118	g:0.047	u:0.037	x:0.286	v:-2.506	current decay
# t:782 I:-0.108	g:0.043	u:0.035	x:0.288	v:-2.528	current decay
# t:783 I:-0.099	g:0.039	u:0.033	x:0.289	v:-2.551	current decay
# t:784 I:-0.090	g:0.035	u:0.031	x:0.291	v:-2.573	current decay
# t:785 I:-0.083	g:0.032	u:0.029	x:0.293	v:-2.596	current decay
# t:786 I:-0.076	g:0.029	u:0.028	x:0.294	v:-2.619	current decay
# t:787 I:-0.069	g:0.026	u:0.026	x:0.296	v:-2.641	current decay
# t:788 I:-0.063	g:0.024	u:0.025	x:0.297	v:-2.663	current decay
# t:789 I:-0.058	g:0.022	u:0.023	x:0.299	v:-2.686	current decay
# t:790 I:-0.053	g:0.019	u:0.022	x:0.301	v:-2.708	current decay
# t:791 I:-0.048	g:0.018	u:0.020	x:0.302	v:-2.731	current decay
# t:792 I:-0.044	g:0.016	u:0.019	x:0.304	v:-2.753	current decay
# t:793 I:-0.040	g:0.015	u:0.018	x:0.306	v:-2.776	current decay
# t:794 I:-0.037	g:0.013	u:0.017	x:0.307	v:-2.798	current decay
# t:795 I:-0.034	g:0.012	u:0.016	x:0.309	v:-2.820	current decay
# t:796 I:-0.031	g:0.011	u:0.015	x:0.310	v:-2.843	current decay
# t:797 I:-0.028	g:0.010	u:0.014	x:0.312	v:-2.865	current decay
# t:798 I:-0.026	g:0.009	u:0.013	x:0.313	v:-2.887	current decay
# t:799 I:-0.026	g:1.198	u:0.269	x:0.230	v:-2.910	synaptic spike
# t:799 I:-3.485	g:1.198	u:0.269	x:0.230	v:-2.910	current decay
# t:800 I:-3.174	g:1.086	u:0.254	x:0.232	v:-2.923	current decay
# t:801 I:-2.892	g:0.984	u:0.239	x:0.234	v:-2.938	current decay
# t:802 I:-2.637	g:0.893	u:0.225	x:0.235	v:-2.954	current decay
# t:803 I:-2.405	g:0.809	u:0.212	x:0.237	v:-2.972	current decay
# t:804 I:-2.194	g:0.734	u:0.200	x:0.239	v:-2.991	current decay
# t:805 I:-2.002	g:0.665	u:0.188	x:0.241	v:-3.010	current decay
# t:806 I:-1.828	g:0.603	u:0.177	x:0.242	v:-3.031	current decay
# t:807 I:-1.668	g:0.547	u:0.167	x:0.244	v:-3.051	current decay
# t:808 I:-1.523	g:0.496	u:0.157	x:0.246	v:-3.073	current decay
# t:809 I:-1.391	g:0.449	u:0.148	x:0.248	v:-3.095	current decay
# t:810 I:-1.270	g:0.407	u:0.139	x:0.249	v:-3.117	current decay
# t:811 I:-1.160	g:0.369	u:0.131	x:0.251	v:-3.139	current decay
# t:812 I:-1.059	g:0.335	u:0.124	x:0.253	v:-3.162	current decay
# t:813 I:-0.967	g:0.304	u:0.116	x:0.255	v:-3.185	current decay
# t:814 I:-0.883	g:0.275	u:0.110	x:0.256	v:-3.208	current decay
# t:815 I:-0.806	g:0.250	u:0.103	x:0.258	v:-3.231	current decay
# t:816 I:-0.736	g:0.226	u:0.097	x:0.260	v:-3.254	current decay
# t:817 I:-0.672	g:0.205	u:0.092	x:0.261	v:-3.277	current decay
# t:818 I:-0.614	g:0.186	u:0.086	x:0.263	v:-3.301	current decay
# t:819 I:-0.561	g:0.169	u:0.081	x:0.265	v:-3.324	current decay
# t:820 I:-0.512	g:0.153	u:0.077	x:0.266	v:-3.347	current decay
# t:821 I:-0.467	g:0.139	u:0.072	x:0.268	v:-3.370	current decay
# t:822 I:-0.427	g:0.126	u:0.068	x:0.270	v:-3.393	current decay
# t:823 I:-0.389	g:0.114	u:0.064	x:0.271	v:-3.417	current decay
# t:824 I:-0.355	g:0.103	u:0.060	x:0.273	v:-3.440	current decay
# t:825 I:-0.324	g:0.094	u:0.057	x:0.275	v:-3.463	current decay
# t:826 I:-0.296	g:0.085	u:0.053	x:0.276	v:-3.486	current decay
# t:827 I:-0.270	g:0.077	u:0.050	x:0.278	v:-3.509	current decay
# t:828 I:-0.247	g:0.070	u:0.047	x:0.280	v:-3.532	current decay
# t:829 I:-0.225	g:0.063	u:0.045	x:0.281	v:-3.555	current decay
# t:830 I:-0.205	g:0.057	u:0.042	x:0.283	v:-3.578	current decay
# t:831 I:-0.187	g:0.052	u:0.040	x:0.285	v:-3.601	current decay
# t:832 I:-0.171	g:0.047	u:0.037	x:0.286	v:-3.623	current decay
# t:833 I:-0.156	g:0.043	u:0.035	x:0.288	v:-3.646	current decay
# t:834 I:-0.142	g:0.039	u:0.033	x:0.290	v:-3.669	current decay
# t:835 I:-0.130	g:0.035	u:0.031	x:0.291	v:-3.691	current decay
# t:836 I:-0.118	g:0.032	u:0.029	x:0.293	v:-3.714	current decay
# t:837 I:-0.108	g:0.029	u:0.028	x:0.295	v:-3.737	current decay
# t:838 I:-0.098	g:0.026	u:0.026	x:0.296	v:-3.759	current decay
# t:839 I:-0.090	g:0.024	u:0.025	x:0.298	v:-3.782	current decay
# t:840 I:-0.082	g:0.022	u:0.023	x:0.299	v:-3.804	current decay
# t:841 I:-0.075	g:0.020	u:0.022	x:0.301	v:-3.826	current decay
# t:842 I:-0.068	g:0.018	u:0.020	x:0.303	v:-3.849	current decay
# t:843 I:-0.062	g:0.016	u:0.019	x:0.304	v:-3.871	current decay
# t:844 I:-0.057	g:0.015	u:0.018	x:0.306	v:-3.893	current decay
# t:845 I:-0.052	g:0.013	u:0.017	x:0.307	v:-3.916	current decay
# t:846 I:-0.047	g:0.012	u:0.016	x:0.309	v:-3.938	current decay
# t:847 I:-0.043	g:0.011	u:0.015	x:0.311	v:-3.960	current decay
# t:848 I:-0.039	g:0.010	u:0.014	x:0.312	v:-3.982	current decay
# t:849 I:-0.036	g:0.009	u:0.013	x:0.314	v:-4.004	current decay
# t:850 I:-0.036	g:1.199	u:0.269	x:0.230	v:-4.027	synaptic spike
# t:850 I:-4.826	g:1.199	u:0.269	x:0.230	v:-4.027	current decay
# t:851 I:-4.386	g:1.087	u:0.254	x:0.232	v:-4.036	current decay
# t:852 I:-3.989	g:0.985	u:0.239	x:0.234	v:-4.048	current decay
# t:853 I:-3.629	g:0.893	u:0.225	x:0.236	v:-4.063	current decay
# t:854 I:-3.303	g:0.810	u:0.212	x:0.237	v:-4.078	current decay
# t:855 I:-3.007	g:0.734	u:0.200	x:0.239	v:-4.096	current decay
# t:856 I:-2.739	g:0.666	u:0.188	x:0.241	v:-4.114	current decay
# t:857 I:-2.495	g:0.604	u:0.177	x:0.243	v:-4.134	current decay
# t:858 I:-2.273	g:0.547	u:0.167	x:0.244	v:-4.154	current decay
# t:859 I:-2.071	g:0.496	u:0.157	x:0.246	v:-4.175	current decay
# t:860 I:-1.888	g:0.450	u:0.148	x:0.248	v:-4.197	current decay
# t:861 I:-1.720	g:0.408	u:0.139	x:0.250	v:-4.219	current decay
# t:862 I:-1.568	g:0.370	u:0.131	x:0.251	v:-4.241	current decay
# t:863 I:-1.429	g:0.335	u:0.124	x:0.253	v:-4.264	current decay
# t:864 I:-1.303	g:0.304	u:0.116	x:0.255	v:-4.287	current decay
# t:865 I:-1.188	g:0.276	u:0.110	x:0.256	v:-4.310	current decay
# t:866 I:-1.082	g:0.250	u:0.103	x:0.258	v:-4.333	current decay
# t:867 I:-0.987	g:0.226	u:0.097	x:0.260	v:-4.356	current decay
# t:868 I:-0.899	g:0.205	u:0.092	x:0.262	v:-4.380	current decay
# t:869 I:-0.820	g:0.186	u:0.086	x:0.263	v:-4.403	current decay
# t:870 I:-0.747	g:0.169	u:0.081	x:0.265	v:-4.426	current decay
# t:871 I:-0.681	g:0.153	u:0.077	x:0.267	v:-4.450	current decay
# t:872 I:-0.621	g:0.139	u:0.072	x:0.268	v:-4.473	current decay
# t:873 I:-0.566	g:0.126	u:0.068	x:0.270	v:-4.496	current decay
# t:874 I:-0.515	g:0.114	u:0.064	x:0.272	v:-4.519	current decay
# t:875 I:-0.470	g:0.103	u:0.060	x:0.273	v:-4.542	current decay
# t:876 I:-0.428	g:0.094	u:0.057	x:0.275	v:-4.565	current decay
# t:877 I:-0.390	g:0.085	u:0.053	x:0.277	v:-4.588	current decay
# t:878 I:-0.355	g:0.077	u:0.050	x:0.278	v:-4.611	current decay
# t:879 I:-0.324	g:0.070	u:0.047	x:0.280	v:-4.634	current decay
# t:880 I:-0.295	g:0.063	u:0.045	x:0.282	v:-4.657	current decay
# t:881 I:-0.269	g:0.057	u:0.042	x:0.283	v:-4.680	current decay
# t:882 I:-0.245	g:0.052	u:0.040	x:0.285	v:-4.702	current decay
# t:883 I:-0.223	g:0.047	u:0.037	x:0.287	v:-4.725	current decay
# t:884 I:-0.203	g:0.043	u:0.035	x:0.288	v:-4.747	current decay
# t:885 I:-0.185	g:0.039	u:0.033	x:0.290	v:-4.770	current decay
# t:886 I:-0.169	g:0.035	u:0.031	x:0.291	v:-4.792	current decay
# t:887 I:-0.154	g:0.032	u:0.029	x:0.293	v:-4.814	current decay
# t:888 I:-0.140	g:0.029	u:0.028	x:0.295	v:-4.837	current decay
# t:889 I:-0.127	g:0.026	u:0.026	x:0.296	v:-4.859	current decay
# t:890 I:-0.116	g:0.024	u:0.025	x:0.298	v:-4.881	current decay
# t:891 I:-0.106	g:0.022	u:0.023	x:0.300	v:-4.903	current decay
# t:892 I:-0.096	g:0.020	u:0.022	x:0.301	v:-4.925	current decay
# t:893 I:-0.088	g:0.018	u:0.020	x:0.303	v:-4.947	current decay
# t:894 I:-0.080	g:0.016	u:0.019	x:0.304	v:-4.969	current decay
# t:895 I:-0.073	g:0.015	u:0.018	x:0.306	v:-4.991	current decay
# t:896 I:-0.066	g:0.013	u:0.017	x:0.308	v:-5.012	current decay
# t:897 I:-0.060	g:0.012	u:0.016	x:0.309	v:-5.034	current decay
# t:898 I:-0.055	g:0.011	u:0.015	x:0.311	v:-5.056	current decay
# t:899 I:-0.050	g:0.010	u:0.014	x:0.312	v:-5.078	current decay
# t:900 I:-0.045	g:0.009	u:0.013	x:0.314	v:-5.099	current decay
# t:901 I:-0.045	g:1.199	u:0.269	x:0.231	v:-5.121	synaptic spike
# t:901 I:-6.141	g:1.199	u:0.269	x:0.231	v:-5.121	current decay
# t:902 I:-5.574	g:1.087	u:0.254	x:0.232	v:-5.127	current decay
# t:903 I:-5.063	g:0.986	u:0.239	x:0.234	v:-5.136	current decay
# t:904 I:-4.601	g:0.894	u:0.225	x:0.236	v:-5.147	current decay
# t:905 I:-4.182	g:0.810	u:0.212	x:0.238	v:-5.161	current decay
# t:906 I:-3.803	g:0.735	u:0.200	x:0.239	v:-5.177	current decay
# t:907 I:-3.460	g:0.666	u:0.188	x:0.241	v:-5.194	current decay
# t:908 I:-3.148	g:0.604	u:0.177	x:0.243	v:-5.212	current decay
# t:909 I:-2.865	g:0.548	u:0.167	x:0.245	v:-5.232	current decay
# t:910 I:-2.607	g:0.496	u:0.157	x:0.246	v:-5.252	current decay
# t:911 I:-2.373	g:0.450	u:0.148	x:0.248	v:-5.273	current decay
# t:912 I:-2.161	g:0.408	u:0.139	x:0.250	v:-5.295	current decay
# t:913 I:-1.967	g:0.370	u:0.131	x:0.251	v:-5.317	current decay
# t:914 I:-1.791	g:0.335	u:0.124	x:0.253	v:-5.339	current decay
# t:915 I:-1.631	g:0.304	u:0.116	x:0.255	v:-5.362	current decay
# t:916 I:-1.485	g:0.276	u:0.110	x:0.257	v:-5.385	current decay
# t:917 I:-1.352	g:0.250	u:0.103	x:0.258	v:-5.408	current decay
# t:918 I:-1.231	g:0.227	u:0.097	x:0.260	v:-5.431	current decay
# t:919 I:-1.121	g:0.205	u:0.092	x:0.262	v:-5.454	current decay
# t:920 I:-1.020	g:0.186	u:0.086	x:0.263	v:-5.477	current decay
# t:921 I:-0.929	g:0.169	u:0.081	x:0.265	v:-5.500	current decay
# t:922 I:-0.846	g:0.153	u:0.077	x:0.267	v:-5.523	current decay
# t:923 I:-0.770	g:0.139	u:0.072	x:0.268	v:-5.546	current decay
# t:924 I:-0.701	g:0.126	u:0.068	x:0.270	v:-5.569	current decay
# t:925 I:-0.638	g:0.114	u:0.064	x:0.272	v:-5.592	current decay
# t:926 I:-0.581	g:0.103	u:0.060	x:0.273	v:-5.615	current decay
# t:927 I:-0.529	g:0.094	u:0.057	x:0.275	v:-5.638	current decay
# t:928 I:-0.481	g:0.085	u:0.053	x:0.277	v:-5.660	current decay
# t:929 I:-0.438	g:0.077	u:0.050	x:0.278	v:-5.683	current decay
# t:930 I:-0.399	g:0.070	u:0.047	x:0.280	v:-5.705	current decay
# t:931 I:-0.363	g:0.063	u:0.045	x:0.282	v:-5.727	current decay
# t:932 I:-0.330	g:0.057	u:0.042	x:0.283	v:-5.750	current decay
# t:933 I:-0.301	g:0.052	u:0.040	x:0.285	v:-5.772	current decay
# t:934 I:-0.274	g:0.047	u:0.037	x:0.287	v:-5.794	current decay
# t:935 I:-0.249	g:0.043	u:0.035	x:0.288	v:-5.816	current decay
# t:936 I:-0.227	g:0.039	u:0.033	x:0.290	v:-5.837	current decay
# t:937 I:-0.206	g:0.035	u:0.031	x:0.292	v:-5.859	current decay
# t:938 I:-0.188	g:0.032	u:0.029	x:0.293	v:-5.881	current decay
# t:939 I:-0.171	g:0.029	u:0.028	x:0.295	v:-5.902	current decay
# t:940 I:-0.155	g:0.026	u:0.026	x:0.296	v:-5.924	current decay
# t:941 I:-0.141	g:0.024	u:0.025	x:0.298	v:-5.945	current decay
# t:942 I:-0.129	g:0.022	u:0.023	x:0.300	v:-5.967	current decay
# t:943 I:-0.117	g:0.020	u:0.022	x:0.301	v:-5.988	current decay
# t:944 I:-0.107	g:0.018	u:0.020	x:0.303	v:-6.009	current decay
# t:945 I:-0.097	g:0.016	u:0.019	x:0.304	v:-6.030	current decay
# t:946 I:-0.088	g:0.015	u:0.018	x:0.306	v:-6.052	current decay
# t:947 I:-0.080	g:0.013	u:0.017	x:0.308	v:-6.073	current decay
# t:948 I:-0.073	g:0.012	u:0.016	x:0.309	v:-6.094	current decay
# t:949 I:-0.066	g:0.011	u:0.015	x:0.311	v:-6.115	current decay
# t:950 I:-0.060	g:0.010	u:0.014	x:0.312	v:-6.136	current decay
# t:951 I:-0.055	g:0.009	u:0.013	x:0.314	v:-6.156	current decay
# t:952 I:-0.055	g:1.200	u:0.269	x:0.231	v:-6.177	synaptic spike
# t:952 I:-7.411	g:1.200	u:0.269	x:0.231	v:-6.177	current decay
# t:953 I:-6.721	g:1.088	u:0.254	x:0.232	v:-6.179	current decay
# t:954 I:-6.099	g:0.986	u:0.239	x:0.234	v:-6.185	current decay
# t:955 I:-5.538	g:0.894	u:0.225	x:0.236	v:-6.194	current decay
# t:956 I:-5.030	g:0.811	u:0.212	x:0.238	v:-6.205	current decay
# t:957 I:-4.571	g:0.735	u:0.200	x:0.239	v:-6.219	current decay
# t:958 I:-4.154	g:0.666	u:0.188	x:0.241	v:-6.235	current decay
# t:959 I:-3.777	g:0.604	u:0.177	x:0.243	v:-6.252	current decay
# t:960 I:-3.434	g:0.548	u:0.167	x:0.245	v:-6.271	current decay
# t:961 I:-3.124	g:0.497	u:0.157	x:0.246	v:-6.290	current decay
# t:962 I:-2.841	g:0.450	u:0.148	x:0.248	v:-6.310	current decay
# t:963 I:-2.584	g:0.408	u:0.139	x:0.250	v:-6.331	current decay
# t:964 I:-2.351	g:0.370	u:0.131	x:0.252	v:-6.353	current decay
# t:965 I:-2.139	g:0.336	u:0.124	x:0.253	v:-6.375	current decay
# t:966 I:-1.946	g:0.304	u:0.116	x:0.255	v:-6.397	current decay
# t:967 I:-1.770	g:0.276	u:0.110	x:0.257	v:-6.419	current decay
# t:968 I:-1.611	g:0.250	u:0.103	x:0.258	v:-6.442	current decay
# t:969 I:-1.466	g:0.227	u:0.097	x:0.260	v:-6.464	current decay
# t:970 I:-1.333	g:0.206	u:0.092	x:0.262	v:-6.487	current decay
# t:971 I:-1.213	g:0.186	u:0.086	x:0.263	v:-6.510	current decay
# t:972 I:-1.104	g:0.169	u:0.081	x:0.265	v:-6.532	current decay
# t:973 I:-1.004	g:0.153	u:0.077	x:0.267	v:-6.555	current decay
# t:974 I:-0.913	g:0.139	u:0.072	x:0.269	v:-6.577	current decay
# t:975 I:-0.831	g:0.126	u:0.068	x:0.270	v:-6.600	current decay
# t:976 I:-0.756	g:0.114	u:0.064	x:0.272	v:-6.622	current decay
# t:977 I:-0.688	g:0.103	u:0.060	x:0.274	v:-6.644	current decay
# t:978 I:-0.626	g:0.094	u:0.057	x:0.275	v:-6.666	current decay
# t:979 I:-0.569	g:0.085	u:0.053	x:0.277	v:-6.688	current decay
# t:980 I:-0.518	g:0.077	u:0.050	x:0.279	v:-6.710	current decay
# t:981 I:-0.471	g:0.070	u:0.047	x:0.280	v:-6.731	current decay
# t:982 I:-0.428	g:0.063	u:0.045	x:0.282	v:-6.753	current decay
# t:983 I:-0.389	g:0.057	u:0.042	x:0.283	v:-6.774	current decay
# t:984 I:-0.354	g:0.052	u:0.040	x:0.285	v:-6.796	current decay
# t:985 I:-0.322	g:0.047	u:0.037	x:0.287	v:-6.817	current decay
# t:986 I:-0.293	g:0.043	u:0.035	x:0.288	v:-6.838	current decay
# t:987 I:-0.266	g:0.039	u:0.033	x:0.290	v:-6.859	current decay
# t:988 I:-0.242	g:0.035	u:0.031	x:0.292	v:-6.880	current decay
# t:989 I:-0.220	g:0.032	u:0.029	x:0.293	v:-6.901	current decay
# t:990 I:-0.200	g:0.029	u:0.028	x:0.295	v:-6.922	current decay
# t:991 I:-0.182	g:0.026	u:0.026	x:0.297	v:-6.942	current decay
# t:992 I:-0.166	g:0.024	u:0.025	x:0.298	v:-6.963	current decay
# t:993 I:-0.151	g:0.022	u:0.023	x:0.300	v:-6.983	current decay
# t:994 I:-0.137	g:0.020	u:0.022	x:0.301	v:-7.004	current decay
# t:995 I:-0.125	g:0.018	u:0.020	x:0.303	v:-7.024	current decay
# t:996 I:-0.113	g:0.016	u:0.019	x:0.305	v:-7.044	current decay
# t:997 I:-0.103	g:0.015	u:0.018	x:0.306	v:-7.064	current decay
# t:998 I:-0.094	g:0.013	u:0.017	x:0.308	v:-7.084	current decay
# t:999 I:-0.085	g:0.012	u:0.016	x:0.309	v:-7.104	current decay
# /tmp/ipykernel_40351/2817761657.py:261: DeprecationWarning: scipy.conj is deprecated and will be removed in SciPy 2.0.0, use numpy.conj instead
#   c = scipy.ifft(af * scipy.conj(bf))
# /tmp/ipykernel_40351/2817761657.py:261: DeprecationWarning: scipy.ifft is deprecated and will be removed in SciPy 2.0.0, use scipy.fft.ifft instead
#   c = scipy.ifft(af * scipy.conj(bf))
# /tmp/ipykernel_40351/2817761657.py:292: RuntimeWarning: invalid value encountered in true_divide
#   pctErrorI = abs((I_2 - I_syn_2)/I_syn_2)

# %%
# Print stats related to the differences between the voltage computed via Keivan's model and CARLsim
print(maxErrorV)
print(minErrorV)
print(meanErrorV)
print(medianErrorV)
print(mismatchV)
# Out:
# 0.0010360326336681467
# 1.2928933573394543e-08
# 0.0003057951979061734
# 0.0003578259458574965
# 0.0003130776190437925

# %%
# Print stats related to the differences between the current computed via Keivan's model and CARLsim
print(maxErrorI)
print(minErrorI)
print(meanErrorI)
print(medianErrorI)
print(mismatchI)
# Out:
# 1.1583349103049558
# 5.181246986581737e-07
# 0.007962890744922471
# 0.0024832550344909762
# 0.0037698842660146663
